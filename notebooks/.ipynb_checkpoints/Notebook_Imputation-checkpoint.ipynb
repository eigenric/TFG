# %% [markdown]
# # Flujo de Trabajo de Imputación para Pampaneira (Refactorizado)
#
# Este cuaderno ejecuta el pipeline refactorizado para imputar valores faltantes en el conjunto de datos de Pampaneira.

# %% [markdown]
# ## 1. Configuración e Importaciones
#
# Aseguramos que la raíz del proyecto esté en el path de Python. Ajusta la profundidad del path ('../') según sea necesario dependiendo de dónde se encuentre este cuaderno en relación con la raíz del proyecto.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
import os
import sys
from sklearn.preprocessing import StandardScaler # Mantener para uso directo/verificación potencial
from torch.optim import Adam
from torch.optim.lr_scheduler import ReduceLROnPlateau
from torch.nn import SmoothL1Loss

# Asegurar que la raíz del proyecto esté en el Python path
# Ajusta la profundidad del path ('../') según sea necesario
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %% [markdown]
# Importamos los módulos refactorizados del proyecto:

# %%
# Importar módulos refactorizados
from pampaneira_imputation import config
from pampaneira_imputation import data_loader as dl
from pampaneira_imputation import data_preprocessor as dp
from pampaneira_imputation import imputation_methods as im
from pampaneira_imputation import evaluation as ev
from pampaneira_imputation import utils
# Out:
# ████████╗██╗███╗   ███╗███████╗    ███████╗███████╗██████╗ ██╗███████╗███████╗    █████╗ ██╗
# ╚══██╔══╝██║████╗ ████║██╔════╝    ██╔════╝██╔════╝██╔══██╗██║██╔════╝██╔════╝   ██╔══██╗██║
#    ██║   ██║██╔████╔██║█████╗█████╗███████╗█████╗  ██████╔╝██║█████╗  ███████╗   ███████║██║
#    ██║   ██║██║╚██╔╝██║██╔══╝╚════╝╚════██║██╔══╝  ██╔══██╗██║██╔══╝  ╚════██║   ██╔══██║██║
#    ██║   ██║██║ ╚═╝ ██║███████╗    ███████║███████╗██║  ██║██║███████╗███████║██╗██║  ██║██║
#    ╚═╝   ╚═╝╚═╝     ╚═╝╚══════╝    ╚══════╝╚══════╝╚═╝  ╚═╝╚═╝╚══════╝╚══════╝╚═╝╚═╝  ╚═╝╚═╝
# ai4ts v0.0.3 - building AI for unified time-series analysis, https://time-series.ai

# %% [markdown]
# Importamos SAITS por separado (asumiendo que pypots está instalado):

# %%
# Importar SAITS por separado (asumiendo que pypots está instalado)
try:
    from pypots.imputation import SAITS, Transformer
except ImportError:
    print("Advertencia: No se encontró la librería pypots. La imputación con SAITS no estará disponible.")
    SAITS = None # Definir como None si no está disponible

# %% [markdown]
# Configuramos pandas y la visualización:

# %%
# Configurar pandas y visualización
pd.options.mode.chained_assignment = None
pd.reset_option('display.max_rows')
pd.reset_option('display.max_columns')
plt.rcParams["figure.figsize"] = [12, 4]
warnings.filterwarnings("ignore") # Usar con precaución

# %% [markdown]
# ## 2. Carga de Datos
#
# Cargamos los datos de la intersección (filtrados para PAM_2):

# %%
# Cargar datos de intersección (filtrados para PAM_2)
try:
    df_int_raw = dl.load_intersection_data(
        filepath=config.INTERSECTION_FILE,
        target_truck_pos=config.TARGET_TRUCK_POS
    )
    print(f"Forma de los datos de intersección cargados: {df_int_raw.shape}")
    print(f"Rango de fechas: {df_int_raw[config.DATE_COL].min()} a {df_int_raw[config.DATE_COL].max()}")
    # display(df_int_raw.head()) # Opcional: mostrar encabezado
except Exception as e:
    print(f"Error al cargar los datos de intersección: {e}")
    # Detener ejecución o manejar el error apropiadamente
    raise
# Out:
# Forma de los datos de intersección cargados: (1335, 115)
# Rango de fechas: 2023-01-17 17:00:00+00:00 a 2023-06-27 00:00:00+00:00

# %% [markdown]
# ## 3. Preprocesamiento de Datos

# %% [markdown]
# ### 3.1 Rellenar Marcas de Tiempo Faltantes (Dentro de Periodos Definidos)
#
# Creamos el rango de fechas completo que cubre ambos periodos conocidos de datos del camión:

# %%
df_int_reindexed = dp.fill_missing_timestamps(df_int_raw, config.PERIOD_1_PADDING_START, config.PERIOD_2_PADDING_END)
print(f"Forma después de reindexar a periodos combinados: {df_int_reindexed.shape}")
# Out:
# Forma después de reindexar a periodos combinados: (3888, 114)

# %% [markdown]
# Verificamos los NaNs introducidos por la reindexación:

# %%
# Verificar los NaNs introducidos
print(f"NaNs introducidos por reindexación: {df_int_reindexed.isnull().sum().sum()}")
# Out:
# NaNs introducidos por reindexación: 292812

# %% [markdown]
# ### 3.2 Dividir en Periodos
#
# Establecemos la columna de fecha como índice y dividimos el DataFrame en los dos periodos definidos en la configuración.

# %%
# Dividir en Periodos
periodo_1_raw, periodo_2_raw = dp.split_by_period(df_int_reindexed)

print(f"Forma del Periodo 1: {periodo_1_raw.shape}")
print(f"Forma del Periodo 2: {periodo_2_raw.shape}")
# Out:
# Forma del Periodo 1: (1368, 114)
# Forma del Periodo 2: (528, 114)

# %% [markdown]
# ### 3.4 Dividir, Escalar, Ventanear y Crear Ausencia para el Periodo 1
#
# Esta función ahora maneja la división train/val/test, el escalado (normalización Z-score), la creación de ventanas deslizantes (`sliding window`) y la introducción artificial de valores faltantes (`missingness`) según la configuración.

# %% [markdown]
# Para dividir el periodo del 17 de enero de 2023 al 14 de marzo de 2023 en entrenamiento, validación y prueba siguiendo un esquema análogo al del Beijing Multi-Site Air-Quality Dataset, vamos a asignar los datos de manera similar a cómo se hizo en ese conjunto.
#
# El esquema original divide los datos en tres partes:
#
# - **Fase de entrenamiento (80% del dataset):** Primeros 45 días
#    - **Training:** 80% de los 45 días: 36 días
#    - **Validación** 20% restante de los 45 días: 9 días.
# - **Prueba (20% del dataset):** 20% del dataset:  11 días.
#
# El periodo de tiempo es del 17 de enero de 2023 al 14 de marzo de 2023. **hay 57 días.**
#
# - **Conjunto de entrenamiento: 17 de enero de 2023 - 21 de febrero de 2023 (36 días)**
# - **Conjunto de validación: 22 de febrero de 2023 - 2 de marzo de 2023 (9 días)**.
# - **Conjunto de prueba: 3 de marzo de 2023 - 14 de marzo de 2023) (12 días)**

# %%
# Dividir, Escalar, Ventanear y Crear Ausencia para el Periodo 1
# Esta función ahora maneja la división train/val/test, escalado, ventaneo y creación de valores faltantes
try:
    processed_data = dp.preprocess_for_imputation(
        periodo_1_raw,
        feature_cols=config.FEATURE_COLUMNS,
        n_steps=config.N_STEPS,
        missing_rate=config.MISSING_RATE,
        missing_pattern=config.MISSING_PATTERN
        # Añadir otros argumentos de missingness si es necesario, ej., min_missing_len=...
    )
    print("Preprocesamiento completo. Estructura de datos:")
    for key, value in processed_data.items():
        if isinstance(value, np.ndarray):
            print(f"- {key}: forma {value.shape}")
        elif isinstance(value, pd.Index):
             print(f"- {key}: longitud {len(value)}")
        elif not isinstance(value, StandardScaler): # No imprimir detalles del scaler
            print(f"- {key}: {value}")

except ValueError as e:
    print(f"Error durante el preprocesamiento: {e}")
    raise
# Out:
# Introduciendo 10.0% de datos faltantes con patrón 'point'...
# Preprocesamiento completo. Estructura de datos:
# - n_steps: 24
# - n_features: 114
# - train_index: longitud 864
# - val_index: longitud 216
# - test_index: longitud 288
# - train_X_ori: forma (841, 24, 114)
# - val_X_ori: forma (193, 24, 114)
# - test_X_ori: forma (265, 24, 114)
# - train_X: forma (841, 24, 114)
# - val_X: forma (193, 24, 114)
# - test_X: forma (265, 24, 114)
# - train_missing_mask: forma (841, 24, 114)
# - val_missing_mask: forma (193, 24, 114)
# - test_missing_mask: forma (265, 24, 114)
# - train_indicating_mask: forma (841, 24, 114)
# - val_indicating_mask: forma (193, 24, 114)
# - test_indicating_mask: forma (265, 24, 114)
# - n_train_samples: 841
# - n_val_samples: 193
# - n_test_samples: 265

# %% [markdown]
# Preparamos los conjuntos de datos para PyPOTS (u otras bibliotecas) si es necesario:

# %%
# Preparar datasets para PyPOTS (u otras bibliotecas) si es necesario
dataset_for_training = {"X": processed_data['train_X']}
dataset_for_validating = {"X": processed_data['val_X'], "X_ori": processed_data['val_X_ori']}
# Nota: La validación en PyPOTS usualmente necesita X_ori para calcular la pérdida sobre los valores originales
# antes del enmascaramiento, pero nuestra evaluación calcula métricas en el conjunto de test usando test_X_ori

dataset_for_testing = {
    "X": processed_data['test_X'], # Datos con NaNs para la entrada del modelo de imputación
    "X_ori": processed_data['test_X_ori'], # Datos originales (escalados) antes de enmascarar
    "indicating_mask": processed_data['test_indicating_mask'] # Máscara de los NaNs introducidos
    }

# %% [markdown]
# ### 3.4 Dividir, Escalar, Ventanear y Crear Ausencia para el Periodo 2
#
# Esta función ahora maneja la división train/val/test, el escalado (normalización Z-score), la creación de ventanas deslizantes (`sliding window`) y la introducción artificial de valores faltantes (`missingness`) según la configuración.

# %%
periodo_2_raw
# Out:
#                            vehicles_PAM_1_OUT  \
# 2023-06-06 00:00:00+00:00                 NaN
# 2023-06-06 01:00:00+00:00                 NaN
# 2023-06-06 02:00:00+00:00                 NaN
# 2023-06-06 03:00:00+00:00                 NaN
# 2023-06-06 04:00:00+00:00                 NaN
# ...                                       ...
# 2023-06-27 19:00:00+00:00                 NaN
# 2023-06-27 20:00:00+00:00                 NaN
# 2023-06-27 21:00:00+00:00                 NaN
# 2023-06-27 22:00:00+00:00                 NaN
# 2023-06-27 23:00:00+00:00                 NaN
#
#                            vehicles_PAM_1_OUT_Zona_Granada  \
# 2023-06-06 00:00:00+00:00                              NaN
# 2023-06-06 01:00:00+00:00                              NaN
# 2023-06-06 02:00:00+00:00                              NaN
# 2023-06-06 03:00:00+00:00                              NaN
# 2023-06-06 04:00:00+00:00                              NaN
# ...                                                    ...
# 2023-06-27 19:00:00+00:00                              NaN
# 2023-06-27 20:00:00+00:00                              NaN
# 2023-06-27 21:00:00+00:00                              NaN
# 2023-06-27 22:00:00+00:00                              NaN
# 2023-06-27 23:00:00+00:00                              NaN
#
#                            vehicles_PAM_1_OUT_Zona_Catalunia_y_Otras  \
# 2023-06-06 00:00:00+00:00                                        NaN
# 2023-06-06 01:00:00+00:00                                        NaN
# 2023-06-06 02:00:00+00:00                                        NaN
# 2023-06-06 03:00:00+00:00                                        NaN
# 2023-06-06 04:00:00+00:00                                        NaN
# ...                                                              ...
# 2023-06-27 19:00:00+00:00                                        NaN
# 2023-06-27 20:00:00+00:00                                        NaN
# 2023-06-27 21:00:00+00:00                                        NaN
# 2023-06-27 22:00:00+00:00                                        NaN
# 2023-06-27 23:00:00+00:00                                        NaN
#
#                            vehicles_PAM_1_OUT_Zona_Andalucia_no_GR  \
# 2023-06-06 00:00:00+00:00                                      NaN
# 2023-06-06 01:00:00+00:00                                      NaN
# 2023-06-06 02:00:00+00:00                                      NaN
# 2023-06-06 03:00:00+00:00                                      NaN
# 2023-06-06 04:00:00+00:00                                      NaN
# ...                                                            ...
# 2023-06-27 19:00:00+00:00                                      NaN
# 2023-06-27 20:00:00+00:00                                      NaN
# 2023-06-27 21:00:00+00:00                                      NaN
# 2023-06-27 22:00:00+00:00                                      NaN
# 2023-06-27 23:00:00+00:00                                      NaN
#
#                            vehicles_PAM_1_OUT_Extranjero  \
# 2023-06-06 00:00:00+00:00                            NaN
# 2023-06-06 01:00:00+00:00                            NaN
# 2023-06-06 02:00:00+00:00                            NaN
# 2023-06-06 03:00:00+00:00                            NaN
# 2023-06-06 04:00:00+00:00                            NaN
# ...                                                  ...
# 2023-06-27 19:00:00+00:00                            NaN
# 2023-06-27 20:00:00+00:00                            NaN
# 2023-06-27 21:00:00+00:00                            NaN
# 2023-06-27 22:00:00+00:00                            NaN
# 2023-06-27 23:00:00+00:00                            NaN
#
#                            vehicles_PAM_1_OUT_Zona_Comunidad_de_Madrid  \
# 2023-06-06 00:00:00+00:00                                          NaN
# 2023-06-06 01:00:00+00:00                                          NaN
# 2023-06-06 02:00:00+00:00                                          NaN
# 2023-06-06 03:00:00+00:00                                          NaN
# 2023-06-06 04:00:00+00:00                                          NaN
# ...                                                                ...
# 2023-06-27 19:00:00+00:00                                          NaN
# 2023-06-27 20:00:00+00:00                                          NaN
# 2023-06-27 21:00:00+00:00                                          NaN
# 2023-06-27 22:00:00+00:00                                          NaN
# 2023-06-27 23:00:00+00:00                                          NaN
#
#                            vehicles_PAM_1_OUT_Zona_Extremadura_y_Otras  \
# 2023-06-06 00:00:00+00:00                                          NaN
# 2023-06-06 01:00:00+00:00                                          NaN
# 2023-06-06 02:00:00+00:00                                          NaN
# 2023-06-06 03:00:00+00:00                                          NaN
# 2023-06-06 04:00:00+00:00                                          NaN
# ...                                                                ...
# 2023-06-27 19:00:00+00:00                                          NaN
# 2023-06-27 20:00:00+00:00                                          NaN
# 2023-06-27 21:00:00+00:00                                          NaN
# 2023-06-27 22:00:00+00:00                                          NaN
# 2023-06-27 23:00:00+00:00                                          NaN
#
#                            vehicles_PAM_1_OUT_Zona_Otras  \
# 2023-06-06 00:00:00+00:00                            NaN
# 2023-06-06 01:00:00+00:00                            NaN
# 2023-06-06 02:00:00+00:00                            NaN
# 2023-06-06 03:00:00+00:00                            NaN
# 2023-06-06 04:00:00+00:00                            NaN
# ...                                                  ...
# 2023-06-27 19:00:00+00:00                            NaN
# 2023-06-27 20:00:00+00:00                            NaN
# 2023-06-27 21:00:00+00:00                            NaN
# 2023-06-27 22:00:00+00:00                            NaN
# 2023-06-27 23:00:00+00:00                            NaN
#
#                            vehicles_PAM_1_OUT_5_seats  \
# 2023-06-06 00:00:00+00:00                         NaN
# 2023-06-06 01:00:00+00:00                         NaN
# 2023-06-06 02:00:00+00:00                         NaN
# 2023-06-06 03:00:00+00:00                         NaN
# 2023-06-06 04:00:00+00:00                         NaN
# ...                                               ...
# 2023-06-27 19:00:00+00:00                         NaN
# 2023-06-27 20:00:00+00:00                         NaN
# 2023-06-27 21:00:00+00:00                         NaN
# 2023-06-27 22:00:00+00:00                         NaN
# 2023-06-27 23:00:00+00:00                         NaN
#
#                            vehicles_PAM_1_OUT_+5_seats  ...  NO  O3  PM10  \
# 2023-06-06 00:00:00+00:00                          NaN  ... NaN NaN   NaN
# 2023-06-06 01:00:00+00:00                          NaN  ... NaN NaN   NaN
# 2023-06-06 02:00:00+00:00                          NaN  ... NaN NaN   NaN
# 2023-06-06 03:00:00+00:00                          NaN  ... NaN NaN   NaN
# 2023-06-06 04:00:00+00:00                          NaN  ... NaN NaN   NaN
# ...                                                ...  ...  ..  ..   ...
# 2023-06-27 19:00:00+00:00                          NaN  ... NaN NaN   NaN
# 2023-06-27 20:00:00+00:00                          NaN  ... NaN NaN   NaN
# 2023-06-27 21:00:00+00:00                          NaN  ... NaN NaN   NaN
# 2023-06-27 22:00:00+00:00                          NaN  ... NaN NaN   NaN
# 2023-06-27 23:00:00+00:00                          NaN  ... NaN NaN   NaN
#
#                            eBC_ff  eBC_bb  TEMP  RH  WS  WD  PRES
# 2023-06-06 00:00:00+00:00     NaN     NaN   NaN NaN NaN NaN   NaN
# 2023-06-06 01:00:00+00:00     NaN     NaN   NaN NaN NaN NaN   NaN
# 2023-06-06 02:00:00+00:00     NaN     NaN   NaN NaN NaN NaN   NaN
# 2023-06-06 03:00:00+00:00     NaN     NaN   NaN NaN NaN NaN   NaN
# 2023-06-06 04:00:00+00:00     NaN     NaN   NaN NaN NaN NaN   NaN
# ...                           ...     ...   ...  ..  ..  ..   ...
# 2023-06-27 19:00:00+00:00     NaN     NaN   NaN NaN NaN NaN   NaN
# 2023-06-27 20:00:00+00:00     NaN     NaN   NaN NaN NaN NaN   NaN
# 2023-06-27 21:00:00+00:00     NaN     NaN   NaN NaN NaN NaN   NaN
# 2023-06-27 22:00:00+00:00     NaN     NaN   NaN NaN NaN NaN   NaN
# 2023-06-27 23:00:00+00:00     NaN     NaN   NaN NaN NaN NaN   NaN
#
# [528 rows x 114 columns]

# %% [markdown]
# ### Fechas de división del periodo 2 (22 días)

# %% [markdown]
# - 80% Fase de entrenamiento: 18 días
#     - **Training:** 80% de 18: **14 días** (2023-06-06 al 2023-06-19)
#     - **Validación:** 20% de 18: **4 días** (2023-06-20 al 2023-06-23)
# - 20% **Testing**: **4 días** (2023-06-24 al 2023-06-27)

# %%
# Dividir, Escalar, Ventanear y Crear Ausencia para el Periodo 1
# Esta función ahora maneja la división train/val/test, escalado, ventaneo y creación de valores faltantes
try:
    processed_data2 = dp.preprocess_for_imputation(
        periodo_2_raw,
        feature_cols=config.FEATURE_COLUMNS,
        n_steps=config.N_STEPS,
        missing_rate=config.MISSING_RATE,
        missing_pattern=config.MISSING_PATTERN,
        train_starn=config.TRAIN_2_START_DATE,
        train_end=config.TRAIN_2_END_DATE,
        val_start=config.VAL_2_START_DATE,
        val_end=config.VAL_2_END_DATE,
        test_start=config.TEST_2_START_DATE,
        test_end=config.TEST_2_END_DATE,
        # Añadir otros argumentos de missingness si es necesario, ej., min_missing_len=...
    )
    print("Preprocesamiento completo. Estructura de datos:")
    for key, value in processed_data.items():
        if isinstance(value, np.ndarray):
            print(f"- {key}: forma {value.shape}")
        elif isinstance(value, pd.Index):
             print(f"- {key}: longitud {len(value)}")
        elif not isinstance(value, StandardScaler): # No imprimir detalles del scaler
            print(f"- {key}: {value}")

except ValueError as e:
    print(f"Error durante el preprocesamiento: {e}")
    raise
# Out:
# Introduciendo 10.0% de datos faltantes con patrón 'point'...
# Preprocesamiento completo. Estructura de datos:
# - n_steps: 24
# - n_features: 114
# - train_index: longitud 864
# - val_index: longitud 216
# - test_index: longitud 288
# - train_X_ori: forma (841, 24, 114)
# - val_X_ori: forma (193, 24, 114)
# - test_X_ori: forma (265, 24, 114)
# - train_X: forma (841, 24, 114)
# - val_X: forma (193, 24, 114)
# - test_X: forma (265, 24, 114)
# - train_missing_mask: forma (841, 24, 114)
# - val_missing_mask: forma (193, 24, 114)
# - test_missing_mask: forma (265, 24, 114)
# - train_indicating_mask: forma (841, 24, 114)
# - val_indicating_mask: forma (193, 24, 114)
# - test_indicating_mask: forma (265, 24, 114)
# - n_train_samples: 841
# - n_val_samples: 193
# - n_test_samples: 265

# %%
# Preparar datasets para PyPOTS (u otras bibliotecas) si es necesario
dataset_for_training2 = {"X": processed_data2['train_X']}
dataset_for_validating2 = {"X": processed_data2['val_X'], "X_ori": processed_data2['val_X_ori']}
# Nota: La validación en PyPOTS usualmente necesita X_ori para calcular la pérdida sobre los valores originales
# antes del enmascaramiento, pero nuestra evaluación calcula métricas en el conjunto de test usando test_X_ori

dataset_for_testing2 = {
    "X": processed_data2['test_X'], # Datos con NaNs para la entrada del modelo de imputación
    "X_ori": processed_data2['test_X_ori'], # Datos originales (escalados) antes de enmascarar
    "indicating_mask": processed_data2['test_indicating_mask'] # Máscara de los NaNs introducidos
}

# %% [markdown]
# ## 4. Métodos de Imputación para Periodo 1
#
# Aplicamos métodos base a los datos del conjunto de test (`dataset_for_testing['X']`). Almacenamos los resultados en un diccionario.

# %%
# Aplicar métodos base a los datos del conjunto de test (`dataset_for_testing['X']`)
X_test_missing = dataset_for_testing['X']
imputed_results = {} # Diccionario para almacenar resultados

print("\nEjecutando métodos de imputación base...")
# Out:
# Ejecutando métodos de imputación base...

# %% [markdown]
# ### 4.1. Modelos Baseline

# %% [markdown]
# ####
# 4.1 Imputación por Mediana
#
# Rellenamos los valores faltantes utilizando la mediana de cada característica (columna) calculada sobre todo el conjunto de datos de test (a través de todas las muestras y pasos de tiempo).

# %%
imputed_results['median'] = im.impute_median_sample_wise(X_test_missing)
print(f"Forma imputación mediana: {imputed_results['median'].shape}, NaNs: {np.isnan(imputed_results['median']).sum()}")
# Out:
# Forma imputación mediana: (265, 24, 114), NaNs: 0

# %% [markdown]
# #### 4.2 Imputación por Media
#
# Similar a la mediana, pero usamos la media de cada característica para rellenar los valores faltantes.

# %%
imputed_results['mean'] = im.impute_mean_sample_wise(X_test_missing)
print(f"Forma imputación media: {imputed_results['mean'].shape}, NaNs: {np.isnan(imputed_results['mean']).sum()}")
# Out:
# Forma imputación media: (265, 24, 114), NaNs: 0

# %% [markdown]
# #### 4.3 Interpolación Lineal
#
# Rellenamos los valores faltantes mediante interpolación lineal a lo largo del eje temporal (pasos de tiempo) para cada muestra y característica de forma independiente.

# %%
imputed_results['linear'] = im.impute_linear(X_test_missing)
print(f"Forma imputación lineal: {imputed_results['linear'].shape}, NaNs: {np.isnan(imputed_results['linear']).sum()}")
# Out:
# Forma imputación lineal: (265, 24, 114), NaNs: 0

# %% [markdown]
# #### 4.4 Relleno Forward/Backward (ffill/bfill)
#
# Aplicamos dos estrategias de relleno local:
# 1.  `ffill_bfill`: Primero rellenamos hacia adelante (usando el último valor válido conocido) y luego hacia atrás (usando el primer valor válido conocido) para rellenar los huecos restantes.
# 2.  `bfill_ffill`: Primero rellenamos hacia atrás y luego hacia adelante.
#
# Nota: Estos métodos pueden requerir eliminar columnas como `WS`, `WD` si causan problemas o no son necesarias. La función de imputación en sí no elimina columnas, pero la evaluación podría necesitar alineación. Asumiremos por ahora que imputamos todas las características. La evaluación maneja la posible eliminación de columnas. Alternativamente, modificamos los datos de entrada antes de pasarlos a la imputación:

# %%
# ### 4.4 Relleno Forward/Backward (ffill/bfill)
# Nota: Estos métodos pueden requerir eliminar columnas como WS, WD si causan problemas.
# Modificamos los datos de entrada si es necesario:
X_test_missing_no_ws_wd = X_test_missing.copy()
cols_to_drop_indices = [config.FEATURE_COLUMNS.index(col) for col in config.COLS_TO_DROP_FOR_BASELINE if col in config.FEATURE_COLUMNS]

if cols_to_drop_indices:
    print(f"Eliminando columnas en índices {cols_to_drop_indices} para métodos Fill.")
    X_test_missing_no_ws_wd = np.delete(X_test_missing, cols_to_drop_indices, axis=2)
else:
    X_test_missing_no_ws_wd = X_test_missing # No hay columnas que eliminar


fb_imputed, bf_imputed = im.impute_forward_backward(X_test_missing_no_ws_wd)
imputed_results['ffill_bfill'] = fb_imputed
imputed_results['bfill_ffill'] = bf_imputed
print(f"Forma imputación Ffill-Bfill: {imputed_results['ffill_bfill'].shape}, NaNs: {np.isnan(imputed_results['ffill_bfill']).sum()}")
print(f"Forma imputación Bfill-Ffill: {imputed_results['bfill_ffill'].shape}, NaNs: {np.isnan(imputed_results['bfill_ffill']).sum()}")
# Out:
# Eliminando columnas en índices [111, 112] para métodos Fill.
# Forma imputación Ffill-Bfill: (265, 24, 112), NaNs: 0
# Forma imputación Bfill-Ffill: (265, 24, 112), NaNs: 0

# %% [markdown]
# ### 4.5. Modelo Transformer

# %%
from pampaneira_imputation import config

transformer_config = config.TRANSFORMER_PARAMS.copy()
transformer_config['n_features'] = processed_data['n_features']  # Set dynamically
    
# Initialize the Transformer model
transformer_model = Transformer(**transformer_config)
    
# Set up optimizer, scheduler, and loss function
optimizer = Adam(transformer_model.model.parameters(), **config.TRANSFORMER_OPTIMIZER_PARAMS)
scheduler = ReduceLROnPlateau(optimizer, **config.TRANSFORMER_SCHEDULER_PARAMS)
loss_func = SmoothL1Loss(**config.TRANSFORMER_LOSS_PARAMS)
    
# Train the model
print("Training Transformer model...")
transformer_model.fit(
        train_set=dataset_for_training,
        val_set=dataset_for_validating,  # Pass validation set for early stopping
)
print("Transformer training complete.")

# Predecir (imputar) en el conjunto de test
print("Imputando con Transformer en el conjunto de test...")
transformer_prediction = transformer_model.predict(dataset_for_testing)
imputed_results['transformer'] = transformer_prediction["imputation"]
print(f"Forma imputación Transformer: {imputed_results['transformer'].shape}, NaNs: {np.isnan(imputed_results['transformer']).sum()}")
# Out:
# 2025-04-08 21:24:24 [INFO]: No given device, using default device: cpu
# 2025-04-08 21:24:24 [INFO]: Model files will be saved to ../results/imputation/transformer/20250408_T212424
# 2025-04-08 21:24:24 [INFO]: Tensorboard file will be saved to ../results/imputation/transformer/20250408_T212424/tensorboard
# 2025-04-08 21:24:24 [INFO]: Using customized MAE as the training loss function.
# 2025-04-08 21:24:24 [INFO]: Using customized MSE as the validation metric function.
# 2025-04-08 21:24:24 [INFO]: Transformer initialized with the given hyperparameters, the number of trainable parameters: 439,922
# Training Transformer model...
# 2025-04-08 21:24:25 [INFO]: Epoch 001 - training loss (MAE): 1.2439, validation MSE: 1.2707
# 2025-04-08 21:24:26 [INFO]: Epoch 002 - training loss (MAE): 0.9399, validation MSE: 1.2570
# 2025-04-08 21:24:27 [INFO]: Epoch 003 - training loss (MAE): 0.8947, validation MSE: 1.2160
# 2025-04-08 21:24:27 [INFO]: Epoch 004 - training loss (MAE): 0.8587, validation MSE: 1.1461
# 2025-04-08 21:24:28 [INFO]: Epoch 005 - training loss (MAE): 0.8167, validation MSE: 1.0835
# 2025-04-08 21:24:29 [INFO]: Epoch 006 - training loss (MAE): 0.7755, validation MSE: 1.0306
# 2025-04-08 21:24:30 [INFO]: Epoch 007 - training loss (MAE): 0.7433, validation MSE: 0.9941
# 2025-04-08 21:24:31 [INFO]: Epoch 008 - training loss (MAE): 0.7111, validation MSE: 0.9779
# 2025-04-08 21:24:33 [INFO]: Epoch 009 - training loss (MAE): 0.6922, validation MSE: 0.9701
# 2025-04-08 21:24:34 [INFO]: Epoch 010 - training loss (MAE): 0.6802, validation MSE: 0.9644
# 2025-04-08 21:24:35 [INFO]: Epoch 011 - training loss (MAE): 0.6630, validation MSE: 0.9570
# 2025-04-08 21:24:37 [INFO]: Epoch 012 - training loss (MAE): 0.6479, validation MSE: 0.9491
# 2025-04-08 21:24:39 [INFO]: Epoch 013 - training loss (MAE): 0.6368, validation MSE: 0.9347
# 2025-04-08 21:24:41 [INFO]: Epoch 014 - training loss (MAE): 0.6254, validation MSE: 0.9329
# 2025-04-08 21:24:43 [INFO]: Epoch 015 - training loss (MAE): 0.6190, validation MSE: 0.9186
# 2025-04-08 21:24:44 [INFO]: Epoch 016 - training loss (MAE): 0.6056, validation MSE: 0.9175
# 2025-04-08 21:24:46 [INFO]: Epoch 017 - training loss (MAE): 0.6009, validation MSE: 0.9037
# 2025-04-08 21:24:48 [INFO]: Epoch 018 - training loss (MAE): 0.5931, validation MSE: 0.9039
# 2025-04-08 21:24:49 [INFO]: Epoch 019 - training loss (MAE): 0.5841, validation MSE: 0.9012
# 2025-04-08 21:24:51 [INFO]: Epoch 020 - training loss (MAE): 0.5776, validation MSE: 0.8953
# 2025-04-08 21:24:52 [INFO]: Epoch 021 - training loss (MAE): 0.5673, validation MSE: 0.8931
# 2025-04-08 21:24:54 [INFO]: Epoch 022 - training loss (MAE): 0.5678, validation MSE: 0.8863
# 2025-04-08 21:24:56 [INFO]: Epoch 023 - training loss (MAE): 0.5601, validation MSE: 0.8780
# 2025-04-08 21:24:58 [INFO]: Epoch 024 - training loss (MAE): 0.5526, validation MSE: 0.8876
# 2025-04-08 21:24:59 [INFO]: Epoch 025 - training loss (MAE): 0.5498, validation MSE: 0.8837
# 2025-04-08 21:25:01 [INFO]: Epoch 026 - training loss (MAE): 0.5447, validation MSE: 0.8742
# 2025-04-08 21:25:02 [INFO]: Epoch 027 - training loss (MAE): 0.5399, validation MSE: 0.8760
# 2025-04-08 21:25:03 [INFO]: Epoch 028 - training loss (MAE): 0.5382, validation MSE: 0.8748
# 2025-04-08 21:25:05 [INFO]: Epoch 029 - training loss (MAE): 0.5321, validation MSE: 0.8744
# 2025-04-08 21:25:07 [INFO]: Epoch 030 - training loss (MAE): 0.5253, validation MSE: 0.8760
# 2025-04-08 21:25:08 [INFO]: Epoch 031 - training loss (MAE): 0.5217, validation MSE: 0.8608
# 2025-04-08 21:25:09 [INFO]: Epoch 032 - training loss (MAE): 0.5181, validation MSE: 0.8656
# 2025-04-08 21:25:11 [INFO]: Epoch 033 - training loss (MAE): 0.5173, validation MSE: 0.8735
# 2025-04-08 21:25:12 [INFO]: Epoch 034 - training loss (MAE): 0.5097, validation MSE: 0.8781
# 2025-04-08 21:25:13 [INFO]: Epoch 035 - training loss (MAE): 0.5081, validation MSE: 0.8692
# 2025-04-08 21:25:14 [INFO]: Epoch 036 - training loss (MAE): 0.5100, validation MSE: 0.8704
# 2025-04-08 21:25:14 [INFO]: Exceeded the training patience. Terminating the training procedure...
# 2025-04-08 21:25:14 [INFO]: Finished training. The best model is from epoch#31.
# 2025-04-08 21:25:14 [INFO]: Saved the model to ../results/imputation/transformer/20250408_T212424/Transformer.pypots
# Transformer training complete.
# Imputando con Transformer en el conjunto de test...
# Forma imputación Transformer: (265, 24, 114), NaNs: 0

# %% [markdown]
# ### 4.6. Modelo SAITS
#
# Si la biblioteca `pypots` está disponible, configuramos y entrenamos un modelo SAITS (Self-Attention based Imputation for Time Series) usando los datos de entrenamiento y validación preprocesados. Luego, usamos el modelo entrenado para imputar los valores faltantes en el conjunto de test.

# %%
# ## 5. Imputación con SAITS (Requiere PyPOTS)

if SAITS is not None:
    print("\nConfigurando y ejecutando imputación con SAITS...")
    # Configurar modelo SAITS
    saits_config = config.SAITS_PARAMS.copy()
    saits_config['n_features'] = processed_data['n_features'] # Establecer dinámicamente

    saits_model = SAITS(**saits_config)

    # Configurar optimizador, planificador y función de pérdida
    optimizer = Adam(saits_model.model.parameters(), **config.SAITS_OPTIMIZER_PARAMS)
    scheduler = ReduceLROnPlateau(optimizer, **config.SAITS_SCHEDULER_PARAMS)
    loss_func = SmoothL1Loss(**config.SAITS_LOSS_PARAMS)

    # Entrenar el modelo
    # Nota: Podrías querer ajustar epochs/patience para ejecuciones más rápidas
    print("Entrenando modelo SAITS...")
    saits_model.fit(
        train_set=dataset_for_training,
        val_set=dataset_for_validating, # Pasar conjunto de validación para early stopping
        )
    print("Entrenamiento de SAITS completo.")

    # Predecir (imputar) en el conjunto de test
    print("Imputando con SAITS en el conjunto de test...")
    saits_prediction = saits_model.predict(dataset_for_testing)
    imputed_results['saits'] = saits_prediction["imputation"]
    print(f"Forma imputación SAITS: {imputed_results['saits'].shape}, NaNs: {np.isnan(imputed_results['saits']).sum()}")

else:
    print("\nSaltando imputación con SAITS ya que pypots no está instalado.")
# Out:
# 2025-04-08 21:25:14 [INFO]: No given device, using default device: cpu
# 2025-04-08 21:25:14 [INFO]: Model files will be saved to ../results/imputation/saits/20250408_T212514
# 2025-04-08 21:25:14 [INFO]: Tensorboard file will be saved to ../results/imputation/saits/20250408_T212514/tensorboard
# 2025-04-08 21:25:14 [INFO]: Using customized MAE as the training loss function.
# 2025-04-08 21:25:14 [INFO]: Using customized MSE as the validation metric function.
# 2025-04-08 21:25:14 [WARNING]: ‼️ d_model must = n_heads * d_k, it should be divisible by n_heads and the result should be equal to d_k, but got d_model=192, n_heads=4, d_k=32
# 2025-04-08 21:25:14 [WARNING]: ⚠️ d_model is reset to 128 = n_heads (4) * d_k (32)
# 2025-04-08 21:25:14 [INFO]: SAITS initialized with the given hyperparameters, the number of trainable parameters: 1,172,736
# Configurando y ejecutando imputación con SAITS...
# Entrenando modelo SAITS...
# 2025-04-08 21:25:18 [INFO]: Epoch 001 - training loss (MAE): 1.1698, validation MSE: 1.3397
# 2025-04-08 21:25:21 [INFO]: Epoch 002 - training loss (MAE): 0.8952, validation MSE: 1.2712
# 2025-04-08 21:25:24 [INFO]: Epoch 003 - training loss (MAE): 0.8444, validation MSE: 1.2195
# 2025-04-08 21:25:28 [INFO]: Epoch 004 - training loss (MAE): 0.8049, validation MSE: 1.1791
# 2025-04-08 21:25:32 [INFO]: Epoch 005 - training loss (MAE): 0.7749, validation MSE: 1.0969
# 2025-04-08 21:25:36 [INFO]: Epoch 006 - training loss (MAE): 0.7361, validation MSE: 1.0513
# 2025-04-08 21:25:40 [INFO]: Epoch 007 - training loss (MAE): 0.7134, validation MSE: 1.0137
# 2025-04-08 21:25:44 [INFO]: Epoch 008 - training loss (MAE): 0.6870, validation MSE: 0.9692
# 2025-04-08 21:25:48 [INFO]: Epoch 009 - training loss (MAE): 0.6670, validation MSE: 0.9609
# 2025-04-08 21:25:51 [INFO]: Epoch 010 - training loss (MAE): 0.6479, validation MSE: 0.9381
# 2025-04-08 21:25:54 [INFO]: Epoch 011 - training loss (MAE): 0.6389, validation MSE: 0.9147
# 2025-04-08 21:25:57 [INFO]: Epoch 012 - training loss (MAE): 0.6277, validation MSE: 0.9029
# 2025-04-08 21:26:00 [INFO]: Epoch 013 - training loss (MAE): 0.6202, validation MSE: 0.8894
# 2025-04-08 21:26:03 [INFO]: Epoch 014 - training loss (MAE): 0.6123, validation MSE: 0.8916
# 2025-04-08 21:26:07 [INFO]: Epoch 015 - training loss (MAE): 0.6080, validation MSE: 0.8837
# 2025-04-08 21:26:10 [INFO]: Epoch 016 - training loss (MAE): 0.5955, validation MSE: 0.8756
# 2025-04-08 21:26:13 [INFO]: Epoch 017 - training loss (MAE): 0.5907, validation MSE: 0.8706
# 2025-04-08 21:26:16 [INFO]: Epoch 018 - training loss (MAE): 0.5845, validation MSE: 0.8602
# 2025-04-08 21:26:19 [INFO]: Epoch 019 - training loss (MAE): 0.5745, validation MSE: 0.8646
# 2025-04-08 21:26:23 [INFO]: Epoch 020 - training loss (MAE): 0.5710, validation MSE: 0.8694
# 2025-04-08 21:26:27 [INFO]: Epoch 021 - training loss (MAE): 0.5614, validation MSE: 0.8590
# 2025-04-08 21:26:31 [INFO]: Epoch 022 - training loss (MAE): 0.5605, validation MSE: 0.8686
# 2025-04-08 21:26:34 [INFO]: Epoch 023 - training loss (MAE): 0.5540, validation MSE: 0.8631
# 2025-04-08 21:26:37 [INFO]: Epoch 024 - training loss (MAE): 0.5477, validation MSE: 0.8611
# 2025-04-08 21:26:40 [INFO]: Epoch 025 - training loss (MAE): 0.5453, validation MSE: 0.8527
# 2025-04-08 21:26:43 [INFO]: Epoch 026 - training loss (MAE): 0.5393, validation MSE: 0.8662
# 2025-04-08 21:26:48 [INFO]: Epoch 027 - training loss (MAE): 0.5308, validation MSE: 0.8557
# 2025-04-08 21:26:51 [INFO]: Epoch 028 - training loss (MAE): 0.5256, validation MSE: 0.8588
# 2025-04-08 21:26:54 [INFO]: Epoch 029 - training loss (MAE): 0.5276, validation MSE: 0.8647
# 2025-04-08 21:26:59 [INFO]: Epoch 030 - training loss (MAE): 0.5227, validation MSE: 0.8643
# 2025-04-08 21:26:59 [INFO]: Exceeded the training patience. Terminating the training procedure...
# 2025-04-08 21:26:59 [INFO]: Finished training. The best model is from epoch#25.
# 2025-04-08 21:26:59 [INFO]: Saved the model to ../results/imputation/saits/20250408_T212514/SAITS.pypots
# Entrenamiento de SAITS completo.
# Imputando con SAITS en el conjunto de test...
# Forma imputación SAITS: (265, 24, 114), NaNs: 0

# %% [markdown]
# ## 5. Métodos de Imputación para Periodo 2
#
# Aplicamos métodos base a los datos del conjunto de test (`dataset_for_testing2['X']`). Almacenamos los resultados en un diccionario.

# %%
# Aplicar métodos base a los datos del conjunto de test (`dataset_for_testing['X']`)
X_test_missing2 = dataset_for_testing2['X']
imputed_results2 = {} # Diccionario para almacenar resultados

print("\nEjecutando métodos de imputación base...")
# Out:
# Ejecutando métodos de imputación base...

# %% [markdown]
# ### 5.1. Modelos Baseline

# %% [markdown]
# #### 5.1.1 Imputación por Mediana en Periodo 2
#
# Rellenamos los valores faltantes utilizando la mediana de cada característica (columna) calculada sobre todo el conjunto de datos de test (a través de todas las muestras y pasos de tiempo).

# %%
imputed_results2['median'] = im.impute_median_sample_wise(X_test_missing2)
print(f"Forma imputación mediana: {imputed_results2['median'].shape}, NaNs: {np.isnan(imputed_results2['median']).sum()}")
# Out:
# Forma imputación mediana: (73, 24, 114), NaNs: 0

# %% [markdown]
# #### 5.1.2 Imputación por Media en Periodo 2
#
# Similar a la mediana, pero usamos la media de cada característica para rellenar los valores faltantes.

# %%
imputed_results2['mean'] = im.impute_mean_sample_wise(X_test_missing2)
print(f"Forma imputación media: {imputed_results2['mean'].shape}, NaNs: {np.isnan(imputed_results2['mean']).sum()}")
# Out:
# Forma imputación media: (73, 24, 114), NaNs: 0

# %% [markdown]
# #### 5.1.3 Interpolación Lineal en Periodo 2
#
# Rellenamos los valores faltantes mediante interpolación lineal a lo largo del eje temporal (pasos de tiempo) para cada muestra y característica de forma independiente.

# %%
imputed_results2['linear'] = im.impute_linear(X_test_missing2)
print(f"Forma imputación lineal: {imputed_results2['linear'].shape}, NaNs: {np.isnan(imputed_results2['linear']).sum()}")
# Out:
# Forma imputación lineal: (73, 24, 114), NaNs: 0

# %% [markdown]
# #### 5.1.4 Relleno Forward/Backward (ffill/bfill) en Periodo 2

# %%
# ### 4.4 Relleno Forward/Backward (ffill/bfill)
# Nota: Estos métodos pueden requerir eliminar columnas como WS, WD si causan problemas.
# Modificamos los datos de entrada si es necesario:
X_test_missing2_no_ws_wd = X_test_missing2.copy()
cols_to_drop_indices = [config.FEATURE_COLUMNS.index(col) for col in config.COLS_TO_DROP_FOR_BASELINE if col in config.FEATURE_COLUMNS]

if cols_to_drop_indices:
    print(f"Eliminando columnas en índices {cols_to_drop_indices} para métodos Fill.")
    X_test_missing2_no_ws_wd = np.delete(X_test_missing2, cols_to_drop_indices, axis=2)
else:
    X_test_missing2_no_ws_wd = X_test_missing2 # No hay columnas que eliminar


fb_imputed, bf_imputed = im.impute_forward_backward(X_test_missing2_no_ws_wd)
imputed_results2['ffill_bfill'] = fb_imputed
imputed_results2['bfill_ffill'] = bf_imputed
print(f"Forma imputación Ffill-Bfill: {imputed_results2['ffill_bfill'].shape}, NaNs: {np.isnan(imputed_results2['ffill_bfill']).sum()}")
print(f"Forma imputación Bfill-Ffill: {imputed_results2['bfill_ffill'].shape}, NaNs: {np.isnan(imputed_results2['bfill_ffill']).sum()}")
# Out:
# Eliminando columnas en índices [111, 112] para métodos Fill.
# Forma imputación Ffill-Bfill: (73, 24, 112), NaNs: 0
# Forma imputación Bfill-Ffill: (73, 24, 112), NaNs: 0

# %%
print(dataset_for_training2['X'].shape)
print(dataset_for_validating2['X'].shape)
print(dataset_for_testing['X'].shape)
# Out:
# (313, 24, 114)
# (73, 24, 114)
# (265, 24, 114)

# %% [markdown]
# ### 5.2. Modelo Transformer

# %%
from pampaneira_imputation import config

transformer_config = config.TRANSFORMER_PARAMS.copy()
transformer_config['n_features'] = processed_data2['n_features']  # Set dynamically
    
# Initialize the Transformer model
transformer_model = Transformer(**transformer_config)
    
# Set up optimizer, scheduler, and loss function
optimizer = Adam(transformer_model.model.parameters(), **config.TRANSFORMER_OPTIMIZER_PARAMS)
scheduler = ReduceLROnPlateau(optimizer, **config.TRANSFORMER_SCHEDULER_PARAMS)
loss_func = SmoothL1Loss(**config.TRANSFORMER_LOSS_PARAMS)
    
# Train the model
print("Training Transformer model...")
transformer_model.fit(
        train_set=dataset_for_training2,
        val_set=dataset_for_validating2,  # Pass validation set for early stopping
)
print("Transformer training complete.")

# Predecir (imputar) en el conjunto de test
print("Imputando con SAITS en el conjunto de test...")
transformer_prediction2 = transformer_model.predict(dataset_for_testing2)
imputed_results2['transformer'] = transformer_prediction2["imputation"]
print(f"Forma imputación Transformer: {imputed_results2['transformer'].shape}, NaNs: {np.isnan(imputed_results2['transformer']).sum()}")
# Out:
# 2025-04-08 21:27:00 [INFO]: No given device, using default device: cpu
# 2025-04-08 21:27:00 [INFO]: Model files will be saved to ../results/imputation/transformer/20250408_T212700
# 2025-04-08 21:27:00 [INFO]: Tensorboard file will be saved to ../results/imputation/transformer/20250408_T212700/tensorboard
# 2025-04-08 21:27:00 [INFO]: Using customized MAE as the training loss function.
# 2025-04-08 21:27:00 [INFO]: Using customized MSE as the validation metric function.
# 2025-04-08 21:27:00 [INFO]: Transformer initialized with the given hyperparameters, the number of trainable parameters: 439,922
# Training Transformer model...
# 2025-04-08 21:27:01 [INFO]: Epoch 001 - training loss (MAE): 1.5333, validation MSE: 1.1204
# 2025-04-08 21:27:02 [INFO]: Epoch 002 - training loss (MAE): 1.2856, validation MSE: 0.9462
# 2025-04-08 21:27:03 [INFO]: Epoch 003 - training loss (MAE): 1.1032, validation MSE: 0.9123
# 2025-04-08 21:27:03 [INFO]: Epoch 004 - training loss (MAE): 1.0221, validation MSE: 0.8785
# 2025-04-08 21:27:04 [INFO]: Epoch 005 - training loss (MAE): 0.9972, validation MSE: 0.8756
# 2025-04-08 21:27:05 [INFO]: Epoch 006 - training loss (MAE): 0.9763, validation MSE: 0.8811
# 2025-04-08 21:27:06 [INFO]: Epoch 007 - training loss (MAE): 0.9591, validation MSE: 0.8671
# 2025-04-08 21:27:06 [INFO]: Epoch 008 - training loss (MAE): 0.9445, validation MSE: 0.8581
# 2025-04-08 21:27:07 [INFO]: Epoch 009 - training loss (MAE): 0.9353, validation MSE: 0.8555
# 2025-04-08 21:27:07 [INFO]: Epoch 010 - training loss (MAE): 0.9212, validation MSE: 0.8425
# 2025-04-08 21:27:08 [INFO]: Epoch 011 - training loss (MAE): 0.9038, validation MSE: 0.8273
# 2025-04-08 21:27:08 [INFO]: Epoch 012 - training loss (MAE): 0.8882, validation MSE: 0.8189
# 2025-04-08 21:27:09 [INFO]: Epoch 013 - training loss (MAE): 0.8739, validation MSE: 0.8117
# 2025-04-08 21:27:09 [INFO]: Epoch 014 - training loss (MAE): 0.8596, validation MSE: 0.8033
# 2025-04-08 21:27:10 [INFO]: Epoch 015 - training loss (MAE): 0.8428, validation MSE: 0.7963
# 2025-04-08 21:27:10 [INFO]: Epoch 016 - training loss (MAE): 0.8309, validation MSE: 0.7785
# 2025-04-08 21:27:11 [INFO]: Epoch 017 - training loss (MAE): 0.8202, validation MSE: 0.7662
# 2025-04-08 21:27:11 [INFO]: Epoch 018 - training loss (MAE): 0.8091, validation MSE: 0.7449
# 2025-04-08 21:27:12 [INFO]: Epoch 019 - training loss (MAE): 0.7977, validation MSE: 0.7293
# 2025-04-08 21:27:12 [INFO]: Epoch 020 - training loss (MAE): 0.7850, validation MSE: 0.7174
# 2025-04-08 21:27:13 [INFO]: Epoch 021 - training loss (MAE): 0.7739, validation MSE: 0.7124
# 2025-04-08 21:27:14 [INFO]: Epoch 022 - training loss (MAE): 0.7637, validation MSE: 0.7044
# 2025-04-08 21:27:14 [INFO]: Epoch 023 - training loss (MAE): 0.7554, validation MSE: 0.7043
# 2025-04-08 21:27:15 [INFO]: Epoch 024 - training loss (MAE): 0.7457, validation MSE: 0.6946
# 2025-04-08 21:27:15 [INFO]: Epoch 025 - training loss (MAE): 0.7371, validation MSE: 0.6913
# 2025-04-08 21:27:16 [INFO]: Epoch 026 - training loss (MAE): 0.7331, validation MSE: 0.7019
# 2025-04-08 21:27:17 [INFO]: Epoch 027 - training loss (MAE): 0.7259, validation MSE: 0.6896
# 2025-04-08 21:27:17 [INFO]: Epoch 028 - training loss (MAE): 0.7154, validation MSE: 0.6823
# 2025-04-08 21:27:18 [INFO]: Epoch 029 - training loss (MAE): 0.7086, validation MSE: 0.6844
# 2025-04-08 21:27:18 [INFO]: Epoch 030 - training loss (MAE): 0.6971, validation MSE: 0.6896
# 2025-04-08 21:27:19 [INFO]: Epoch 031 - training loss (MAE): 0.6934, validation MSE: 0.6810
# 2025-04-08 21:27:19 [INFO]: Epoch 032 - training loss (MAE): 0.6855, validation MSE: 0.6819
# 2025-04-08 21:27:20 [INFO]: Epoch 033 - training loss (MAE): 0.6800, validation MSE: 0.6878
# 2025-04-08 21:27:20 [INFO]: Epoch 034 - training loss (MAE): 0.6728, validation MSE: 0.6783
# 2025-04-08 21:27:21 [INFO]: Epoch 035 - training loss (MAE): 0.6667, validation MSE: 0.6741
# 2025-04-08 21:27:21 [INFO]: Epoch 036 - training loss (MAE): 0.6606, validation MSE: 0.6790
# 2025-04-08 21:27:22 [INFO]: Epoch 037 - training loss (MAE): 0.6563, validation MSE: 0.6758
# 2025-04-08 21:27:22 [INFO]: Epoch 038 - training loss (MAE): 0.6515, validation MSE: 0.6722
# 2025-04-08 21:27:22 [INFO]: Epoch 039 - training loss (MAE): 0.6436, validation MSE: 0.6707
# 2025-04-08 21:27:23 [INFO]: Epoch 040 - training loss (MAE): 0.6387, validation MSE: 0.6726
# 2025-04-08 21:27:23 [INFO]: Epoch 041 - training loss (MAE): 0.6323, validation MSE: 0.6767
# 2025-04-08 21:27:24 [INFO]: Epoch 042 - training loss (MAE): 0.6288, validation MSE: 0.6724
# 2025-04-08 21:27:24 [INFO]: Epoch 043 - training loss (MAE): 0.6199, validation MSE: 0.6768
# 2025-04-08 21:27:25 [INFO]: Epoch 044 - training loss (MAE): 0.6190, validation MSE: 0.6799
# 2025-04-08 21:27:25 [INFO]: Exceeded the training patience. Terminating the training procedure...
# 2025-04-08 21:27:25 [INFO]: Finished training. The best model is from epoch#39.
# 2025-04-08 21:27:25 [INFO]: Saved the model to ../results/imputation/transformer/20250408_T212700/Transformer.pypots
# Transformer training complete.
# Imputando con SAITS en el conjunto de test...
# Forma imputación Transformer: (73, 24, 114), NaNs: 0

# %% [markdown]
# ### 5.3. Modelo SAITS
#
# Si la biblioteca `pypots` está disponible, configuramos y entrenamos un modelo SAITS (Self-Attention based Imputation for Time Series) usando los datos de entrenamiento y validación preprocesados. Luego, usamos el modelo entrenado para imputar los valores faltantes en el conjunto de test.

# %%
# ## 5. Imputación con SAITS (Requiere PyPOTS)

if SAITS is not None:
    print("\nConfigurando y ejecutando imputación con SAITS...")
    # Configurar modelo SAITS
    saits_config = config.SAITS_PARAMS.copy()
    saits_config['n_features'] = processed_data2['n_features'] # Establecer dinámicamente

    saits_model = SAITS(**saits_config)

    # Configurar optimizador, planificador y función de pérdida
    optimizer = Adam(saits_model.model.parameters(), **config.SAITS_OPTIMIZER_PARAMS)
    scheduler = ReduceLROnPlateau(optimizer, **config.SAITS_SCHEDULER_PARAMS)
    loss_func = SmoothL1Loss(**config.SAITS_LOSS_PARAMS)

    # Entrenar el modelo
    # Nota: Podrías querer ajustar epochs/patience para ejecuciones más rápidas
    print("Entrenando modelo SAITS...")
    saits_model.fit(
        train_set=dataset_for_training2,
        val_set=dataset_for_validating2, # Pasar conjunto de validación para early stopping
        )
    print("Entrenamiento de SAITS completo.")

    # Predecir (imputar) en el conjunto de test
    print("Imputando con SAITS en el conjunto de test...")
    saits_prediction = saits_model.predict(dataset_for_testing2)
    imputed_results2['saits'] = saits_prediction["imputation"]
    print(f"Forma imputación SAITS: {imputed_results2['saits'].shape}, NaNs: {np.isnan(imputed_results2['saits']).sum()}")

else:
    print("\nSaltando imputación con SAITS ya que pypots no está instalado.")
# Out:
# 2025-04-08 21:27:25 [INFO]: No given device, using default device: cpu
# 2025-04-08 21:27:25 [INFO]: Model files will be saved to ../results/imputation/saits/20250408_T212725
# 2025-04-08 21:27:25 [INFO]: Tensorboard file will be saved to ../results/imputation/saits/20250408_T212725/tensorboard
# 2025-04-08 21:27:25 [INFO]: Using customized MAE as the training loss function.
# 2025-04-08 21:27:25 [INFO]: Using customized MSE as the validation metric function.
# 2025-04-08 21:27:25 [WARNING]: ‼️ d_model must = n_heads * d_k, it should be divisible by n_heads and the result should be equal to d_k, but got d_model=192, n_heads=4, d_k=32
# 2025-04-08 21:27:25 [WARNING]: ⚠️ d_model is reset to 128 = n_heads (4) * d_k (32)
# 2025-04-08 21:27:25 [INFO]: SAITS initialized with the given hyperparameters, the number of trainable parameters: 1,172,736
# Configurando y ejecutando imputación con SAITS...
# Entrenando modelo SAITS...
# 2025-04-08 21:27:26 [INFO]: Epoch 001 - training loss (MAE): 1.4385, validation MSE: 1.0980
# 2025-04-08 21:27:28 [INFO]: Epoch 002 - training loss (MAE): 1.2283, validation MSE: 0.9240
# 2025-04-08 21:27:30 [INFO]: Epoch 003 - training loss (MAE): 1.0763, validation MSE: 0.8991
# 2025-04-08 21:27:31 [INFO]: Epoch 004 - training loss (MAE): 1.0001, validation MSE: 0.8784
# 2025-04-08 21:27:32 [INFO]: Epoch 005 - training loss (MAE): 0.9548, validation MSE: 0.8816
# 2025-04-08 21:27:33 [INFO]: Epoch 006 - training loss (MAE): 0.9344, validation MSE: 0.8736
# 2025-04-08 21:27:35 [INFO]: Epoch 007 - training loss (MAE): 0.9099, validation MSE: 0.8680
# 2025-04-08 21:27:36 [INFO]: Epoch 008 - training loss (MAE): 0.8999, validation MSE: 0.8602
# 2025-04-08 21:27:38 [INFO]: Epoch 009 - training loss (MAE): 0.8828, validation MSE: 0.8531
# 2025-04-08 21:27:39 [INFO]: Epoch 010 - training loss (MAE): 0.8712, validation MSE: 0.8467
# 2025-04-08 21:27:41 [INFO]: Epoch 011 - training loss (MAE): 0.8574, validation MSE: 0.8402
# 2025-04-08 21:27:42 [INFO]: Epoch 012 - training loss (MAE): 0.8447, validation MSE: 0.8323
# 2025-04-08 21:27:43 [INFO]: Epoch 013 - training loss (MAE): 0.8308, validation MSE: 0.8190
# 2025-04-08 21:27:45 [INFO]: Epoch 014 - training loss (MAE): 0.8143, validation MSE: 0.8073
# 2025-04-08 21:27:46 [INFO]: Epoch 015 - training loss (MAE): 0.7994, validation MSE: 0.7948
# 2025-04-08 21:27:48 [INFO]: Epoch 016 - training loss (MAE): 0.7901, validation MSE: 0.7749
# 2025-04-08 21:27:49 [INFO]: Epoch 017 - training loss (MAE): 0.7797, validation MSE: 0.7552
# 2025-04-08 21:27:51 [INFO]: Epoch 018 - training loss (MAE): 0.7674, validation MSE: 0.7327
# 2025-04-08 21:27:52 [INFO]: Epoch 019 - training loss (MAE): 0.7596, validation MSE: 0.7170
# 2025-04-08 21:27:54 [INFO]: Epoch 020 - training loss (MAE): 0.7471, validation MSE: 0.7043
# 2025-04-08 21:27:55 [INFO]: Epoch 021 - training loss (MAE): 0.7388, validation MSE: 0.6993
# 2025-04-08 21:27:57 [INFO]: Epoch 022 - training loss (MAE): 0.7302, validation MSE: 0.6899
# 2025-04-08 21:27:58 [INFO]: Epoch 023 - training loss (MAE): 0.7213, validation MSE: 0.6827
# 2025-04-08 21:28:00 [INFO]: Epoch 024 - training loss (MAE): 0.7138, validation MSE: 0.6774
# 2025-04-08 21:28:01 [INFO]: Epoch 025 - training loss (MAE): 0.7072, validation MSE: 0.6737
# 2025-04-08 21:28:02 [INFO]: Epoch 026 - training loss (MAE): 0.6974, validation MSE: 0.6668
# 2025-04-08 21:28:03 [INFO]: Epoch 027 - training loss (MAE): 0.6891, validation MSE: 0.6690
# 2025-04-08 21:28:04 [INFO]: Epoch 028 - training loss (MAE): 0.6857, validation MSE: 0.6702
# 2025-04-08 21:28:06 [INFO]: Epoch 029 - training loss (MAE): 0.6752, validation MSE: 0.6657
# 2025-04-08 21:28:08 [INFO]: Epoch 030 - training loss (MAE): 0.6729, validation MSE: 0.6679
# 2025-04-08 21:28:09 [INFO]: Epoch 031 - training loss (MAE): 0.6640, validation MSE: 0.6628
# 2025-04-08 21:28:10 [INFO]: Epoch 032 - training loss (MAE): 0.6615, validation MSE: 0.6659
# 2025-04-08 21:28:12 [INFO]: Epoch 033 - training loss (MAE): 0.6540, validation MSE: 0.6681
# 2025-04-08 21:28:13 [INFO]: Epoch 034 - training loss (MAE): 0.6464, validation MSE: 0.6675
# 2025-04-08 21:28:14 [INFO]: Epoch 035 - training loss (MAE): 0.6411, validation MSE: 0.6681
# 2025-04-08 21:28:16 [INFO]: Epoch 036 - training loss (MAE): 0.6321, validation MSE: 0.6780
# 2025-04-08 21:28:16 [INFO]: Exceeded the training patience. Terminating the training procedure...
# 2025-04-08 21:28:16 [INFO]: Finished training. The best model is from epoch#31.
# 2025-04-08 21:28:16 [INFO]: Saved the model to ../results/imputation/saits/20250408_T212725/SAITS.pypots
# Entrenamiento de SAITS completo.
# Imputando con SAITS en el conjunto de test...
# Forma imputación SAITS: (73, 24, 114), NaNs: 0

# %% [markdown]
# ## 6. Evaluar Resultados de Imputación en Periodo 1
#
# Evaluamos el rendimiento de cada método de imputación utilizando métricas estándar (MAE, MSE, RMSE, MRE) calculadas únicamente sobre los valores que fueron originalmente faltantes (indicados por `indicating_mask`). Comparamos los valores imputados (`y_pred`) con los valores verdaderos originales (`y_true`, correspondientes a `test_X_ori`).

# %%
print("\nEvaluando rendimiento de imputación en el conjunto de test...")

# Usar la función del módulo de evaluación
# Requiere el diccionario de datos preprocesados (para ground truth y máscara)
# y el diccionario de resultados imputados
evaluation_table = ev.evaluate_all_methods(
    processed_data,
    imputed_results,
    methods_to_evaluate=list(imputed_results.keys()) # Evaluar todos los métodos calculados
)

evaluation_table.T
# Out:
# Evaluando rendimiento de imputación en el conjunto de test...
#
# Calculando métricas para: median
#
# Calculando métricas para: mean
#
# Calculando métricas para: linear
# Ajustando datos verdaderos y máscara para ffill_bfill debido a columnas eliminadas.
#
# Calculando métricas para: ffill_bfill
# Ajustando datos verdaderos y máscara para bfill_ffill debido a columnas eliminadas.
#
# Calculando métricas para: bfill_ffill
#
# Calculando métricas para: transformer
#
# Calculando métricas para: saits
# Method  Median    Mean  Linear  Ffill Bfill  Bfill Ffill  Transformer   Saits
# RMSE    0.6558  0.5850  0.7259       0.8094       0.7897       0.5887  0.4792
# MSE     0.4300  0.3423  0.5270       0.6551       0.6237       0.3466  0.2296
# MAE     0.4186  0.3553  0.5462       0.6113       0.5876       0.4767  0.3454
# MRE     2.8744  2.4401  3.7508       3.9935       3.8385       3.2732  2.3718

# %% [markdown]
# ### 6.1 Resumen de la Tabla de Métricas de Imputación/Predicción
#
# Esta tabla compara el rendimiento de diferentes métodos de imputación o predicción utilizando cuatro métricas de error: RMSE (Raíz del Error Cuadrático Medio), MSE (Error Cuadrático Medio), MAE (Error Absoluto Medio) y MRE (Error Relativo Medio). Valores más bajos en todas las métricas indican un mejor rendimiento.
#
# En resumen, los métodos basados en modelos complejos, Transformer y Saits, demuestran el mejor rendimiento general, con valores significativamente más bajos en todas las métricas en comparación con los métodos más simples.
#
# La Media se destaca como un método de referencia sorprendentemente efectivo, superando a la Mediana y a los métodos de interpolación lineal y de relleno simple (Ffill y Bfill). Esto sugiere que para este conjunto de datos, la media proporciona una buena estimación central.
#
# Los métodos de relleno simple, Ffill (relleno hacia adelante) y Bfill (relleno hacia atrás), muestran el peor rendimiento, indicando que son enfoques ingenuos y menos efectivos para este tipo de datos.
#
# El método Lineal se sitúa en un punto intermedio, mejor que los rellenos simples pero peor que la Media, la Mediana y los modelos Transformer y Saits.

# %% [markdown]
# ## 6. Evaluar Resultados de Imputación en Periodo 2
#
# Evaluamos el rendimiento de cada método de imputación utilizando métricas estándar (MAE, MSE, RMSE, MRE) calculadas únicamente sobre los valores que fueron originalmente faltantes (indicados por `indicating_mask`). Comparamos los valores imputados (`y_pred`) con los valores verdaderos originales (`y_true`, correspondientes a `test_X_ori`).

# %%
print("\nEvaluando rendimiento de imputación en el conjunto de test...")

# Usar la función del módulo de evaluación
# Requiere el diccionario de datos preprocesados (para ground truth y máscara)
# y el diccionario de resultados imputados
evaluation_table2 = ev.evaluate_all_methods(
    processed_data2,
    imputed_results2,
    methods_to_evaluate=list(imputed_results2.keys()) # Evaluar todos los métodos calculados
)

evaluation_table2.T
# Out:
# Evaluando rendimiento de imputación en el conjunto de test...
#
# Calculando métricas para: median
#
# Calculando métricas para: mean
#
# Calculando métricas para: linear
# Ajustando datos verdaderos y máscara para ffill_bfill debido a columnas eliminadas.
#
# Calculando métricas para: ffill_bfill
# Ajustando datos verdaderos y máscara para bfill_ffill debido a columnas eliminadas.
#
# Calculando métricas para: bfill_ffill
#
# Calculando métricas para: transformer
#
# Calculando métricas para: saits
# Method  Median    Mean  Linear  Ffill Bfill  Bfill Ffill  Transformer   Saits
# RMSE    0.7259  0.6893  0.8334       0.8751       0.8769       0.4146  0.4046
# MSE     0.5269  0.4751  0.6945       0.7658       0.7689       0.1719  0.1637
# MAE     0.5036  0.4714  0.6470       0.6690       0.6817       0.2667  0.2658
# MRE     4.3371  4.0601  5.5721       5.7885       5.8980       2.2966  2.2892

# %% [markdown]
# ## 7. Visualizar Resultados (Ejemplo: NO2)
#
# Visualizamos los resultados de la imputación para una característica específica (NO2) en el periodo de test. Comparamos la serie original (escalada, con valores faltantes), la serie verdadera (`Ground Truth`, escalada, antes de introducir valores faltantes artificiales) y las series imputadas por diferentes métodos. Los puntos rojos indican los valores que fueron artificialmente marcados como faltantes y luego imputados.

# %%
# ## 7. Visualizar Resultados (Ejemplo: NO2)

# Seleccionar una característica para visualizar
feature_to_plot = "NO2"
if feature_to_plot not in config.FEATURE_COLUMNS:
    print(f"Advertencia: '{feature_to_plot}' no está en las columnas de características. Saltando gráfico.")
else:
    feature_index = config.FEATURE_COLUMNS.index(feature_to_plot)

    # Obtener datos originales de test (antes de ventanear, potencialmente sin escalar para interpretabilidad)
    test_df_original = periodo_1_raw.loc[config.TEST_START_DATE:config.TEST_END_DATE]#[feature_to_plot]
    # Ajustar por fecha final exclusiva si es necesario basado en cómo se hizo el split
    # Ejemplo: si TEST_END_DATE = "2023-03-15", loc incluirá hasta "2023-03-14 23:00:00"
    # pero si los datos preprocesados excluyen el último día, ajustar aquí:
    # test_df_original = test_df_original.iloc[:-1] # O ajustar basado en el número exacto de filas


    # Reestructurar datos imputados a DataFrame para facilitar la visualización
    # Usar el scaler para invertir la transformación si se desea escala original
    scaler = processed_data['scaler']
    test_index_full = processed_data['test_index'] # Índice antes de ventanear

    plt.figure(figsize=(15, 8))
    plt.title(f"Comparación de Imputación para {feature_to_plot} (Periodo Test)")
    plt.xlabel("Tiempo")
    plt.ylabel(f"{feature_to_plot} (Escalado)") # Etiquetar como escalado

    # Graficar datos originales con valores faltantes (escalados)
    # Asegurarse que test_df_original tenga las columnas correctas antes de transformar
    original_scaled_test_data = scaler.transform(test_df_original[config.FEATURE_COLUMNS])
    original_series_scaled = pd.Series(original_scaled_test_data[:, feature_index], index=test_df_original.index)
    plt.plot(original_series_scaled.index, original_series_scaled.values, label='Original (Escalado, con NaNs)', color='gray', alpha=0.7, linestyle=':')

    # Graficar Ground Truth (donde se introdujo la ausencia) - escalado
    # Necesitamos reconstruir la serie temporal ground truth desde test_X_ori
    # Usar la utilidad de reestructuración
    ground_truth_df = utils.reshape_imputed_to_df(
         dataset_for_testing['X_ori'], # Datos escalados ANTES de enmascarar
         test_index_full, # Usar el índice antes de ventanear
         config.FEATURE_COLUMNS,
         config.N_STEPS
         )

    # Extraer el rango de tiempo relevante para graficar
    # Asegurarse que los índices coincidan con original_series_scaled
    plot_start = original_series_scaled.index.min()
    plot_end = original_series_scaled.index.max()

    # Verificar si las fechas están en ground_truth_df
    if plot_start in ground_truth_df.index and plot_end in ground_truth_df.index:
        ground_truth_series = ground_truth_df.loc[plot_start:plot_end, feature_to_plot]

        # Marcar los puntos que eran originalmente faltantes (usando la máscara)
        mask_flat = dataset_for_testing['indicating_mask'].reshape(-1, processed_data['n_features'])
        # Crear índice para la máscara aplanada que coincida con ground_truth_df
        mask_index = ground_truth_df.index[:len(mask_flat)] # Asegurar que no exceda la longitud
        mask_series = pd.Series(mask_flat[:, feature_index], index=mask_index).loc[plot_start:plot_end]

        missing_indices = mask_series[mask_series == 1].index

        plt.plot(ground_truth_series.index, ground_truth_series.values, label='Ground Truth (Escalado)', color='black', linewidth=1.5)
        # Asegurar que los missing_indices existen en ground_truth_series antes de graficar
        valid_missing_indices = missing_indices.intersection(ground_truth_series.index)
        plt.scatter(valid_missing_indices, ground_truth_series.loc[valid_missing_indices], color='red', s=15, label='Puntos Imputados (Verdad)', zorder=5)

    else:
        print("Advertencia: Rango de fechas de test original no encontrado completamente en datos ground truth reconstruidos. Saltando gráfico de ground truth.")
        ground_truth_series = None # Para evitar errores posteriores


    # Graficar resultados imputados
    plot_methods = ['median', 'linear', 'saits'] # Elegir métodos a graficar
    colors = ['blue', 'green', 'orange', 'purple', 'brown']
    linestyles = ['--', '-.', ':']

    for i, method in enumerate(plot_methods):
        if method in imputed_results:
            # Verificar si las columnas necesitan alineación (ej., ffill/bfill)
            current_cols = config.FEATURE_COLUMNS
            current_feature_index = feature_index
            y_pred = imputed_results[method]

            # Ajustar columnas y índice de característica si se eliminaron columnas para este método
            if method in ['ffill_bfill', 'bfill_ffill'] and cols_to_drop_indices:
                 current_cols = [col for idx, col in enumerate(config.FEATURE_COLUMNS) if idx not in cols_to_drop_indices]
                 if feature_to_plot in current_cols:
                     current_feature_index = current_cols.index(feature_to_plot)
                 else:
                     print(f"Saltando gráfico para {method} - {feature_to_plot} fue eliminada.")
                     continue # Saltar gráfico de este método para esta característica
                 # y_pred ya está ajustado

            # Reestructurar la predicción
            imputed_df = utils.reshape_imputed_to_df(
                 y_pred,
                 test_index_full, # Usar índice antes de ventanear
                 current_cols, # Usar columnas potencialmente reducidas
                 config.N_STEPS
            )

            # Extraer la serie y graficar en el rango correcto
            if plot_start in imputed_df.index and plot_end in imputed_df.index:
                imputed_series = imputed_df.loc[plot_start:plot_end, feature_to_plot]
                plt.plot(imputed_series.index, imputed_series.values,
                         label=f'{method.title()} Imputado',
                         color=colors[i % len(colors)],
                         linestyle=linestyles[i % len(linestyles)],
                         alpha=0.8)
            else:
                 print(f"Advertencia: Rango de fechas de test original no encontrado completamente en datos imputados ({method}). Saltando gráfico parcial.")


    plt.legend()
    plt.grid(True, linestyle='--', alpha=0.6)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## 8. Opcional: Guardar Resultados
#
# Podemos guardar la tabla de evaluación y/o los datos imputados (por ejemplo, los resultados de SAITS) en archivos CSV si es necesario para análisis posteriores o informes.

# %%
# Guardar la tabla de evaluación
# evaluation_table.to_csv(f"{config.RESULTS_DIR}/imputation_evaluation.csv")
# print(f"Resultados de evaluación guardados en {config.RESULTS_DIR}/imputation_evaluation.csv")

# Guardar datos imputados (ej. resultado de SAITS) si es necesario
# saits_imputed_df = utils.reshape_imputed_to_df(...) # Necesitas reconstruir el DataFrame
# saits_imputed_df.to_csv(...)

print("\nFlujo de trabajo finalizado.")
# Out:
# Flujo de trabajo finalizado.
