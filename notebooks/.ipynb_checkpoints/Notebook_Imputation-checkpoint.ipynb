# %% [markdown]
# # Flujo de Trabajo de Imputación para Pampaneira (Refactorizado)
#
# Este cuaderno ejecuta el pipeline refactorizado para imputar valores faltantes en el conjunto de datos de Pampaneira.

# %% [markdown]
# ## 1. Configuración e Importaciones
#
# Aseguramos que la raíz del proyecto esté en el path de Python. Ajusta la profundidad del path ('../') según sea necesario dependiendo de dónde se encuentre este cuaderno en relación con la raíz del proyecto.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
import os
import sys
from sklearn.preprocessing import StandardScaler # Mantener para uso directo/verificación potencial
from torch.optim import Adam
from torch.optim.lr_scheduler import ReduceLROnPlateau
from torch.nn import SmoothL1Loss

# Asegurar que la raíz del proyecto esté en el Python path
# Ajusta la profundidad del path ('../') según sea necesario
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %% [markdown]
# Importamos los módulos refactorizados del proyecto:

# %%
# Importar módulos refactorizados
from pampaneira_imputation import config
from pampaneira_imputation import data_loader as dl
from pampaneira_imputation import data_preprocessor as dp
from pampaneira_imputation import imputation_methods as im
from pampaneira_imputation import evaluation as ev
from pampaneira_imputation import utils
# Out:
# ████████╗██╗███╗   ███╗███████╗    ███████╗███████╗██████╗ ██╗███████╗███████╗    █████╗ ██╗
# ╚══██╔══╝██║████╗ ████║██╔════╝    ██╔════╝██╔════╝██╔══██╗██║██╔════╝██╔════╝   ██╔══██╗██║
#    ██║   ██║██╔████╔██║█████╗█████╗███████╗█████╗  ██████╔╝██║█████╗  ███████╗   ███████║██║
#    ██║   ██║██║╚██╔╝██║██╔══╝╚════╝╚════██║██╔══╝  ██╔══██╗██║██╔══╝  ╚════██║   ██╔══██║██║
#    ██║   ██║██║ ╚═╝ ██║███████╗    ███████║███████╗██║  ██║██║███████╗███████║██╗██║  ██║██║
#    ╚═╝   ╚═╝╚═╝     ╚═╝╚══════╝    ╚══════╝╚══════╝╚═╝  ╚═╝╚═╝╚══════╝╚══════╝╚═╝╚═╝  ╚═╝╚═╝
# ai4ts v0.0.3 - building AI for unified time-series analysis, https://time-series.ai

# %% [markdown]
# Importamos SAITS por separado (asumiendo que pypots está instalado):

# %%
# Importar SAITS por separado (asumiendo que pypots está instalado)
try:
    from pypots.imputation import SAITS, Transformer
except ImportError:
    print("Advertencia: No se encontró la librería pypots. La imputación con SAITS no estará disponible.")
    SAITS = None # Definir como None si no está disponible

# %% [markdown]
# Configuramos pandas y la visualización:

# %%
# Configurar pandas y visualización
pd.options.mode.chained_assignment = None
pd.reset_option('display.max_rows')
pd.reset_option('display.max_columns')
plt.rcParams["figure.figsize"] = [12, 4]
warnings.filterwarnings("ignore") # Usar con precaución

# %% [markdown]
# ## 2. Carga de Datos
#
# Cargamos los datos de la intersección (filtrados para PAM_2):

# %%
# Cargar datos de intersección (filtrados para PAM_2)
try:
    df_int_raw = dl.load_intersection_data(
        filepath=config.INTERSECTION_FILE,
        target_truck_pos=config.TARGET_TRUCK_POS
    )
    print(f"Forma de los datos de intersección cargados: {df_int_raw.shape}")
    print(f"Rango de fechas: {df_int_raw[config.DATE_COL].min()} a {df_int_raw[config.DATE_COL].max()}")
    # display(df_int_raw.head()) # Opcional: mostrar encabezado
except Exception as e:
    print(f"Error al cargar los datos de intersección: {e}")
    # Detener ejecución o manejar el error apropiadamente
    raise
# Out:
# Forma de los datos de intersección cargados: (1335, 115)
# Rango de fechas: 2023-01-17 17:00:00+00:00 a 2023-06-27 00:00:00+00:00

# %% [markdown]
# ## 3. Preprocesamiento de Datos

# %% [markdown]
# ### 3.1 Rellenar Marcas de Tiempo Faltantes (Dentro de Periodos Definidos)
#
# Creamos el rango de fechas completo que cubre ambos periodos conocidos de datos del camión:

# %%
df_int_reindexed = dp.fill_missing_timestamps(df_int_raw, config.PERIOD_1_START, config.PERIOD_2_END)
print(f"Forma después de reindexar a periodos combinados: {df_int_reindexed.shape}")
# Out:
# Forma después de reindexar a periodos combinados: (3840, 114)

# %% [markdown]
# Verificamos los NaNs introducidos por la reindexación:

# %%
# Verificar los NaNs introducidos
print(f"NaNs introducidos por reindexación: {df_int_reindexed.isnull().sum().sum()}")
# Out:
# NaNs introducidos por reindexación: 288216

# %%
df_int_reindexed
# Out:
#                            vehicles_PAM_1_OUT  \
# 2023-01-18 00:00:00+00:00                 0.0
# 2023-01-18 01:00:00+00:00                 NaN
# 2023-01-18 02:00:00+00:00                 NaN
# 2023-01-18 03:00:00+00:00                 NaN
# 2023-01-18 04:00:00+00:00                 NaN
# ...                                       ...
# 2023-06-26 19:00:00+00:00                 7.0
# 2023-06-26 20:00:00+00:00                 3.0
# 2023-06-26 21:00:00+00:00                 0.0
# 2023-06-26 22:00:00+00:00                 0.0
# 2023-06-26 23:00:00+00:00                 NaN
#
#                            vehicles_PAM_1_OUT_Zona_Granada  \
# 2023-01-18 00:00:00+00:00                              0.0
# 2023-01-18 01:00:00+00:00                              NaN
# 2023-01-18 02:00:00+00:00                              NaN
# 2023-01-18 03:00:00+00:00                              NaN
# 2023-01-18 04:00:00+00:00                              NaN
# ...                                                    ...
# 2023-06-26 19:00:00+00:00                              5.0
# 2023-06-26 20:00:00+00:00                              3.0
# 2023-06-26 21:00:00+00:00                              0.0
# 2023-06-26 22:00:00+00:00                              0.0
# 2023-06-26 23:00:00+00:00                              NaN
#
#                            vehicles_PAM_1_OUT_Zona_Catalunia_y_Otras  \
# 2023-01-18 00:00:00+00:00                                        0.0
# 2023-01-18 01:00:00+00:00                                        NaN
# 2023-01-18 02:00:00+00:00                                        NaN
# 2023-01-18 03:00:00+00:00                                        NaN
# 2023-01-18 04:00:00+00:00                                        NaN
# ...                                                              ...
# 2023-06-26 19:00:00+00:00                                        1.0
# 2023-06-26 20:00:00+00:00                                        0.0
# 2023-06-26 21:00:00+00:00                                        0.0
# 2023-06-26 22:00:00+00:00                                        0.0
# 2023-06-26 23:00:00+00:00                                        NaN
#
#                            vehicles_PAM_1_OUT_Zona_Andalucia_no_GR  \
# 2023-01-18 00:00:00+00:00                                      0.0
# 2023-01-18 01:00:00+00:00                                      NaN
# 2023-01-18 02:00:00+00:00                                      NaN
# 2023-01-18 03:00:00+00:00                                      NaN
# 2023-01-18 04:00:00+00:00                                      NaN
# ...                                                            ...
# 2023-06-26 19:00:00+00:00                                      0.0
# 2023-06-26 20:00:00+00:00                                      0.0
# 2023-06-26 21:00:00+00:00                                      0.0
# 2023-06-26 22:00:00+00:00                                      0.0
# 2023-06-26 23:00:00+00:00                                      NaN
#
#                            vehicles_PAM_1_OUT_Extranjero  \
# 2023-01-18 00:00:00+00:00                            0.0
# 2023-01-18 01:00:00+00:00                            NaN
# 2023-01-18 02:00:00+00:00                            NaN
# 2023-01-18 03:00:00+00:00                            NaN
# 2023-01-18 04:00:00+00:00                            NaN
# ...                                                  ...
# 2023-06-26 19:00:00+00:00                            1.0
# 2023-06-26 20:00:00+00:00                            0.0
# 2023-06-26 21:00:00+00:00                            0.0
# 2023-06-26 22:00:00+00:00                            0.0
# 2023-06-26 23:00:00+00:00                            NaN
#
#                            vehicles_PAM_1_OUT_Zona_Comunidad_de_Madrid  \
# 2023-01-18 00:00:00+00:00                                          0.0
# 2023-01-18 01:00:00+00:00                                          NaN
# 2023-01-18 02:00:00+00:00                                          NaN
# 2023-01-18 03:00:00+00:00                                          NaN
# 2023-01-18 04:00:00+00:00                                          NaN
# ...                                                                ...
# 2023-06-26 19:00:00+00:00                                          0.0
# 2023-06-26 20:00:00+00:00                                          0.0
# 2023-06-26 21:00:00+00:00                                          0.0
# 2023-06-26 22:00:00+00:00                                          0.0
# 2023-06-26 23:00:00+00:00                                          NaN
#
#                            vehicles_PAM_1_OUT_Zona_Extremadura_y_Otras  \
# 2023-01-18 00:00:00+00:00                                          0.0
# 2023-01-18 01:00:00+00:00                                          NaN
# 2023-01-18 02:00:00+00:00                                          NaN
# 2023-01-18 03:00:00+00:00                                          NaN
# 2023-01-18 04:00:00+00:00                                          NaN
# ...                                                                ...
# 2023-06-26 19:00:00+00:00                                          0.0
# 2023-06-26 20:00:00+00:00                                          0.0
# 2023-06-26 21:00:00+00:00                                          0.0
# 2023-06-26 22:00:00+00:00                                          0.0
# 2023-06-26 23:00:00+00:00                                          NaN
#
#                            vehicles_PAM_1_OUT_Zona_Otras  \
# 2023-01-18 00:00:00+00:00                            0.0
# 2023-01-18 01:00:00+00:00                            NaN
# 2023-01-18 02:00:00+00:00                            NaN
# 2023-01-18 03:00:00+00:00                            NaN
# 2023-01-18 04:00:00+00:00                            NaN
# ...                                                  ...
# 2023-06-26 19:00:00+00:00                            0.0
# 2023-06-26 20:00:00+00:00                            0.0
# 2023-06-26 21:00:00+00:00                            0.0
# 2023-06-26 22:00:00+00:00                            0.0
# 2023-06-26 23:00:00+00:00                            NaN
#
#                            vehicles_PAM_1_OUT_5_seats  \
# 2023-01-18 00:00:00+00:00                         0.0
# 2023-01-18 01:00:00+00:00                         NaN
# 2023-01-18 02:00:00+00:00                         NaN
# 2023-01-18 03:00:00+00:00                         NaN
# 2023-01-18 04:00:00+00:00                         NaN
# ...                                               ...
# 2023-06-26 19:00:00+00:00                         5.0
# 2023-06-26 20:00:00+00:00                         3.0
# 2023-06-26 21:00:00+00:00                         0.0
# 2023-06-26 22:00:00+00:00                         0.0
# 2023-06-26 23:00:00+00:00                         NaN
#
#                            vehicles_PAM_1_OUT_+5_seats  ...   NO     O3  PM10  \
# 2023-01-18 00:00:00+00:00                          0.0  ...  0.1    NaN   0.0
# 2023-01-18 01:00:00+00:00                          NaN  ...  NaN    NaN   NaN
# 2023-01-18 02:00:00+00:00                          NaN  ...  NaN    NaN   NaN
# 2023-01-18 03:00:00+00:00                          NaN  ...  NaN    NaN   NaN
# 2023-01-18 04:00:00+00:00                          NaN  ...  NaN    NaN   NaN
# ...                                                ...  ...  ...    ...   ...
# 2023-06-26 19:00:00+00:00                          0.0  ...  1.5  111.4   7.8
# 2023-06-26 20:00:00+00:00                          0.0  ...  0.4   99.6  23.0
# 2023-06-26 21:00:00+00:00                          0.0  ...  0.1   78.8  11.3
# 2023-06-26 22:00:00+00:00                          0.0  ...  0.1   77.4   1.9
# 2023-06-26 23:00:00+00:00                          NaN  ...  NaN    NaN   NaN
#
#                            eBC_ff  eBC_bb  TEMP    RH    WS      WD   PRES
# 2023-01-18 00:00:00+00:00     NaN     NaN   6.6  52.9  3.89  114.50  878.0
# 2023-01-18 01:00:00+00:00     NaN     NaN   NaN   NaN   NaN     NaN    NaN
# 2023-01-18 02:00:00+00:00     NaN     NaN   NaN   NaN   NaN     NaN    NaN
# 2023-01-18 03:00:00+00:00     NaN     NaN   NaN   NaN   NaN     NaN    NaN
# 2023-01-18 04:00:00+00:00     NaN     NaN   NaN   NaN   NaN     NaN    NaN
# ...                           ...     ...   ...   ...   ...     ...    ...
# 2023-06-26 19:00:00+00:00     0.6     0.1  31.4  21.5  1.12  246.34  893.3
# 2023-06-26 20:00:00+00:00     0.3     0.1  28.8  26.0  0.81    7.46  893.6
# 2023-06-26 21:00:00+00:00     0.4     0.1  25.7  29.5  1.06  129.23  893.9
# 2023-06-26 22:00:00+00:00     0.2     0.1  24.7  27.9  1.25  133.45  894.3
# 2023-06-26 23:00:00+00:00     NaN     NaN   NaN   NaN   NaN     NaN    NaN
#
# [3840 rows x 114 columns]

# %% [markdown]
# ### 3.2 Dividir en Periodos
#
# Establecemos la columna de fecha como índice y dividimos el DataFrame en los dos periodos definidos en la configuración.

# %%
# Dividir en Periodos
periodo_1_raw, periodo_2_raw = dp.split_by_period(df_int_reindexed)

print(f"Forma del Periodo 1: {periodo_1_raw.shape}")
print(f"Forma del Periodo 2: {periodo_2_raw.shape}")
# Out:
# Forma del Periodo 1: (1332, 114)
# Forma del Periodo 2: (480, 114)

# %% [markdown]
# ### 3.4 Dividir, Escalar, Ventanear y Crear Ausencia para el Periodo 1
#
# Esta función ahora maneja la división train/val/test, el escalado (normalización Z-score), la creación de ventanas deslizantes (`sliding window`) y la introducción artificial de valores faltantes (`missingness`) según la configuración.

# %% [markdown]
# Para dividir el periodo del 18 de enero de 2023 al 14 de marzo de 2023 en entrenamiento, validación y prueba siguiendo un esquema análogo al del Beijing Multi-Site Air-Quality Dataset, vamos a asignar los datos de manera similar a cómo se hizo en ese conjunto.
#
# El esquema original divide los datos en tres partes:
#
# - **Fase de entrenamiento (80% del dataset):** Primeros 45 días
#    - **Training:** 80% de los 45 días: 36 días
#    - **Validación** 20% restante de los 45 días: 9 días.
# - **Prueba (20% del dataset):** 20% del dataset:  11 días.
#
# El periodo de tiempo es del 18 de enero de 2023 al 14 de marzo de 2023. **hay 56 días.**
#
# - **Conjunto de entrenamiento: 18 de enero de 2023 - 21 de febrero de 2023 (36 días)**
# - **Conjunto de validación: 22 de febrero de 2023 - 2 de marzo de 2023 (9 días)**.
# - **Conjunto de prueba: 3 de marzo de 2023 - 14 de marzo de 2023) (12 días)**

# %%
# Dividir, Escalar, Ventanear y Crear Ausencia para el Periodo 1
# Esta función ahora maneja la división train/val/test, escalado, ventaneo y creación de valores faltantes
try:
    processed_data = dp.preprocess_for_imputation(
        periodo_1_raw,
        feature_cols=config.FEATURE_COLUMNS,
        n_steps=config.N_STEPS,
        missing_rate=config.MISSING_RATE,
        missing_pattern=config.MISSING_PATTERN
        # Añadir otros argumentos de missingness si es necesario, ej., min_missing_len=...
    )
    print("Preprocesamiento completo. Estructura de datos:")
    for key, value in processed_data.items():
        if isinstance(value, np.ndarray):
            print(f"- {key}: forma {value.shape}")
        elif isinstance(value, pd.DataFrame):
            print(f"- {key}: forma {value.shape}")
        elif isinstance(value, pd.Index):
             print(f"- {key}: longitud {len(value)}")
        elif not isinstance(value, StandardScaler): # No imprimir detalles del scaler
            print(f"- {key}: {value}")

except ValueError as e:
    print(f"Error durante el preprocesamiento: {e}")
    raise
# Out:
# Introduciendo 10.0% de datos faltantes con patrón 'point'...
# Preprocesamiento completo. Estructura de datos:
# - n_steps: 24
# - n_features: 114
# - train_index: longitud 840
# - val_index: longitud 216
# - test_index: longitud 276
# - train_X_ori: forma (817, 24, 114)
# - val_X_ori: forma (193, 24, 114)
# - test_X_ori: forma (253, 24, 114)
# - train_X: forma (817, 24, 114)
# - val_X: forma (193, 24, 114)
# - test_X: forma (253, 24, 114)
# - train_X_df: forma (840, 114)
# - val_X_df: forma (216, 114)
# - test_X_df: forma (276, 114)
# - train_missing_mask: forma (817, 24, 114)
# - val_missing_mask: forma (193, 24, 114)
# - test_missing_mask: forma (253, 24, 114)
# - train_indicating_mask: forma (817, 24, 114)
# - val_indicating_mask: forma (193, 24, 114)
# - test_indicating_mask: forma (253, 24, 114)
# - n_train_samples: 817
# - n_val_samples: 193
# - n_test_samples: 253

# %% [markdown]
# Preparamos los conjuntos de datos para PyPOTS (u otras bibliotecas) si es necesario:

# %%
# Preparar datasets para PyPOTS (u otras bibliotecas) si es necesario
dataset_for_training = {"X": processed_data['train_X']}
dataset_for_validating = {"X": processed_data['val_X'], "X_ori": processed_data['val_X_ori']}
# Nota: La validación en PyPOTS usualmente necesita X_ori para calcular la pérdida sobre los valores originales
# antes del enmascaramiento, pero nuestra evaluación calcula métricas en el conjunto de test usando test_X_ori

dataset_for_testing = {
    "X": processed_data['test_X'], # Datos con NaNs para la entrada del modelo de imputación
    "X_ori": processed_data['test_X_ori'], # Datos originales (escalados) antes de enmascarar
    "indicating_mask": processed_data['test_indicating_mask'] # Máscara de los NaNs introducidos
}

# %% [markdown]
# ### 3.4 Dividir, Escalar, Ventanear y Crear Ausencia para el Periodo 2
#
# Esta función ahora maneja la división train/val/test, el escalado (normalización Z-score), la creación de ventanas deslizantes (`sliding window`) y la introducción artificial de valores faltantes (`missingness`) según la configuración.

# %%
periodo_2_raw
# Out:
#                            vehicles_PAM_1_OUT  \
# 2023-06-07 00:00:00+00:00                 NaN
# 2023-06-07 01:00:00+00:00                 0.0
# 2023-06-07 02:00:00+00:00                 NaN
# 2023-06-07 03:00:00+00:00                 NaN
# 2023-06-07 04:00:00+00:00                 NaN
# ...                                       ...
# 2023-06-26 19:00:00+00:00                 7.0
# 2023-06-26 20:00:00+00:00                 3.0
# 2023-06-26 21:00:00+00:00                 0.0
# 2023-06-26 22:00:00+00:00                 0.0
# 2023-06-26 23:00:00+00:00                 NaN
#
#                            vehicles_PAM_1_OUT_Zona_Granada  \
# 2023-06-07 00:00:00+00:00                              NaN
# 2023-06-07 01:00:00+00:00                              0.0
# 2023-06-07 02:00:00+00:00                              NaN
# 2023-06-07 03:00:00+00:00                              NaN
# 2023-06-07 04:00:00+00:00                              NaN
# ...                                                    ...
# 2023-06-26 19:00:00+00:00                              5.0
# 2023-06-26 20:00:00+00:00                              3.0
# 2023-06-26 21:00:00+00:00                              0.0
# 2023-06-26 22:00:00+00:00                              0.0
# 2023-06-26 23:00:00+00:00                              NaN
#
#                            vehicles_PAM_1_OUT_Zona_Catalunia_y_Otras  \
# 2023-06-07 00:00:00+00:00                                        NaN
# 2023-06-07 01:00:00+00:00                                        0.0
# 2023-06-07 02:00:00+00:00                                        NaN
# 2023-06-07 03:00:00+00:00                                        NaN
# 2023-06-07 04:00:00+00:00                                        NaN
# ...                                                              ...
# 2023-06-26 19:00:00+00:00                                        1.0
# 2023-06-26 20:00:00+00:00                                        0.0
# 2023-06-26 21:00:00+00:00                                        0.0
# 2023-06-26 22:00:00+00:00                                        0.0
# 2023-06-26 23:00:00+00:00                                        NaN
#
#                            vehicles_PAM_1_OUT_Zona_Andalucia_no_GR  \
# 2023-06-07 00:00:00+00:00                                      NaN
# 2023-06-07 01:00:00+00:00                                      0.0
# 2023-06-07 02:00:00+00:00                                      NaN
# 2023-06-07 03:00:00+00:00                                      NaN
# 2023-06-07 04:00:00+00:00                                      NaN
# ...                                                            ...
# 2023-06-26 19:00:00+00:00                                      0.0
# 2023-06-26 20:00:00+00:00                                      0.0
# 2023-06-26 21:00:00+00:00                                      0.0
# 2023-06-26 22:00:00+00:00                                      0.0
# 2023-06-26 23:00:00+00:00                                      NaN
#
#                            vehicles_PAM_1_OUT_Extranjero  \
# 2023-06-07 00:00:00+00:00                            NaN
# 2023-06-07 01:00:00+00:00                            0.0
# 2023-06-07 02:00:00+00:00                            NaN
# 2023-06-07 03:00:00+00:00                            NaN
# 2023-06-07 04:00:00+00:00                            NaN
# ...                                                  ...
# 2023-06-26 19:00:00+00:00                            1.0
# 2023-06-26 20:00:00+00:00                            0.0
# 2023-06-26 21:00:00+00:00                            0.0
# 2023-06-26 22:00:00+00:00                            0.0
# 2023-06-26 23:00:00+00:00                            NaN
#
#                            vehicles_PAM_1_OUT_Zona_Comunidad_de_Madrid  \
# 2023-06-07 00:00:00+00:00                                          NaN
# 2023-06-07 01:00:00+00:00                                          0.0
# 2023-06-07 02:00:00+00:00                                          NaN
# 2023-06-07 03:00:00+00:00                                          NaN
# 2023-06-07 04:00:00+00:00                                          NaN
# ...                                                                ...
# 2023-06-26 19:00:00+00:00                                          0.0
# 2023-06-26 20:00:00+00:00                                          0.0
# 2023-06-26 21:00:00+00:00                                          0.0
# 2023-06-26 22:00:00+00:00                                          0.0
# 2023-06-26 23:00:00+00:00                                          NaN
#
#                            vehicles_PAM_1_OUT_Zona_Extremadura_y_Otras  \
# 2023-06-07 00:00:00+00:00                                          NaN
# 2023-06-07 01:00:00+00:00                                          0.0
# 2023-06-07 02:00:00+00:00                                          NaN
# 2023-06-07 03:00:00+00:00                                          NaN
# 2023-06-07 04:00:00+00:00                                          NaN
# ...                                                                ...
# 2023-06-26 19:00:00+00:00                                          0.0
# 2023-06-26 20:00:00+00:00                                          0.0
# 2023-06-26 21:00:00+00:00                                          0.0
# 2023-06-26 22:00:00+00:00                                          0.0
# 2023-06-26 23:00:00+00:00                                          NaN
#
#                            vehicles_PAM_1_OUT_Zona_Otras  \
# 2023-06-07 00:00:00+00:00                            NaN
# 2023-06-07 01:00:00+00:00                            0.0
# 2023-06-07 02:00:00+00:00                            NaN
# 2023-06-07 03:00:00+00:00                            NaN
# 2023-06-07 04:00:00+00:00                            NaN
# ...                                                  ...
# 2023-06-26 19:00:00+00:00                            0.0
# 2023-06-26 20:00:00+00:00                            0.0
# 2023-06-26 21:00:00+00:00                            0.0
# 2023-06-26 22:00:00+00:00                            0.0
# 2023-06-26 23:00:00+00:00                            NaN
#
#                            vehicles_PAM_1_OUT_5_seats  \
# 2023-06-07 00:00:00+00:00                         NaN
# 2023-06-07 01:00:00+00:00                         0.0
# 2023-06-07 02:00:00+00:00                         NaN
# 2023-06-07 03:00:00+00:00                         NaN
# 2023-06-07 04:00:00+00:00                         NaN
# ...                                               ...
# 2023-06-26 19:00:00+00:00                         5.0
# 2023-06-26 20:00:00+00:00                         3.0
# 2023-06-26 21:00:00+00:00                         0.0
# 2023-06-26 22:00:00+00:00                         0.0
# 2023-06-26 23:00:00+00:00                         NaN
#
#                            vehicles_PAM_1_OUT_+5_seats  ...   NO     O3  PM10  \
# 2023-06-07 00:00:00+00:00                          NaN  ...  NaN    NaN   NaN
# 2023-06-07 01:00:00+00:00                          0.0  ...  0.1   88.3   NaN
# 2023-06-07 02:00:00+00:00                          NaN  ...  NaN    NaN   NaN
# 2023-06-07 03:00:00+00:00                          NaN  ...  NaN    NaN   NaN
# 2023-06-07 04:00:00+00:00                          NaN  ...  NaN    NaN   NaN
# ...                                                ...  ...  ...    ...   ...
# 2023-06-26 19:00:00+00:00                          0.0  ...  1.5  111.4   7.8
# 2023-06-26 20:00:00+00:00                          0.0  ...  0.4   99.6  23.0
# 2023-06-26 21:00:00+00:00                          0.0  ...  0.1   78.8  11.3
# 2023-06-26 22:00:00+00:00                          0.0  ...  0.1   77.4   1.9
# 2023-06-26 23:00:00+00:00                          NaN  ...  NaN    NaN   NaN
#
#                            eBC_ff  eBC_bb  TEMP    RH    WS      WD   PRES
# 2023-06-07 00:00:00+00:00     NaN     NaN   NaN   NaN   NaN     NaN    NaN
# 2023-06-07 01:00:00+00:00     0.1     0.1  16.7  68.5  2.08  116.29  887.5
# 2023-06-07 02:00:00+00:00     NaN     NaN   NaN   NaN   NaN     NaN    NaN
# 2023-06-07 03:00:00+00:00     NaN     NaN   NaN   NaN   NaN     NaN    NaN
# 2023-06-07 04:00:00+00:00     NaN     NaN   NaN   NaN   NaN     NaN    NaN
# ...                           ...     ...   ...   ...   ...     ...    ...
# 2023-06-26 19:00:00+00:00     0.6     0.1  31.4  21.5  1.12  246.34  893.3
# 2023-06-26 20:00:00+00:00     0.3     0.1  28.8  26.0  0.81    7.46  893.6
# 2023-06-26 21:00:00+00:00     0.4     0.1  25.7  29.5  1.06  129.23  893.9
# 2023-06-26 22:00:00+00:00     0.2     0.1  24.7  27.9  1.25  133.45  894.3
# 2023-06-26 23:00:00+00:00     NaN     NaN   NaN   NaN   NaN     NaN    NaN
#
# [480 rows x 114 columns]

# %% [markdown]
# ### Fechas de división del periodo 2 (20 días)

# %% [markdown]
# - 80% del dataset Fase de entrenamiento: 16 días
#     - **Training:** 80% de 16: **13 días** (2023-06-07 al 2023-06-19)
#     - **Validación:** 20% de 16: **3 días** (2023-06-20 al 2023-06-22)
# - 20% del dataset **Testing**: **4 días** (2023-06-23 al 2023-06-26)

# %%
# Dividir, Escalar, Ventanear y Crear Ausencia para el Periodo 1
# Esta función ahora maneja la división train/val/test, escalado, ventaneo y creación de valores faltantes
try:
    processed_data2 = dp.preprocess_for_imputation(
        periodo_2_raw,
        feature_cols=config.FEATURE_COLUMNS,
        n_steps=config.N_STEPS,
        missing_rate=config.MISSING_RATE,
        missing_pattern=config.MISSING_PATTERN,
        train_starn=config.TRAIN_2_START_DATE,
        train_end=config.TRAIN_2_END_DATE,
        val_start=config.VAL_2_START_DATE,
        val_end=config.VAL_2_END_DATE,
        test_start=config.TEST_2_START_DATE,
        test_end=config.TEST_2_END_DATE,
        # Añadir otros argumentos de missingness si es necesario, ej., min_missing_len=...
    )
    print("Preprocesamiento completo. Estructura de datos:")
    for key, value in processed_data.items():
        if isinstance(value, np.ndarray):
            print(f"- {key}: forma {value.shape}")
        elif isinstance(value, pd.DataFrame):
            print(f"- {key}: forma {value.shape}")
        elif isinstance(value, pd.Index):
             print(f"- {key}: longitud {len(value)}")
        elif not isinstance(value, StandardScaler): # No imprimir detalles del scaler
            print(f"- {key}: {value}")

except ValueError as e:
    print(f"Error durante el preprocesamiento: {e}")
    raise
# Out:
# Introduciendo 10.0% de datos faltantes con patrón 'point'...
# Preprocesamiento completo. Estructura de datos:
# - n_steps: 24
# - n_features: 114
# - train_index: longitud 840
# - val_index: longitud 216
# - test_index: longitud 276
# - train_X_ori: forma (817, 24, 114)
# - val_X_ori: forma (193, 24, 114)
# - test_X_ori: forma (253, 24, 114)
# - train_X: forma (817, 24, 114)
# - val_X: forma (193, 24, 114)
# - test_X: forma (253, 24, 114)
# - train_X_df: forma (840, 114)
# - val_X_df: forma (216, 114)
# - test_X_df: forma (276, 114)
# - train_missing_mask: forma (817, 24, 114)
# - val_missing_mask: forma (193, 24, 114)
# - test_missing_mask: forma (253, 24, 114)
# - train_indicating_mask: forma (817, 24, 114)
# - val_indicating_mask: forma (193, 24, 114)
# - test_indicating_mask: forma (253, 24, 114)
# - n_train_samples: 817
# - n_val_samples: 193
# - n_test_samples: 253

# %%
# Preparar datasets para PyPOTS (u otras bibliotecas) si es necesario
dataset_for_training2 = {"X": processed_data2['train_X']}
dataset_for_validating2 = {"X": processed_data2['val_X'], "X_ori": processed_data2['val_X_ori']}
# Nota: La validación en PyPOTS usualmente necesita X_ori para calcular la pérdida sobre los valores originales
# antes del enmascaramiento, pero nuestra evaluación calcula métricas en el conjunto de test usando test_X_ori

dataset_for_testing2 = {
    "X": processed_data2['test_X'], # Datos con NaNs para la entrada del modelo de imputación
    "X_ori": processed_data2['test_X_ori'], # Datos originales (escalados) antes de enmascarar
    "indicating_mask": processed_data2['test_indicating_mask'] # Máscara de los NaNs introducidos
}

# %% [markdown]
# ## 4. Métodos de Imputación para Periodo 1
#
# Aplicamos métodos base a los datos del conjunto de test (`dataset_for_testing['X']`). Almacenamos los resultados en un diccionario.

# %%
# Aplicar métodos base a los datos del conjunto de test (`dataset_for_testing['X']`)
X_test_missing = dataset_for_testing['X']
imputed_results = {} # Diccionario para almacenar resultados

print("\nEjecutando métodos de imputación base...")
# Out:
# Ejecutando métodos de imputación base...

# %% [markdown]
# ### 4.1. Modelos Baseline

# %% [markdown]
# ####
# 4.1 Imputación por Mediana
#
# Rellenamos los valores faltantes utilizando la mediana de cada característica (columna) calculada sobre todo el conjunto de datos de test (a través de todas las muestras y pasos de tiempo).

# %%
imputed_results['median'] = im.impute_median_sample_wise(X_test_missing)
print(f"Forma imputación mediana: {imputed_results['median'].shape}, NaNs: {np.isnan(imputed_results['median']).sum()}")
# Out:
#   Midiendo tiempo para 'impute_median_sample_wise'...
#   Finalizado 'impute_median_sample_wise' en 4.303959 segundos
# Forma imputación mediana: (253, 24, 114), NaNs: 0

# %% [markdown]
# #### 4.2 Imputación por Media
#
# Similar a la mediana, pero usamos la media de cada característica para rellenar los valores faltantes.

# %%
imputed_results['mean'] = im.impute_mean_sample_wise(X_test_missing)

print(f"Forma imputación media: {imputed_results['mean'].shape}, NaNs: {np.isnan(imputed_results['mean']).sum()}")
# Out:
#   Midiendo tiempo para 'impute_mean_sample_wise'...
#   Finalizado 'impute_mean_sample_wise' en 1.903079 segundos
# Forma imputación media: (253, 24, 114), NaNs: 0

# %% [markdown]
# #### 4.3 Interpolación Lineal
#
# Rellenamos los valores faltantes mediante interpolación lineal a lo largo del eje temporal (pasos de tiempo) para cada muestra y característica de forma independiente.

# %%
imputed_results['linear'] = im.impute_linear(X_test_missing)
print(f"Forma imputación lineal: {imputed_results['linear'].shape}, NaNs: {np.isnan(imputed_results['linear']).sum()}")
# Out:
#   Midiendo tiempo para 'impute_linear'...
#   Finalizado 'impute_linear' en 0.781630 segundos
# Forma imputación lineal: (253, 24, 114), NaNs: 0

# %% [markdown]
# #### 4.4 Relleno Forward/Backward (ffill/bfill)
#
# Nota: Estos métodos pueden requerir eliminar columnas como `WS`, `WD` si causan problemas o no son necesarias. La función de imputación en sí no elimina columnas, pero la evaluación podría necesitar alineación. Asumiremos por ahora que imputamos todas las características. La evaluación maneja la posible eliminación de columnas. Alternativamente, modificamos los datos de entrada antes de pasarlos a la imputación:

# %%
# ### 4.4 Relleno Forward/Backward (ffill/bfill)
# Nota: Estos métodos pueden requerir eliminar columnas como WS, WD si causan problemas.
# Modificamos los datos de entrada si es necesario:
X_test_missing_no_ws_wd = X_test_missing.copy()
cols_to_drop_indices = [config.FEATURE_COLUMNS.index(col) for col in config.COLS_TO_DROP_FOR_BASELINE if col in config.FEATURE_COLUMNS]

if cols_to_drop_indices:
    print(f"Eliminando columnas en índices {cols_to_drop_indices} para métodos Fill.")
    X_test_missing_no_ws_wd = np.delete(X_test_missing, cols_to_drop_indices, axis=2)
else:
    X_test_missing_no_ws_wd = X_test_missing # No hay columnas que eliminar

imputed_results['ffill'] = im.impute_forward(X_test_missing_no_ws_wd)
imputed_results['bfill'] = im.impute_backward(X_test_missing_no_ws_wd)
print(f"Forma imputación Forward fill {imputed_results['ffill'].shape}, NaNs: {np.isnan(imputed_results['ffill']).sum()}")
print(f"Forma imputación Backward fill: {imputed_results['bfill'].shape}, NaNs: {np.isnan(imputed_results['bfill']).sum()}")
# Out:
# Eliminando columnas en índices [111, 112] para métodos Fill.
#   Midiendo tiempo para 'impute_forward'...
#   Finalizado 'impute_forward' en 0.058667 segundos
#   Midiendo tiempo para 'impute_backward'...
#   Finalizado 'impute_backward' en 0.057314 segundos
# Forma imputación Forward fill (253, 24, 112), NaNs: 0
# Forma imputación Backward fill: (253, 24, 112), NaNs: 0

# %% [markdown]
# ### 4.5. Modelo Transformer

# %%
imputed_results['transformer'] = im.impute_transformer(dataset_for_training, 
                                                       dataset_for_validating, 
                                                       dataset_for_testing)
# Out:
# 2025-04-21 20:01:51 [INFO]: No given device, using default device: cpu
# 2025-04-21 20:01:51 [INFO]: Model files will be saved to ../results/imputation/transformer/20250421_T200151
# 2025-04-21 20:01:51 [INFO]: Tensorboard file will be saved to ../results/imputation/transformer/20250421_T200151/tensorboard
# 2025-04-21 20:01:51 [INFO]: Using customized MAE as the training loss function.
# 2025-04-21 20:01:51 [INFO]: Using customized MSE as the validation metric function.
# 2025-04-21 20:01:51 [INFO]: Transformer initialized with the given hyperparameters, the number of trainable parameters: 439,922
#   Midiendo tiempo para 'impute_transformer'...
#
# ---> Ejecutando lógica de imputación con Transformer...
#     Inicializando Transformer model...
#     Configurando optimizer, scheduler, loss...
#     Training Transformer model...
# 2025-04-21 20:01:52 [INFO]: Epoch 001 - training loss (MAE): 1.2947, validation MSE: 1.0575
# 2025-04-21 20:01:53 [INFO]: Epoch 002 - training loss (MAE): 0.9648, validation MSE: 1.0066
# 2025-04-21 20:01:53 [INFO]: Epoch 003 - training loss (MAE): 0.9111, validation MSE: 0.9572
# 2025-04-21 20:01:54 [INFO]: Epoch 004 - training loss (MAE): 0.8713, validation MSE: 0.9174
# 2025-04-21 20:01:55 [INFO]: Epoch 005 - training loss (MAE): 0.8293, validation MSE: 0.8465
# 2025-04-21 20:01:55 [INFO]: Epoch 006 - training loss (MAE): 0.7871, validation MSE: 0.7870
# 2025-04-21 20:01:56 [INFO]: Epoch 007 - training loss (MAE): 0.7485, validation MSE: 0.7489
# 2025-04-21 20:01:59 [INFO]: Epoch 008 - training loss (MAE): 0.7212, validation MSE: 0.7281
# 2025-04-21 20:02:00 [INFO]: Epoch 009 - training loss (MAE): 0.7002, validation MSE: 0.7160
# 2025-04-21 20:02:01 [INFO]: Epoch 010 - training loss (MAE): 0.6835, validation MSE: 0.7068
# 2025-04-21 20:02:02 [INFO]: Epoch 011 - training loss (MAE): 0.6686, validation MSE: 0.7027
# 2025-04-21 20:02:03 [INFO]: Epoch 012 - training loss (MAE): 0.6547, validation MSE: 0.6939
# 2025-04-21 20:02:04 [INFO]: Epoch 013 - training loss (MAE): 0.6455, validation MSE: 0.6931
# 2025-04-21 20:02:05 [INFO]: Epoch 014 - training loss (MAE): 0.6352, validation MSE: 0.6838
# 2025-04-21 20:02:06 [INFO]: Epoch 015 - training loss (MAE): 0.6246, validation MSE: 0.6805
# 2025-04-21 20:02:07 [INFO]: Epoch 016 - training loss (MAE): 0.6175, validation MSE: 0.6708
# 2025-04-21 20:02:08 [INFO]: Epoch 017 - training loss (MAE): 0.6107, validation MSE: 0.6641
# 2025-04-21 20:02:09 [INFO]: Epoch 018 - training loss (MAE): 0.6024, validation MSE: 0.6600
# 2025-04-21 20:02:10 [INFO]: Epoch 019 - training loss (MAE): 0.5957, validation MSE: 0.6590
# 2025-04-21 20:02:11 [INFO]: Epoch 020 - training loss (MAE): 0.5892, validation MSE: 0.6469
# 2025-04-21 20:02:12 [INFO]: Epoch 021 - training loss (MAE): 0.5819, validation MSE: 0.6424
# 2025-04-21 20:02:14 [INFO]: Epoch 022 - training loss (MAE): 0.5797, validation MSE: 0.6408
# 2025-04-21 20:02:15 [INFO]: Epoch 023 - training loss (MAE): 0.5709, validation MSE: 0.6341
# 2025-04-21 20:02:16 [INFO]: Epoch 024 - training loss (MAE): 0.5638, validation MSE: 0.6329
# 2025-04-21 20:02:17 [INFO]: Epoch 025 - training loss (MAE): 0.5591, validation MSE: 0.6366
# 2025-04-21 20:02:18 [INFO]: Epoch 026 - training loss (MAE): 0.5549, validation MSE: 0.6353
# 2025-04-21 20:02:19 [INFO]: Epoch 027 - training loss (MAE): 0.5497, validation MSE: 0.6292
# 2025-04-21 20:02:20 [INFO]: Epoch 028 - training loss (MAE): 0.5442, validation MSE: 0.6228
# 2025-04-21 20:02:21 [INFO]: Epoch 029 - training loss (MAE): 0.5399, validation MSE: 0.6262
# 2025-04-21 20:02:22 [INFO]: Epoch 030 - training loss (MAE): 0.5378, validation MSE: 0.6270
# 2025-04-21 20:02:23 [INFO]: Epoch 031 - training loss (MAE): 0.5309, validation MSE: 0.6240
# 2025-04-21 20:02:25 [INFO]: Epoch 032 - training loss (MAE): 0.5259, validation MSE: 0.6205
# 2025-04-21 20:02:26 [INFO]: Epoch 033 - training loss (MAE): 0.5246, validation MSE: 0.6144
# 2025-04-21 20:02:28 [INFO]: Epoch 034 - training loss (MAE): 0.5208, validation MSE: 0.6162
# 2025-04-21 20:02:29 [INFO]: Epoch 035 - training loss (MAE): 0.5180, validation MSE: 0.6221
# 2025-04-21 20:02:30 [INFO]: Epoch 036 - training loss (MAE): 0.5164, validation MSE: 0.6126
# 2025-04-21 20:02:31 [INFO]: Epoch 037 - training loss (MAE): 0.5106, validation MSE: 0.6071
# 2025-04-21 20:02:33 [INFO]: Epoch 038 - training loss (MAE): 0.5077, validation MSE: 0.6082
# 2025-04-21 20:02:34 [INFO]: Epoch 039 - training loss (MAE): 0.5047, validation MSE: 0.6118
# 2025-04-21 20:02:35 [INFO]: Epoch 040 - training loss (MAE): 0.4990, validation MSE: 0.6118
# 2025-04-21 20:02:36 [INFO]: Epoch 041 - training loss (MAE): 0.4990, validation MSE: 0.6093
# 2025-04-21 20:02:37 [INFO]: Epoch 042 - training loss (MAE): 0.4937, validation MSE: 0.6102
# 2025-04-21 20:02:37 [INFO]: Exceeded the training patience. Terminating the training procedure...
# 2025-04-21 20:02:37 [INFO]: Finished training. The best model is from epoch#37.
# 2025-04-21 20:02:37 [INFO]: Saved the model to ../results/imputation/transformer/20250421_T200151/Transformer.pypots
#     Transformer training complete.
#     Imputando con Transformer en el conjunto de test...
#     Imputación Transformer completa.
#   Finalizado 'impute_transformer' en 46.353799 segundos

# %% [markdown]
# ### 4.6. Modelo SAITS
#
# Si la biblioteca `pypots` está disponible, configuramos y entrenamos un modelo SAITS (Self-Attention based Imputation for Time Series) usando los datos de entrenamiento y validación preprocesados. Luego, usamos el modelo entrenado para imputar los valores faltantes en el conjunto de test.

# %%
imputed_results['saits'] = im.impute_saits(dataset_for_training, 
                                           dataset_for_validating, 
                                           dataset_for_testing)
# Out:
# 2025-04-21 20:02:37 [INFO]: No given device, using default device: cpu
# 2025-04-21 20:02:37 [INFO]: Model files will be saved to ../results/imputation/saits/20250421_T200237
# 2025-04-21 20:02:37 [INFO]: Tensorboard file will be saved to ../results/imputation/saits/20250421_T200237/tensorboard
# 2025-04-21 20:02:37 [INFO]: Using customized MAE as the training loss function.
# 2025-04-21 20:02:37 [INFO]: Using customized MSE as the validation metric function.
# 2025-04-21 20:02:38 [INFO]: SAITS initialized with the given hyperparameters, the number of trainable parameters: 1,940,096
#   Midiendo tiempo para 'impute_saits'...
#
# Configurando y ejecutando imputación con SAITS...
# Entrenando modelo SAITS...
# 2025-04-21 20:02:41 [INFO]: Epoch 001 - training loss (MAE): 1.1728, validation MSE: 1.0793
# 2025-04-21 20:02:45 [INFO]: Epoch 002 - training loss (MAE): 0.8982, validation MSE: 0.9993
# 2025-04-21 20:02:50 [INFO]: Epoch 003 - training loss (MAE): 0.8366, validation MSE: 0.9452
# 2025-04-21 20:02:55 [INFO]: Epoch 004 - training loss (MAE): 0.7926, validation MSE: 0.8832
# 2025-04-21 20:02:59 [INFO]: Epoch 005 - training loss (MAE): 0.7545, validation MSE: 0.8112
# 2025-04-21 20:03:02 [INFO]: Epoch 006 - training loss (MAE): 0.7192, validation MSE: 0.7495
# 2025-04-21 20:03:05 [INFO]: Epoch 007 - training loss (MAE): 0.6906, validation MSE: 0.7163
# 2025-04-21 20:03:09 [INFO]: Epoch 008 - training loss (MAE): 0.6684, validation MSE: 0.6915
# 2025-04-21 20:03:14 [INFO]: Epoch 009 - training loss (MAE): 0.6516, validation MSE: 0.6713
# 2025-04-21 20:03:22 [INFO]: Epoch 010 - training loss (MAE): 0.6347, validation MSE: 0.6553
# 2025-04-21 20:03:30 [INFO]: Epoch 011 - training loss (MAE): 0.6222, validation MSE: 0.6353
# 2025-04-21 20:03:34 [INFO]: Epoch 012 - training loss (MAE): 0.6109, validation MSE: 0.6294
# 2025-04-21 20:03:39 [INFO]: Epoch 013 - training loss (MAE): 0.6000, validation MSE: 0.6190
# 2025-04-21 20:03:44 [INFO]: Epoch 014 - training loss (MAE): 0.5947, validation MSE: 0.6147
# 2025-04-21 20:03:48 [INFO]: Epoch 015 - training loss (MAE): 0.5810, validation MSE: 0.6044
# 2025-04-21 20:03:51 [INFO]: Epoch 016 - training loss (MAE): 0.5724, validation MSE: 0.6019
# 2025-04-21 20:03:56 [INFO]: Epoch 017 - training loss (MAE): 0.5637, validation MSE: 0.5918
# 2025-04-21 20:04:02 [INFO]: Epoch 018 - training loss (MAE): 0.5570, validation MSE: 0.5838
# 2025-04-21 20:04:08 [INFO]: Epoch 019 - training loss (MAE): 0.5515, validation MSE: 0.5953
# 2025-04-21 20:04:13 [INFO]: Epoch 020 - training loss (MAE): 0.5423, validation MSE: 0.5794
# 2025-04-21 20:04:17 [INFO]: Epoch 021 - training loss (MAE): 0.5358, validation MSE: 0.5894
# 2025-04-21 20:04:20 [INFO]: Epoch 022 - training loss (MAE): 0.5284, validation MSE: 0.5878
# 2025-04-21 20:04:24 [INFO]: Epoch 023 - training loss (MAE): 0.5226, validation MSE: 0.5900
# 2025-04-21 20:04:28 [INFO]: Epoch 024 - training loss (MAE): 0.5159, validation MSE: 0.5778
# 2025-04-21 20:04:31 [INFO]: Epoch 025 - training loss (MAE): 0.5116, validation MSE: 0.5801
# 2025-04-21 20:04:34 [INFO]: Epoch 026 - training loss (MAE): 0.5056, validation MSE: 0.5820
# 2025-04-21 20:04:38 [INFO]: Epoch 027 - training loss (MAE): 0.4980, validation MSE: 0.5836
# 2025-04-21 20:04:41 [INFO]: Epoch 028 - training loss (MAE): 0.4914, validation MSE: 0.5878
# 2025-04-21 20:04:44 [INFO]: Epoch 029 - training loss (MAE): 0.4884, validation MSE: 0.5937
# 2025-04-21 20:04:44 [INFO]: Exceeded the training patience. Terminating the training procedure...
# 2025-04-21 20:04:44 [INFO]: Finished training. The best model is from epoch#24.
# 2025-04-21 20:04:44 [INFO]: Saved the model to ../results/imputation/saits/20250421_T200237/SAITS.pypots
# Entrenamiento de SAITS completo.
# Imputando con SAITS en el conjunto de test...
#   Finalizado 'impute_saits' en 127.028752 segundos

# %% [markdown]
# ## 4.2. Tiempos de ejecución en Periodo 1

# %%
if im.imputation_times:
    # Mapeo de nombres de función a nombres amigables para la tabla final
    # Si los nombres de tus funciones ya son amigables, puedes saltarte esto
    friendly_names_map = {
        'impute_mean': 'Mean',
        'impute_median': 'Median', # Este es el que mostraste
        'impute_linear': 'Linear',
        'impute_forward': 'Forward Fill',
        'impute_bakcward': 'Backward Fill',
        'impute_transformer': 'Transformer',
        'impute_saits': 'Saits',
        # Asegúrate de que este mapeo incluye TODAS tus funciones decoradas
    }

    # Usar nombres amigables en la tabla
    table_data = [(friendly_names_map.get(func_name, func_name), duration)
                  for func_name, duration in im.imputation_times.items()]

    time_results_df = pd.DataFrame(table_data, columns=['Método', 'Tiempo (segundos)'])

    # Ordenar por tiempo
    time_results_df = time_results_df.sort_values(by='Tiempo (segundos)').reset_index(drop=True)
time_results_df
# Out:
#                       Método  Tiempo (segundos)
# 0            impute_backward           0.057314
# 1               Forward Fill           0.058667
# 2                     Linear           0.781630
# 3    impute_mean_sample_wise           1.903079
# 4  impute_median_sample_wise           4.303959
# 5                Transformer          46.353799
# 6                      Saits         127.028752

# %% [markdown]
# ## 5. Métodos de Imputación para Periodo 2
#
# Aplicamos métodos base a los datos del conjunto de test (`dataset_for_testing2['X']`). Almacenamos los resultados en un diccionario.

# %%
# Aplicar métodos base a los datos del conjunto de test (`dataset_for_testing['X']`)
X_test_missing2 = dataset_for_testing2['X']
imputed_results2 = {} # Diccionario para almacenar resultados

print("\nEjecutando métodos de imputación base...")
# Out:
# Ejecutando métodos de imputación base...

# %% [markdown]
# ### 5.1. Modelos Baseline

# %% [markdown]
# #### 5.1.1 Imputación por Mediana en Periodo 2
#
# Rellenamos los valores faltantes utilizando la mediana de cada característica (columna) calculada sobre todo el conjunto de datos de test (a través de todas las muestras y pasos de tiempo).

# %%
imputed_results2['median'] = im.impute_median_sample_wise(X_test_missing2)
print(f"Forma imputación mediana: {imputed_results2['median'].shape}, NaNs: {np.isnan(imputed_results2['median']).sum()}")
# Out:
#   Midiendo tiempo para 'impute_median_sample_wise'...
#   Finalizado 'impute_median_sample_wise' en 0.401920 segundos
# Forma imputación mediana: (73, 24, 114), NaNs: 0

# %% [markdown]
# #### 5.1.2 Imputación por Media en Periodo 2
#
# Similar a la mediana, pero usamos la media de cada característica para rellenar los valores faltantes.

# %%
imputed_results2['mean'] = im.impute_mean_sample_wise(X_test_missing2)
print(f"Forma imputación media: {imputed_results2['mean'].shape}, NaNs: {np.isnan(imputed_results2['mean']).sum()}")
# Out:
#   Midiendo tiempo para 'impute_mean_sample_wise'...
#   Finalizado 'impute_mean_sample_wise' en 0.223324 segundos
# Forma imputación media: (73, 24, 114), NaNs: 0

# %% [markdown]
# #### 5.1.3 Interpolación Lineal en Periodo 2
#
# Rellenamos los valores faltantes mediante interpolación lineal a lo largo del eje temporal (pasos de tiempo) para cada muestra y característica de forma independiente.

# %%
imputed_results2['linear'] = im.impute_linear(X_test_missing2)
print(f"Forma imputación lineal: {imputed_results2['linear'].shape}, NaNs: {np.isnan(imputed_results2['linear']).sum()}")
# Out:
#   Midiendo tiempo para 'impute_linear'...
#   Finalizado 'impute_linear' en 0.239486 segundos
# Forma imputación lineal: (73, 24, 114), NaNs: 0

# %% [markdown]
# #### 5.1.4 Relleno Forward/Backward (ffill/bfill) en Periodo 2

# %%
# ### 4.4 Relleno Forward/Backward (ffill/bfill)
# Nota: Estos métodos pueden requerir eliminar columnas como WS, WD si causan problemas.
# Modificamos los datos de entrada si es necesario:
X_test_missing2_no_ws_wd = X_test_missing2.copy()
cols_to_drop_indices = [config.FEATURE_COLUMNS.index(col) for col in config.COLS_TO_DROP_FOR_BASELINE if col in config.FEATURE_COLUMNS]

if cols_to_drop_indices:
    print(f"Eliminando columnas en índices {cols_to_drop_indices} para métodos Fill.")
    X_test_missing2_no_ws_wd = np.delete(X_test_missing2, cols_to_drop_indices, axis=2)
else:
    X_test_missing2_no_ws_wd = X_test_missing2 # No hay columnas que eliminar

imputed_results2['ffill'] = im.impute_forward(X_test_missing2_no_ws_wd)
imputed_results2['bfill'] = im.impute_backward(X_test_missing2_no_ws_wd)
print(f"Forma imputación Forward fill {imputed_results2['ffill'].shape}, NaNs: {np.isnan(imputed_results2['ffill']).sum()}")
print(f"Forma imputación Backward fill: {imputed_results2['bfill'].shape}, NaNs: {np.isnan(imputed_results2['bfill']).sum()}")
# Out:
# Eliminando columnas en índices [111, 112] para métodos Fill.
#   Midiendo tiempo para 'impute_forward'...
#   Finalizado 'impute_forward' en 0.027191 segundos
#   Midiendo tiempo para 'impute_backward'...
#   Finalizado 'impute_backward' en 0.017325 segundos
# Forma imputación Forward fill (73, 24, 112), NaNs: 0
# Forma imputación Backward fill: (73, 24, 112), NaNs: 0

# %%
print(dataset_for_training2['X'].shape)
print(dataset_for_validating2['X'].shape)
print(dataset_for_testing['X'].shape)
# Out:
# (289, 24, 114)
# (49, 24, 114)
# (253, 24, 114)

# %% [markdown]
# ### 5.2. Modelo Transformer

# %%
imputed_results2['transformer'] = im.impute_transformer(dataset_for_training2, 
                                                       dataset_for_validating2, 
                                                       dataset_for_testing2)
# Out:
# 2025-04-21 20:05:11 [INFO]: No given device, using default device: cpu
# 2025-04-21 20:05:11 [INFO]: Model files will be saved to ../results/imputation/transformer/20250421_T200511
# 2025-04-21 20:05:11 [INFO]: Tensorboard file will be saved to ../results/imputation/transformer/20250421_T200511/tensorboard
# 2025-04-21 20:05:11 [INFO]: Using customized MAE as the training loss function.
# 2025-04-21 20:05:11 [INFO]: Using customized MSE as the validation metric function.
# 2025-04-21 20:05:11 [INFO]: Transformer initialized with the given hyperparameters, the number of trainable parameters: 439,922
#   Midiendo tiempo para 'impute_transformer'...
#
# ---> Ejecutando lógica de imputación con Transformer...
#     Inicializando Transformer model...
#     Configurando optimizer, scheduler, loss...
#     Training Transformer model...
# 2025-04-21 20:05:11 [INFO]: Epoch 001 - training loss (MAE): 1.5508, validation MSE: 0.7499
# 2025-04-21 20:05:11 [INFO]: Epoch 002 - training loss (MAE): 1.3343, validation MSE: 0.6349
# 2025-04-21 20:05:11 [INFO]: Epoch 003 - training loss (MAE): 1.1528, validation MSE: 0.6019
# 2025-04-21 20:05:12 [INFO]: Epoch 004 - training loss (MAE): 1.0526, validation MSE: 0.5430
# 2025-04-21 20:05:12 [INFO]: Epoch 005 - training loss (MAE): 1.0046, validation MSE: 0.5416
# 2025-04-21 20:05:12 [INFO]: Epoch 006 - training loss (MAE): 0.9848, validation MSE: 0.5318
# 2025-04-21 20:05:13 [INFO]: Epoch 007 - training loss (MAE): 0.9648, validation MSE: 0.5190
# 2025-04-21 20:05:13 [INFO]: Epoch 008 - training loss (MAE): 0.9512, validation MSE: 0.5123
# 2025-04-21 20:05:13 [INFO]: Epoch 009 - training loss (MAE): 0.9349, validation MSE: 0.5052
# 2025-04-21 20:05:13 [INFO]: Epoch 010 - training loss (MAE): 0.9163, validation MSE: 0.4970
# 2025-04-21 20:05:14 [INFO]: Epoch 011 - training loss (MAE): 0.9006, validation MSE: 0.4946
# 2025-04-21 20:05:14 [INFO]: Epoch 012 - training loss (MAE): 0.8850, validation MSE: 0.4898
# 2025-04-21 20:05:14 [INFO]: Epoch 013 - training loss (MAE): 0.8744, validation MSE: 0.4820
# 2025-04-21 20:05:14 [INFO]: Epoch 014 - training loss (MAE): 0.8618, validation MSE: 0.4723
# 2025-04-21 20:05:15 [INFO]: Epoch 015 - training loss (MAE): 0.8457, validation MSE: 0.4596
# 2025-04-21 20:05:15 [INFO]: Epoch 016 - training loss (MAE): 0.8269, validation MSE: 0.4530
# 2025-04-21 20:05:15 [INFO]: Epoch 017 - training loss (MAE): 0.8214, validation MSE: 0.4441
# 2025-04-21 20:05:16 [INFO]: Epoch 018 - training loss (MAE): 0.8023, validation MSE: 0.4336
# 2025-04-21 20:05:16 [INFO]: Epoch 019 - training loss (MAE): 0.7894, validation MSE: 0.4298
# 2025-04-21 20:05:16 [INFO]: Epoch 020 - training loss (MAE): 0.7780, validation MSE: 0.4233
# 2025-04-21 20:05:16 [INFO]: Epoch 021 - training loss (MAE): 0.7710, validation MSE: 0.4221
# 2025-04-21 20:05:17 [INFO]: Epoch 022 - training loss (MAE): 0.7623, validation MSE: 0.4191
# 2025-04-21 20:05:18 [INFO]: Epoch 023 - training loss (MAE): 0.7527, validation MSE: 0.4146
# 2025-04-21 20:05:18 [INFO]: Epoch 024 - training loss (MAE): 0.7459, validation MSE: 0.4165
# 2025-04-21 20:05:19 [INFO]: Epoch 025 - training loss (MAE): 0.7392, validation MSE: 0.4138
# 2025-04-21 20:05:19 [INFO]: Epoch 026 - training loss (MAE): 0.7329, validation MSE: 0.4148
# 2025-04-21 20:05:20 [INFO]: Epoch 027 - training loss (MAE): 0.7187, validation MSE: 0.4099
# 2025-04-21 20:05:21 [INFO]: Epoch 028 - training loss (MAE): 0.7113, validation MSE: 0.4105
# 2025-04-21 20:05:22 [INFO]: Epoch 029 - training loss (MAE): 0.7053, validation MSE: 0.4063
# 2025-04-21 20:05:22 [INFO]: Epoch 030 - training loss (MAE): 0.6964, validation MSE: 0.4126
# 2025-04-21 20:05:23 [INFO]: Epoch 031 - training loss (MAE): 0.6898, validation MSE: 0.4061
# 2025-04-21 20:05:23 [INFO]: Epoch 032 - training loss (MAE): 0.6868, validation MSE: 0.4024
# 2025-04-21 20:05:24 [INFO]: Epoch 033 - training loss (MAE): 0.6756, validation MSE: 0.4037
# 2025-04-21 20:05:24 [INFO]: Epoch 034 - training loss (MAE): 0.6703, validation MSE: 0.4080
# 2025-04-21 20:05:25 [INFO]: Epoch 035 - training loss (MAE): 0.6658, validation MSE: 0.4042
# 2025-04-21 20:05:26 [INFO]: Epoch 036 - training loss (MAE): 0.6511, validation MSE: 0.4075
# 2025-04-21 20:05:26 [INFO]: Epoch 037 - training loss (MAE): 0.6529, validation MSE: 0.4090
# 2025-04-21 20:05:26 [INFO]: Exceeded the training patience. Terminating the training procedure...
# 2025-04-21 20:05:26 [INFO]: Finished training. The best model is from epoch#32.
# 2025-04-21 20:05:26 [INFO]: Saved the model to ../results/imputation/transformer/20250421_T200511/Transformer.pypots
#     Transformer training complete.
#     Imputando con Transformer en el conjunto de test...
#     Imputación Transformer completa.
#   Finalizado 'impute_transformer' en 15.669099 segundos

# %% [markdown]
# ### 5.3. Modelo SAITS
#
# Si la biblioteca `pypots` está disponible, configuramos y entrenamos un modelo SAITS (Self-Attention based Imputation for Time Series) usando los datos de entrenamiento y validación preprocesados. Luego, usamos el modelo entrenado para imputar los valores faltantes en el conjunto de test.

# %%
imputed_results2['saits'] = im.impute_saits(dataset_for_training2, 
                                            dataset_for_validating2, 
                                                dataset_for_testing2)
# Out:
# 2025-04-21 20:05:26 [INFO]: No given device, using default device: cpu
# 2025-04-21 20:05:26 [INFO]: Model files will be saved to ../results/imputation/saits/20250421_T200526
# 2025-04-21 20:05:26 [INFO]: Tensorboard file will be saved to ../results/imputation/saits/20250421_T200526/tensorboard
# 2025-04-21 20:05:26 [INFO]: Using customized MAE as the training loss function.
# 2025-04-21 20:05:26 [INFO]: Using customized MSE as the validation metric function.
# 2025-04-21 20:05:26 [INFO]: SAITS initialized with the given hyperparameters, the number of trainable parameters: 1,940,096
#   Midiendo tiempo para 'impute_saits'...
#
# Configurando y ejecutando imputación con SAITS...
# Entrenando modelo SAITS...
# 2025-04-21 20:05:28 [INFO]: Epoch 001 - training loss (MAE): 1.4417, validation MSE: 0.7054
# 2025-04-21 20:05:30 [INFO]: Epoch 002 - training loss (MAE): 1.1824, validation MSE: 0.5823
# 2025-04-21 20:05:31 [INFO]: Epoch 003 - training loss (MAE): 1.0474, validation MSE: 0.5378
# 2025-04-21 20:05:33 [INFO]: Epoch 004 - training loss (MAE): 0.9826, validation MSE: 0.5329
# 2025-04-21 20:05:34 [INFO]: Epoch 005 - training loss (MAE): 0.9484, validation MSE: 0.5244
# 2025-04-21 20:05:36 [INFO]: Epoch 006 - training loss (MAE): 0.9148, validation MSE: 0.5170
# 2025-04-21 20:05:38 [INFO]: Epoch 007 - training loss (MAE): 0.8995, validation MSE: 0.5056
# 2025-04-21 20:05:39 [INFO]: Epoch 008 - training loss (MAE): 0.8735, validation MSE: 0.5079
# 2025-04-21 20:05:40 [INFO]: Epoch 009 - training loss (MAE): 0.8561, validation MSE: 0.4940
# 2025-04-21 20:05:42 [INFO]: Epoch 010 - training loss (MAE): 0.8368, validation MSE: 0.4906
# 2025-04-21 20:05:43 [INFO]: Epoch 011 - training loss (MAE): 0.8185, validation MSE: 0.4878
# 2025-04-21 20:05:44 [INFO]: Epoch 012 - training loss (MAE): 0.8153, validation MSE: 0.4776
# 2025-04-21 20:05:45 [INFO]: Epoch 013 - training loss (MAE): 0.7967, validation MSE: 0.4681
# 2025-04-21 20:05:46 [INFO]: Epoch 014 - training loss (MAE): 0.7828, validation MSE: 0.4469
# 2025-04-21 20:05:47 [INFO]: Epoch 015 - training loss (MAE): 0.7666, validation MSE: 0.4396
# 2025-04-21 20:05:49 [INFO]: Epoch 016 - training loss (MAE): 0.7607, validation MSE: 0.4287
# 2025-04-21 20:05:50 [INFO]: Epoch 017 - training loss (MAE): 0.7456, validation MSE: 0.4270
# 2025-04-21 20:05:52 [INFO]: Epoch 018 - training loss (MAE): 0.7355, validation MSE: 0.4223
# 2025-04-21 20:05:53 [INFO]: Epoch 019 - training loss (MAE): 0.7308, validation MSE: 0.4123
# 2025-04-21 20:05:54 [INFO]: Epoch 020 - training loss (MAE): 0.7139, validation MSE: 0.4120
# 2025-04-21 20:05:55 [INFO]: Epoch 021 - training loss (MAE): 0.7048, validation MSE: 0.4152
# 2025-04-21 20:05:57 [INFO]: Epoch 022 - training loss (MAE): 0.7010, validation MSE: 0.4115
# 2025-04-21 20:05:58 [INFO]: Epoch 023 - training loss (MAE): 0.6868, validation MSE: 0.4082
# 2025-04-21 20:05:59 [INFO]: Epoch 024 - training loss (MAE): 0.6748, validation MSE: 0.4085
# 2025-04-21 20:06:00 [INFO]: Epoch 025 - training loss (MAE): 0.6666, validation MSE: 0.4084
# 2025-04-21 20:06:02 [INFO]: Epoch 026 - training loss (MAE): 0.6588, validation MSE: 0.4042
# 2025-04-21 20:06:04 [INFO]: Epoch 027 - training loss (MAE): 0.6498, validation MSE: 0.4013
# 2025-04-21 20:06:05 [INFO]: Epoch 028 - training loss (MAE): 0.6430, validation MSE: 0.4002
# 2025-04-21 20:06:06 [INFO]: Epoch 029 - training loss (MAE): 0.6308, validation MSE: 0.4111
# 2025-04-21 20:06:08 [INFO]: Epoch 030 - training loss (MAE): 0.6265, validation MSE: 0.4027
# 2025-04-21 20:06:09 [INFO]: Epoch 031 - training loss (MAE): 0.6184, validation MSE: 0.4039
# 2025-04-21 20:06:10 [INFO]: Epoch 032 - training loss (MAE): 0.6107, validation MSE: 0.4028
# 2025-04-21 20:06:11 [INFO]: Epoch 033 - training loss (MAE): 0.6023, validation MSE: 0.4011
# 2025-04-21 20:06:11 [INFO]: Exceeded the training patience. Terminating the training procedure...
# 2025-04-21 20:06:11 [INFO]: Finished training. The best model is from epoch#28.
# 2025-04-21 20:06:12 [INFO]: Saved the model to ../results/imputation/saits/20250421_T200526/SAITS.pypots
# Entrenamiento de SAITS completo.
# Imputando con SAITS en el conjunto de test...
#   Finalizado 'impute_saits' en 45.527003 segundos

# %% [markdown]
# ## 5.2. Tiempos de ejecución en Periodo 2

# %%
if im.imputation_times:
    # Mapeo de nombres de función a nombres amigables para la tabla final
    # Si los nombres de tus funciones ya son amigables, puedes saltarte esto
    friendly_names_map = {
        'impute_mean': 'Mean',
        'impute_median': 'Median', # Este es el que mostraste
        'impute_linear': 'Linear',
        'impute_forward': 'Forward Fill',
        'impute_bakcward': 'Backward Fill',
        'impute_transformer': 'Transformer',
        'impute_saits': 'Saits',
        # Asegúrate de que este mapeo incluye TODAS tus funciones decoradas
    }

    # Usar nombres amigables en la tabla
    table_data = [(friendly_names_map.get(func_name, func_name), duration)
                  for func_name, duration in im.imputation_times.items()]

    time_results_df2 = pd.DataFrame(table_data, columns=['Método', 'Tiempo (segundos)'])

    # Ordenar por tiempo
    time_results_df2 = time_results_df.sort_values(by='Tiempo (segundos)').reset_index(drop=True)
time_results_df2
# Out:
#                       Método  Tiempo (segundos)
# 0            impute_backward           0.057314
# 1               Forward Fill           0.058667
# 2                     Linear           0.781630
# 3    impute_mean_sample_wise           1.903079
# 4  impute_median_sample_wise           4.303959
# 5                Transformer          46.353799
# 6                      Saits         127.028752

# %% [markdown]
# ## 6. Evaluar Resultados de Imputación en Periodo 1
#
# Evaluamos el rendimiento de cada método de imputación utilizando métricas estándar (MAE, MSE, RMSE, MRE) calculadas únicamente sobre los valores que fueron originalmente faltantes (indicados por `indicating_mask`). Comparamos los valores imputados (`y_pred`) con los valores verdaderos originales (`y_true`, correspondientes a `test_X_ori`).

# %%
print("\nEvaluando rendimiento de imputación en el conjunto de test...")
import pampaneira_imputation.evaluation as ev

# Usar la función del módulo de evaluación
# Requiere el diccionario de datos preprocesados (para ground truth y máscara)
# y el diccionario de resultados imputados
evaluation_table = ev.evaluate_all_methods(
    processed_data,
    imputed_results,
    methods_to_evaluate=list(imputed_results.keys()) # Evaluar todos los métodos calculados
)

evaluation_table.T
# Out:
# Evaluando rendimiento de imputación en el conjunto de test...
#
# Calculando métricas para: median
#
# Calculando métricas para: mean
#
# Calculando métricas para: linear
# Ajustando datos verdaderos y máscara para ffill debido a columnas eliminadas para ffill.
#
# Calculando métricas para: ffill
# Ajustando datos verdaderos y máscara para bfill debido a columnas eliminadas para bfill.
#
# Calculando métricas para: bfill
#
# Calculando métricas para: transformer
#
# Calculando métricas para: saits
# Method  Median    Mean  Linear   Ffill   Bfill  Transformer   Saits
# RMSE    0.6617  0.5832  0.7246  0.7838  0.7362       0.6922  0.4426
# MSE     0.4378  0.3401  0.5250  0.6143  0.5421       0.4792  0.1959
# MAE     0.4292  0.3558  0.5515  0.5655  0.4962       0.5785  0.3093
# MRE     2.7472  2.2774  3.5301  3.4361  3.0148       3.7032  1.9801

# %% [markdown]
# ### 6.1. Interpretación de la Tabla de Métricas de Imputación/Predicción
#
# Esta tabla compara el rendimiento de diferentes métodos de imputación o predicción utilizando cuatro métricas de error: RMSE (Raíz del Error Cuadrático Medio), MSE (Error Cuadrático Medio), MAE (Error Absoluto Medio) y MRE (Error Relativo Medio). Valores más bajos en todas las métricas indican un mejor rendimiento.
#
# En resumen, los métodos basados en modelos complejos, Transformer y Saits, demuestran el mejor rendimiento general, con valores significativamente más bajos en todas las métricas en comparación con los métodos más simples.
#
# La Media se destaca como un método de referencia sorprendentemente efectivo, superando a la Mediana y a los métodos de interpolación lineal y de relleno simple (Ffill y Bfill). Esto sugiere que para este conjunto de datos, la media proporciona una buena estimación central.
#
# Los métodos de relleno simple, Ffill (relleno hacia adelante) y Bfill (relleno hacia atrás), muestran el peor rendimiento, indicando que son enfoques ingenuos y menos efectivos para este tipo de datos.
#
# El método Lineal se sitúa en un punto intermedio, mejor que los rellenos simples pero peor que la Media, la Mediana y los modelos Transformer y Saits.

# %% [markdown]
# ## 7. Evaluar Resultados de Imputación en Periodo 2
#
# Evaluamos el rendimiento de cada método de imputación utilizando métricas estándar (MAE, MSE, RMSE, MRE) calculadas únicamente sobre los valores que fueron originalmente faltantes (indicados por `indicating_mask`). Comparamos los valores imputados (`y_pred`) con los valores verdaderos originales (`y_true`, correspondientes a `test_X_ori`).

# %%
print("\nEvaluando rendimiento de imputación en el conjunto de test...")

# Usar la función del módulo de evaluación
# Requiere el diccionario de datos preprocesados (para ground truth y máscara)
# y el diccionario de resultados imputados
evaluation_table2 = ev.evaluate_all_methods(
    processed_data2,
    imputed_results2,
    methods_to_evaluate=list(imputed_results2.keys()) # Evaluar todos los métodos calculados
)

evaluation_table2.T
# Out:
# Evaluando rendimiento de imputación en el conjunto de test...
#
# Calculando métricas para: median
#
# Calculando métricas para: mean
#
# Calculando métricas para: linear
# Ajustando datos verdaderos y máscara para ffill debido a columnas eliminadas para ffill.
#
# Calculando métricas para: ffill
# Ajustando datos verdaderos y máscara para bfill debido a columnas eliminadas para bfill.
#
# Calculando métricas para: bfill
#
# Calculando métricas para: transformer
#
# Calculando métricas para: saits
# Method  Median    Mean  Linear   Ffill   Bfill  Transformer   Saits
# RMSE    0.7595  0.7244  0.7644  0.7989  0.8056       0.5252  0.5163
# MSE     0.5768  0.5248  0.5843  0.6383  0.6489       0.2758  0.2665
# MAE     0.4849  0.4691  0.5181  0.4603  0.5061       0.3254  0.3140
# MRE     2.0625  1.9952  2.2036  1.9667  2.1625       1.3838  1.3356

# %% [markdown]
# ## 8. Visualizar Resultados (Ejemplo: NO2)
#
# Visualizamos los resultados de la imputación para una característica específica (NO2) en el periodo de test. Comparamos la serie original (escalada, con valores faltantes), la serie verdadera (`Ground Truth`, escalada, antes de introducir valores faltantes artificiales) y las series imputadas por diferentes métodos. Los puntos rojos indican los valores que fueron artificialmente marcados como faltantes y luego imputados.

# %%
import matplotlib.pyplot as plt
import pandas as pd
# Asumiendo que 'config', 'periodo_1_raw', 'processed_data', 'imputed_results', 'utils'
# y 'dataset_for_testing' están definidos en el contexto de tu script.

# --- Configuración y Carga de Datos (asumiendo que ya están definidos) ---
# feature_to_plot = "NO2"
# config.FEATURE_COLUMNS = [...] # Lista de nombres de columnas de características
# periodo_1_raw = pd.DataFrame(...) # DataFrame original con datos crudos
# processed_data = {'scaler': scaler_object, 'test_index': test_index_full, 'n_features': n_features}
# imputed_results = {'saits': saits_imputed_array, ...} # Diccionario con resultados de imputación
# utils.reshape_imputed_to_df = function(...) # Función utilitaria
# dataset_for_testing = {'X_ori': original_scaled_test_windows, 'indicating_mask': mask_array} # Datos originales ANTES de enmascarar y la máscara


# Seleccionar una característica para visualizar
feature_to_plot = "NO2"
if feature_to_plot not in config.FEATURE_COLUMNS:
    print(f"Advertencia: '{feature_to_plot}' no está en las columnas de características. Saltando gráfico.")
else:
    feature_index = config.FEATURE_COLUMNS.index(feature_to_plot)

    # Obtener datos originales de test (antes de ventanear) para el rango deseado
    # Usamos el mismo rango que en el zoom del gráfico anterior para detalle
    plot_start = "2023-03-06 00:00:00"
    plot_end = "2023-03-08 00:00:00"
    test_df_original = periodo_1_raw.loc[plot_start:plot_end]

    # --- 2. Graficar Ground Truth (donde se introdujo la ausencia) - escalado ---
    # Reconstruir la serie temporal ground truth desde test_X_ori (datos originales escalados antes de enmascarar)
    ground_truth_df = utils.reshape_imputed_to_df(
         dataset_for_testing['X_ori'], # Usar los datos escalados originales completos
         test_index_full, # Usar el índice completo antes de ventanear
         config.FEATURE_COLUMNS,
         config.N_STEPS
         )

    # Extraer el rango de tiempo relevante para graficar desde el Ground Truth
    # Asegurarse que los índices coincidan con el rango deseado
    if plot_start in ground_truth_df.index and plot_end in ground_truth_df.index:
        ground_truth_series = ground_truth_df.loc[plot_start:plot_end, feature_to_plot]

        # Marcar los puntos que eran originalmente faltantes (usando la máscara)
        # Necesitamos aplanar la máscara para que coincida con la serie temporal
        mask_flat = dataset_for_testing['indicating_mask'].reshape(-1, processed_data['n_features'])
        # Crear índice para la máscara aplanada que coincida con ground_truth_df
        # Asegurarse que la longitud del índice coincida con la máscara aplanada
        mask_index = ground_truth_df.index[:len(mask_flat)]
        mask_series = pd.Series(mask_flat[:, feature_index], index=mask_index).loc[plot_start:plot_end] # Filtrar por el rango de graficado

        # Obtener los índices de los puntos que faltaban (donde la máscara es 1)
        missing_indices = mask_series[mask_series == 1].index

        # Graficar la línea Ground Truth
        plt.plot(ground_truth_series.index, ground_truth_series.values,
                 label='Ground Truth (Escalado)',
                 color='black',
                 linewidth=1.5)

        # Graficar los puntos rojos de los Ground Truth que faltaban
        # Asegurar que los missing_indices existan en ground_truth_series antes de graficar
        valid_missing_indices = missing_indices.intersection(ground_truth_series.index)
        plt.scatter(valid_missing_indices, ground_truth_series.loc[valid_missing_indices],
                    color='red',
                    s=25, # Tamaño un poco más grande para que se vean mejor
                    label='Puntos Imputados (Verdad)', # Etiqueta clara para los puntos
                    zorder=5) # Asegurar que los puntos se dibujen encima de las líneas

    else:
        print("Advertencia: Rango de fechas de test original no encontrado completamente en datos ground truth reconstruidos. Saltando gráfico de ground truth.")
        ground_truth_series = None # Para evitar errores posteriores

    # --- 3. Graficar resultados imputados para 'Saits' ---
    method_to_plot = 'saits' # Elegir el método Saits
    imputed_color = 'orange' # Elegir un color
    imputed_linestyle = ':' # Usar el estilo punteado

    if method_to_plot in imputed_results:
        y_pred_saits = imputed_results[method_to_plot]

        # Reestructurar la predicción de Saits
        imputed_df_saits = utils.reshape_imputed_to_df(
             y_pred_saits,
             test_index_full, # Usar índice completo de test
             config.FEATURE_COLUMNS,
             config.N_STEPS
        )

        # Extraer la serie de Saits para la característica y el rango de tiempo deseado
        if plot_start in imputed_df_saits.index and plot_end in imputed_df_saits.index:
            imputed_series_saits = imputed_df_saits.loc[plot_start:plot_end, feature_to_plot]

            plt.plot(imputed_series_saits.index, imputed_series_saits.values,
                     label=f'{method_to_plot.title()} Imputado',
                     color=imputed_color,
                     linestyle=imputed_linestyle,
                     alpha=0.8)
        else:
             print(f"Advertencia: Rango de fechas de test original no encontrado completamente en datos imputados ({method_to_plot}). Saltando gráfico parcial.")

    else:
        print(f"Advertencia: El método '{method_to_plot}' no se encuentra en los resultados imputados.")


    # --- Elementos Adicionales del Gráfico ---
    plt.legend()
    plt.grid(True, linestyle='--', alpha=0.6)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## 9. Opcional: Guardar Resultados
#
# Podemos guardar la tabla de evaluación y/o los datos imputados (por ejemplo, los resultados de SAITS) en archivos CSV si es necesario para análisis posteriores o informes.

# %%
# Guardar la tabla de evaluación
# evaluation_table.to_csv(f"{config.RESULTS_DIR}/imputation_evaluation.csv")
# print(f"Resultados de evaluación guardados en {config.RESULTS_DIR}/imputation_evaluation.csv")

# Guardar datos imputados (ej. resultado de SAITS) si es necesario
# saits_imputed_df = utils.reshape_imputed_to_df(...) # Necesitas reconstruir el DataFrame
# saits_imputed_df.to_csv(...)

print("\nFlujo de trabajo finalizado.")
# Out:
# Flujo de trabajo finalizado.
