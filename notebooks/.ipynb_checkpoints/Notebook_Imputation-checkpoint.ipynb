# %% [markdown]
# # Flujo de Trabajo de Imputación para Pampaneira (Refactorizado)
#
# Este cuaderno ejecuta el pipeline refactorizado para imputar valores faltantes en el conjunto de datos de Pampaneira.

# %% [markdown]
# ## 1. Configuración e Importaciones
#
# Aseguramos que la raíz del proyecto esté en el path de Python. Ajusta la profundidad del path ('../') según sea necesario dependiendo de dónde se encuentre este cuaderno en relación con la raíz del proyecto.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
import os
import sys
from sklearn.preprocessing import StandardScaler # Mantener para uso directo/verificación potencial
from torch.optim import Adam
from torch.optim.lr_scheduler import ReduceLROnPlateau
from torch.nn import SmoothL1Loss

# Asegurar que la raíz del proyecto esté en el Python path
# Ajusta la profundidad del path ('../') según sea necesario
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %% [markdown]
# Importamos los módulos refactorizados del proyecto:

# %%
# Importar módulos refactorizados
from pampaneira_imputation import config
from pampaneira_imputation import data_loader as dl
from pampaneira_imputation import data_preprocessor as dp
from pampaneira_imputation import imputation_methods as im
from pampaneira_imputation import evaluation as ev
from pampaneira_imputation import utils
# Out:
# ████████╗██╗███╗   ███╗███████╗    ███████╗███████╗██████╗ ██╗███████╗███████╗    █████╗ ██╗
# ╚══██╔══╝██║████╗ ████║██╔════╝    ██╔════╝██╔════╝██╔══██╗██║██╔════╝██╔════╝   ██╔══██╗██║
#    ██║   ██║██╔████╔██║█████╗█████╗███████╗█████╗  ██████╔╝██║█████╗  ███████╗   ███████║██║
#    ██║   ██║██║╚██╔╝██║██╔══╝╚════╝╚════██║██╔══╝  ██╔══██╗██║██╔══╝  ╚════██║   ██╔══██║██║
#    ██║   ██║██║ ╚═╝ ██║███████╗    ███████║███████╗██║  ██║██║███████╗███████║██╗██║  ██║██║
#    ╚═╝   ╚═╝╚═╝     ╚═╝╚══════╝    ╚══════╝╚══════╝╚═╝  ╚═╝╚═╝╚══════╝╚══════╝╚═╝╚═╝  ╚═╝╚═╝
# ai4ts v0.0.3 - building AI for unified time-series analysis, https://time-series.ai

# %% [markdown]
# Importamos SAITS por separado (asumiendo que pypots está instalado):

# %%
# Importar SAITS por separado (asumiendo que pypots está instalado)
try:
    from pypots.imputation import SAITS, Transformer
except ImportError:
    print("Advertencia: No se encontró la librería pypots. La imputación con SAITS no estará disponible.")
    SAITS = None # Definir como None si no está disponible

# %% [markdown]
# Configuramos pandas y la visualización:

# %%
# Configurar pandas y visualización
pd.options.mode.chained_assignment = None
pd.reset_option('display.max_rows')
pd.reset_option('display.max_columns')
plt.rcParams["figure.figsize"] = [12, 4]
warnings.filterwarnings("ignore") # Usar con precaución

# %% [markdown]
# ## 2. Carga de Datos
#
# Cargamos los datos de la intersección (filtrados para PAM_2):

# %%
# Cargar datos de intersección (filtrados para PAM_2)
try:
    df_int_raw = dl.load_intersection_data(
        filepath=config.INTERSECTION_FILE,
        target_truck_pos=config.TARGET_TRUCK_POS
    )
    print(f"Forma de los datos de intersección cargados: {df_int_raw.shape}")
    print(f"Rango de fechas: {df_int_raw[config.DATE_COL].min()} a {df_int_raw[config.DATE_COL].max()}")
    # display(df_int_raw.head()) # Opcional: mostrar encabezado
except Exception as e:
    print(f"Error al cargar los datos de intersección: {e}")
    # Detener ejecución o manejar el error apropiadamente
    raise
# Out:
# Forma de los datos de intersección cargados: (1335, 115)
# Rango de fechas: 2023-01-17 17:00:00+00:00 a 2023-06-27 00:00:00+00:00

# %% [markdown]
# ## 3. Preprocesamiento de Datos

# %% [markdown]
# ### 3.1 Rellenar Marcas de Tiempo Faltantes (Dentro de Periodos Definidos)
#
# Creamos el rango de fechas completo que cubre ambos periodos conocidos de datos del camión:

# %%
df_int_reindexed = dp.fill_missing_timestamps(df_int_raw, config.PERIOD_1_START, config.PERIOD_2_END)
print(f"Forma después de reindexar a periodos combinados: {df_int_reindexed.shape}")
# Out:
# Forma después de reindexar a periodos combinados: (3840, 114)

# %% [markdown]
# Verificamos los NaNs introducidos por la reindexación:

# %%
# Verificar los NaNs introducidos
print(f"NaNs introducidos por reindexación: {df_int_reindexed.isnull().sum().sum()}")
# Out:
# NaNs introducidos por reindexación: 288216

# %%
df_int_reindexed
# Out:
#                            vehicles_PAM_1_OUT  \
# 2023-01-18 00:00:00+00:00                 0.0
# 2023-01-18 01:00:00+00:00                 NaN
# 2023-01-18 02:00:00+00:00                 NaN
# 2023-01-18 03:00:00+00:00                 NaN
# 2023-01-18 04:00:00+00:00                 NaN
# ...                                       ...
# 2023-06-26 19:00:00+00:00                 7.0
# 2023-06-26 20:00:00+00:00                 3.0
# 2023-06-26 21:00:00+00:00                 0.0
# 2023-06-26 22:00:00+00:00                 0.0
# 2023-06-26 23:00:00+00:00                 NaN
#
#                            vehicles_PAM_1_OUT_Zona_Granada  \
# 2023-01-18 00:00:00+00:00                              0.0
# 2023-01-18 01:00:00+00:00                              NaN
# 2023-01-18 02:00:00+00:00                              NaN
# 2023-01-18 03:00:00+00:00                              NaN
# 2023-01-18 04:00:00+00:00                              NaN
# ...                                                    ...
# 2023-06-26 19:00:00+00:00                              5.0
# 2023-06-26 20:00:00+00:00                              3.0
# 2023-06-26 21:00:00+00:00                              0.0
# 2023-06-26 22:00:00+00:00                              0.0
# 2023-06-26 23:00:00+00:00                              NaN
#
#                            vehicles_PAM_1_OUT_Zona_Catalunia_y_Otras  \
# 2023-01-18 00:00:00+00:00                                        0.0
# 2023-01-18 01:00:00+00:00                                        NaN
# 2023-01-18 02:00:00+00:00                                        NaN
# 2023-01-18 03:00:00+00:00                                        NaN
# 2023-01-18 04:00:00+00:00                                        NaN
# ...                                                              ...
# 2023-06-26 19:00:00+00:00                                        1.0
# 2023-06-26 20:00:00+00:00                                        0.0
# 2023-06-26 21:00:00+00:00                                        0.0
# 2023-06-26 22:00:00+00:00                                        0.0
# 2023-06-26 23:00:00+00:00                                        NaN
#
#                            vehicles_PAM_1_OUT_Zona_Andalucia_no_GR  \
# 2023-01-18 00:00:00+00:00                                      0.0
# 2023-01-18 01:00:00+00:00                                      NaN
# 2023-01-18 02:00:00+00:00                                      NaN
# 2023-01-18 03:00:00+00:00                                      NaN
# 2023-01-18 04:00:00+00:00                                      NaN
# ...                                                            ...
# 2023-06-26 19:00:00+00:00                                      0.0
# 2023-06-26 20:00:00+00:00                                      0.0
# 2023-06-26 21:00:00+00:00                                      0.0
# 2023-06-26 22:00:00+00:00                                      0.0
# 2023-06-26 23:00:00+00:00                                      NaN
00:00+00:00                          NaN  ...  NaN    NaN   NaN
# ...                                                ...  ...  ...    ...   ...
# 2023-06-26 19:00:00+00:00                          0.0  ...  1.5  111.4   7.8
# 2023-06-26 20:00:00+00:00                          0.0  ...  0.4   99.6  23.0
# 2023-06-26 21:00:00+00:00                          0.0  ...  0.1   78.8  11.3
# 2023-06-26 22:00:00+00:00                          0.0  ...  0.1   77.4   1.9
# 2023-06-26 23:00:00+00:00                          NaN  ...  NaN    NaN   NaN
#
#                            eBC_ff  eBC_bb  TEMP    RH    WS      WD   PRES
# 2023-01-18 00:00:00+00:00     NaN     NaN   6.6  52.9  3.89  114.50  878.0
# 2023-01-18 01:00:00+00:00     NaN     NaN   NaN   NaN   NaN     NaN    NaN
# 2023-01-18 02:00:00+00:00     NaN     NaN   NaN   NaN   NaN     NaN    NaN
# 2023-01-18 03:00:00+00:00     NaN     NaN   NaN   NaN   NaN     NaN    NaN
# 2023-01-18 04:00:00+00:00     NaN     NaN   NaN   NaN   NaN     NaN    NaN
# ...                           ...     ...   ...   ...   ...     ...    ...
# 2023-06-26 19:00:00+00:00     0.6     0.1  31.4  21.5  1.12  246.34  893.3
# 2023-06-26 20:00:00+00:00     0.3     0.1  28.8  26.0  0.81    7.46  893.6
# 2023-06-26 21:00:00+00:00     0.4     0.1  25.7  29.5  1.06  129.23  893.9
# 2023-06-26 22:00:00+00:00     0.2     0.1  24.7  27.9  1.25  133.45  894.3
# 2023-06-26 23:00:00+00:00     NaN     NaN   NaN   NaN   NaN     NaN    NaN
#
# [3840 rows x 114 columns]

# %% [markdown]
# ### 3.2 Dividir en Periodos
#
# Establecemos la columna de fecha como índice y dividimos el DataFrame en los dos periodos definidos en la configuración.

# %%
# Dividir en Periodos
periodo_1_raw, periodo_2_raw = dp.split_by_period(df_int_reindexed)

print(f"Forma del Periodo 1: {periodo_1_raw.shape}")
print(f"Forma del Periodo 2: {periodo_2_raw.shape}")
# Out:
# Forma del Periodo 1: (1332, 114)
# Forma del Periodo 2: (480, 114)

# %% [markdown]
# ### 3.4 Dividir, Escalar, Ventanear y Crear Ausencia para el Periodo 1
#
# Esta función ahora maneja la división train/val/test, el escalado (normalización Z-score), la creación de ventanas deslizantes (`sliding window`) y la introducción artificial de valores faltantes (`missingness`) según la configuración.

# %% [markdown]
# Para dividir el periodo del 18 de enero de 2023 al 14 de marzo de 2023 en entrenamiento, validación y prueba siguiendo un esquema análogo al del Beijing Multi-Site Air-Quality Dataset, vamos a asignar los datos de manera similar a cómo se hizo en ese conjunto.
#
# El esquema original divide los datos en tres partes:
#
# - **Fase de entrenamiento (80% del dataset):** Primeros 45 días
#    - **Training:** 80% de los 45 días: 36 días
#    - **Validación** 20% restante de los 45 días: 9 días.
# - **Prueba (20% del dataset):** 20% del dataset:  11 días.
#
# El periodo de tiempo es del 18 de enero de 2023 al 14 de marzo de 2023. **hay 56 días.**
#
# - **Conjunto de entrenamiento: 18 de enero de 2023 - 21 de febrero de 2023 (36 días)**
# - **Conjunto de validación: 22 de febrero de 2023 - 2 de marzo de 2023 (9 días)**.
# - **Conjunto de prueba: 3 de marzo de 2023 - 14 de marzo de 2023) (12 días)**

# %%
# Dividir, Escalar, Ventanear y Crear Ausencia para el Periodo 1
# Esta función ahora maneja la división train/val/test, escalado, ventaneo y creación de valores faltantes
try:
    processed_data = dp.preprocess_for_imputation(
        periodo_1_raw,
        feature_cols=config.FEATURE_COLUMNS,
        n_steps=config.N_STEPS,
        missing_rate=config.MISSING_RATE,
        missing_pattern=config.MISSING_PATTERN
        # Añadir otros argumentos de missingness si es necesario, ej., min_missing_len=...
    )
    print("Preprocesamiento completo. Estructura de datos:")
    for key, value in processed_data.items():
        if isinstance(value, np.ndarray):
            print(f"- {key}: forma {value.shape}")
        elif isinstance(value, pd.DataFrame):
            print(f"- {key}: forma {value.shape}")
        elif isinstance(value, pd.Index):
             print(f"- {key}: longitud {len(value)}")
        elif not isinstance(value, StandardScaler): # No imprimir detalles del scaler
            print(f"- {key}: {value}")

except ValueError as e:
    print(f"Error durante el preprocesamiento: {e}")
    raise
# Out:
# Introduciendo 10.0% de datos faltantes con patrón 'point'...
# Preprocesamiento completo. Estructura de datos:
# - n_steps: 24
# - n_features: 114
# - train_index: longitud 840
# - val_index: longitud 216
# - test_index: longitud 276
# - train_X_ori: forma (817, 24, 114)
# - val_X_ori: forma (193, 24, 114)
# - test_X_ori: forma (253, 24, 114)
# - train_X: forma (817, 24, 114)
# - val_X: forma (193, 24, 114)
# - test_X: forma (253, 24, 114)
# - train_X_df: forma (840, 114)
# - val_X_df: forma (216, 114)
# - test_X_df: forma (276, 114)
# - train_missing_mask: forma (817, 24, 114)
# - val_missing_mask: forma (193, 24, 114)
# - test_missing_mask: forma (253, 24, 114)
# - train_indicating_mask: forma (817, 24, 114)
# - val_indicating_mask: forma (193, 24, 114)
# - test_indicating_mask: forma (253, 24, 114)
# - n_train_samples: 817
# - n_val_samples: 193
# - n_test_samples: 253

# %% [markdown]
# Preparamos los conjuntos de datos para PyPOTS (u otras bibliotecas) si es necesario:

# %%
# Preparar datasets para PyPOTS (u otras bibliotecas) si es necesario
dataset_for_training = {"X": processed_data['train_X']}
dataset_for_validating = {"X": processed_data['val_X'], "X_ori": processed_data['val_X_ori']}
# Nota: La validación en PyPOTS usualmente necesita X_ori para calcular la pérdida sobre los valores originales
# antes del enmascaramiento, pero nuestra evaluación calcula métricas en el conjunto de test usando test_X_ori

dataset_for_testing = {
    "X": processed_data['test_X'], # Datos con NaNs para la entrada del modelo de imputación
    "X_ori": processed_data['test_X_ori'], # Datos originales (escalados) antes de enmascarar
    "indicating_mask": processed_data['test_indicating_mask'] # Máscara de los NaNs introducidos
}

# %% [markdown]
# ### 3.4 Dividir, Escalar, Ventanear y Crear Ausencia para el Periodo 2
#
# Esta función ahora maneja la división train/val/test, el escalado (normalización Z-score), la creación de ventanas deslizantes (`sliding window`) y la introducción artificial de valores faltantes (`missingness`) según la configuración.

# %%
periodo_2_raw
# Out:
#                            vehicles_PAM_1_OUT  \
# 2023-06-07 00:00:00+00:00                 NaN
# 2023-06-07 01:00:00+00:00                 0.0
# 2023-06-07 02:00:00+00:00                 NaN
# 2023-06-07 03:00:00+00:00                 NaN
# 2023-06-07 04:00:00+00:00                 NaN
# ...                                       ...
# 2023-06-26 19:00:00+00:00                 7.0
# 2023-06-26 20:00:00+00:00                 3.0
# 2023-06-26 21:00:00+00:00                 0.0
# 2023-06-26 22:00:00+00:00                 0.0
# 2023-06-26 23:00:00+00:00                 NaN
#
#                            vehicles_PAM_1_OUT_Zona_Granada  \
# 2023-06-07 04:00:00+00:00                                          NaN
# ...                                                                ...
# 2023-06-26 19:00:00+00:00                                          0.0
# 2023-06-26 20:00:00+00:00                                          0.0
# 2023-06-26 21:00:00+00:00                                          0.0
# 2023-06-26 22:00:00+00:00                                          0.0
# 2023-06-26 23:00:00+00:00                                          NaN
#
#                            vehicles_PAM_1_OUT_Zona_Otras  \
# 2023-06-07 00:00:00+00:00                            NaN
# 2023-06-07 01:00:00+00:00                            0.0
# 2023-06-07 02:00:00+00:00                            NaN
# 2023-06-07 03:00:00+00:00                            NaN
# 2023-06-07 04:00:00+00:00                            NaN
# ...                                                  ...
# 2023-06-26 19:00:00+00:00                            0.0
# 2023-06-26 20:00:00+00:00                            0.0
# 2023-06-26 21:00:00+00:00                            0.0
# 2023-06-26 22:00:00+00:00                            0.0
# 2023-06-26 23:00:00+00:00                            NaN
#
#                            vehicles_PAM_1_OUT_5_seats  \
# 2023-06-07 00:00:00+00:00                         NaN
# 2023-06-07 01:00:00+00:00                         0.0
# 2023-06-07 02:00:00+00:00                         NaN
# 2023-06-07 03:00:00+00:00                         NaN
# 2023-06-07 04:00:00+00:00                         NaN
# ...                                               ...
# 2023-06-26 19:00:00+00:00                         5.0
# 2023-06-26 20:00:00+00:00                         3.0
# 2023-06-26 21:00:00+00:00                         0.0
# 2023-06-26 22:00:00+00:00                         0.0
# 2023-06-26 23:00:00+00:00                         NaN
#
#                            vehicles_PAM_1_OUT_+5_seats  ...   NO     O3  PM10  \
# 2023-06-07 00:00:00+00:00                          NaN  ...  NaN    NaN   NaN
# 2023-06-07 01:00:00+00:00                          0.0  ...  0.1   88.3   NaN
# 2023-06-07 02:00:00+00:00                          NaN  ...  NaN    NaN   NaN
# 2023-06-07 03:00:00+00:00                          NaN  ...  NaN    NaN   NaN
# 2023-06-07 04:00:00+00:00                          NaN  ...  NaN    NaN   NaN
# ...                                                ...  ...  ...    ...   ...
# 2023-06-26 19:00:00+00:00                          0.0  ...  1.5  111.4   7.8
# 2023-06-26 20:00:00+00:00                          0.0  ...  0.4   99.6  23.0
# 2023-06-26 21:00:00+00:00                          0.0  ...  0.1   78.8  11.3
# 2023-06-26 22:00:00+00:00                          0.0  ...  0.1   77.4   1.9
# 2023-06-26 23:00:00+00:00                          NaN  ...  NaN    NaN   NaN
#
#                            eBC_ff  eBC_bb  TEMP    RH    WS      WD   PRES
# 2023-06-07 00:00:00+00:00     NaN     NaN   NaN   NaN   NaN     NaN    NaN
# 2023-06-07 01:00:00+00:00     0.1     0.1  16.7  68.5  2.08  116.29  887.5
# 2023-06-07 02:00:00+00:00     NaN     NaN   NaN   NaN   NaN     NaN    NaN
# 2023-06-07 03:00:00+00:00     NaN     NaN   NaN   NaN   NaN     NaN    NaN
# 2023-06-07 04:00:00+00:00     NaN     NaN   NaN   NaN   NaN     NaN    NaN
# ...                           ...     ...   ...   ...   ...     ...    ...
# 2023-06-26 19:00:00+00:00     0.6     0.1  31.4  21.5  1.12  246.34  893.3
# 2023-06-26 20:00:00+00:00     0.3     0.1  28.8  26.0  0.81    7.46  893.6
# 2023-06-26 21:00:00+00:00     0.4     0.1  25.7  29.5  1.06  129.23  893.9
# 2023-06-26 22:00:00+00:00     0.2     0.1  24.7  27.9  1.25  133.45  894.3
# 2023-06-26 23:00:00+00:00     NaN     NaN   NaN   NaN   NaN     NaN    NaN
#
# [480 rows x 114 columns]

# %% [markdown]
# ### Fechas de división del periodo 2 (20 días)

# %% [markdown]
# - 80% del dataset Fase de entrenamiento: 16 días
#     - **Training:** 80% de 16: **13 días** (2023-06-07 al 2023-06-19)
#     - **Validación:** 20% de 16: **3 días** (2023-06-20 al 2023-06-22)
# - 20% del dataset **Testing**: **4 días** (2023-06-23 al 2023-06-26)

# %%
# Dividir, Escalar, Ventanear y Crear Ausencia para el Periodo 1
# Esta función ahora maneja la división train/val/test, escalado, ventaneo y creación de valores faltantes
try:
    processed_data2 = dp.preprocess_for_imputation(
        periodo_2_raw,
        feature_cols=config.FEATURE_COLUMNS,
        n_steps=config.N_STEPS,
        missing_rate=config.MISSING_RATE,
        missing_pattern=config.MISSING_PATTERN,
        train_starn=config.TRAIN_2_START_DATE,
        train_end=config.TRAIN_2_END_DATE,
        val_start=config.VAL_2_START_DATE,
        val_end=config.VAL_2_END_DATE,
        test_start=config.TEST_2_START_DATE,
        test_end=config.TEST_2_END_DATE,
        # Añadir otros argumentos de missingness si es necesario, ej., min_missing_len=...
    )
    print("Preprocesamiento completo. Estructura de datos:")
    for key, value in processed_data.items():
        if isinstance(value, np.ndarray):
            print(f"- {key}: forma {value.shape}")
        elif isinstance(value, pd.DataFrame):
            print(f"- {key}: forma {value.shape}")
        elif isinstance(value, pd.Index):
             print(f"- {key}: longitud {len(value)}")
        elif not isinstance(value, StandardScaler): # No imprimir detalles del scaler
            print(f"- {key}: {value}")

except ValueError as e:
    print(f"Error durante el preprocesamiento: {e}")
    raise
# Out:
# Introduciendo 10.0% de datos faltantes con patrón 'point'...
# Preprocesamiento completo. Estructura de datos:
# - n_steps: 24
# - n_features: 114
# - train_index: longitud 840
# - val_index: longitud 216
# - test_index: longitud 276
# - train_X_ori: forma (817, 24, 114)
# - val_X_ori: forma (193, 24, 114)
# - test_X_ori: forma (253, 24, 114)
# - train_X: forma (817, 24, 114)
# - val_X: forma (193, 24, 114)
# - test_X: forma (253, 24, 114)
# - train_X_df: forma (840, 114)
# - val_X_df: forma (216, 114)
# - test_X_df: forma (276, 114)
# - train_missing_mask: forma (817, 24, 114)
# - val_missing_mask: forma (193, 24, 114)
# - test_missing_mask: forma (253, 24, 114)
# - train_indicating_mask: forma (817, 24, 114)
# - val_indicating_mask: forma (193, 24, 114)
# - test_indicating_mask: forma (253, 24, 114)
# - n_train_samples: 817
# - n_val_samples: 193
# - n_test_samples: 253

# %%
# Preparar datasets para PyPOTS (u otras bibliotecas) si es necesario
dataset_for_training2 = {"X": processed_data2['train_X']}
dataset_for_validating2 = {"X": processed_data2['val_X'], "X_ori": processed_data2['val_X_ori']}
# Nota: La validación en PyPOTS usualmente necesita X_ori para calcular la pérdida sobre los valores originales
# antes del enmascaramiento, pero nuestra evaluación calcula métricas en el conjunto de test usando test_X_ori

dataset_for_testing2 = {
    "X": processed_data2['test_X'], # Datos con NaNs para la entrada del modelo de imputación
    "X_ori": processed_data2['test_X_ori'], # Datos originales (escalados) antes de enmascarar
    "indicating_mask": processed_data2['test_indicating_mask'] # Máscara de los NaNs introducidos
}

# %% [markdown]
# ## 4. Métodos de Imputación para Periodo 1
#
# Aplicamos métodos base a los datos del conjunto de test (`dataset_for_testing['X']`). Almacenamos los resultados en un diccionario.

# %%
# Aplicar métodos base a los datos del conjunto de test (`dataset_for_testing['X']`)
X_test_missing = dataset_for_testing['X']
imputed_results = {} # Diccionario para almacenar resultados

print("\nEjecutando métodos de imputación base...")
# Out:
# Ejecutando métodos de imputación base...

# %% [markdown]
# ### 4.1. Modelos Baseline

# %% [markdown]
# ####
# 4.1 Imputación por Mediana
#
# Rellenamos los valores faltantes utilizando la mediana de cada característica (columna) calculada sobre todo el conjunto de datos de test (a través de todas las muestras y pasos de tiempo).

# %%
imputed_results['median'] = im.impute_median_sample_wise(X_test_missing)
print(f"Forma imputación mediana: {imputed_results['median'].shape}, NaNs: {np.isnan(imputed_results['median']).sum()}")
# Out:
# Forma imputación mediana: (253, 24, 114), NaNs: 0

# %% [markdown]
# #### 4.2 Imputación por Media
#
# Similar a la mediana, pero usamos la media de cada característica para rellenar los valores faltantes.

# %%
imputed_results['mean'] = im.impute_mean_sample_wise(X_test_missing)
print(f"Forma imputación media: {imputed_results['mean'].shape}, NaNs: {np.isnan(imputed_results['mean']).sum()}")
# Out:
# Forma imputación media: (253, 24, 114), NaNs: 0

# %% [markdown]
# #### 4.3 Interpolación Lineal
#
# Rellenamos los valores faltantes mediante interpolación lineal a lo largo del eje temporal (pasos de tiempo) para cada muestra y característica de forma independiente.

# %%
imputed_results['linear'] = im.impute_linear(X_test_missing)
print(f"Forma imputación lineal: {imputed_results['linear'].shape}, NaNs: {np.isnan(imputed_results['linear']).sum()}")
# Out:
# Forma imputación lineal: (253, 24, 114), NaNs: 0

# %% [markdown]
# #### 4.4 Relleno Forward/Backward (ffill/bfill)
#
# Nota: Estos métodos pueden requerir eliminar columnas como `WS`, `WD` si causan problemas o no son necesarias. La función de imputación en sí no elimina columnas, pero la evaluación podría necesitar alineación. Asumiremos por ahora que imputamos todas las características. La evaluación maneja la posible eliminación de columnas. Alternativamente, modificamos los datos de entrada antes de pasarlos a la imputación:

# %%
# ### 4.4 Relleno Forward/Backward (ffill/bfill)
# Nota: Estos métodos pueden requerir eliminar columnas como WS, WD si causan problemas.
# Modificamos los datos de entrada si es necesario:
X_test_missing_no_ws_wd = X_test_missing.copy()
cols_to_drop_indices = [config.FEATURE_COLUMNS.index(col) for col in config.COLS_TO_DROP_FOR_BASELINE if col in config.FEATURE_COLUMNS]

if cols_to_drop_indices:
    print(f"Eliminando columnas en índices {cols_to_drop_indices} para métodos Fill.")
    X_test_missing_no_ws_wd = np.delete(X_test_missing, cols_to_drop_indices, axis=2)
else:
    X_test_missing_no_ws_wd = X_test_missing # No hay columnas que eliminar

imputed_results['ffill'] = im.impute_forward(X_test_missing_no_ws_wd)
imputed_results['bfill'] = im.impute_backward(X_test_missing_no_ws_wd)
print(f"Forma imputación Forward fill {imputed_results['ffill'].shape}, NaNs: {np.isnan(imputed_results['ffill']).sum()}")
print(f"Forma imputación Backward fill: {imputed_results['bfill'].shape}, NaNs: {np.isnan(imputed_results['bfill']).sum()}")
# Out:
# Eliminando columnas en índices [111, 112] para métodos Fill.
# Forma imputación Forward fill (253, 24, 112), NaNs: 0
# Forma imputación Backward fill: (253, 24, 112), NaNs: 0

# %% [markdown]
# ### 4.5. Modelo Transformer

# %%
from pampaneira_imputation import config

transformer_config = config.TRANSFORMER_PARAMS.copy()
transformer_config['n_features'] = processed_data['n_features']  # Set dynamically
    
# Initialize the Transformer model
transformer_model = Transformer(**transformer_config)
    
# Set up optimizer, scheduler, and loss function
optimizer = Adam(transformer_model.model.parameters(), **config.TRANSFORMER_OPTIMIZER_PARAMS)
scheduler = ReduceLROnPlateau(optimizer, **config.TRANSFORMER_SCHEDULER_PARAMS)
loss_func = SmoothL1Loss(**config.TRANSFORMER_LOSS_PARAMS)
    
# Train the model
print("Training Transformer model...")
transformer_model.fit(
        train_set=dataset_for_training,
        val_set=dataset_for_validating,  # Pass validation set for early stopping
)
print("Transformer training complete.")

# Predecir (imputar) en el conjunto de test
print("Imputando con Transformer en el conjunto de test...")
transformer_prediction = transformer_model.predict(dataset_for_testing)
imputed_results['transformer'] = transformer_prediction["imputation"]
print(f"Forma imputación Transformer: {imputed_results['transformer'].shape}, NaNs: {np.isnan(imputed_results['transformer']).sum()}")
# Out:
# 2025-04-19 21:30:49 [INFO]: No given device, using default device: cpu
# 2025-04-19 21:30:49 [INFO]: Model files will be saved to ../results/imputation/transformer/20250419_T213049
# 2025-04-19 21:30:49 [INFO]: Tensorboard file will be saved to ../results/imputation/transformer/20250419_T213049/tensorboard
# 2025-04-19 21:30:49 [INFO]: Using customized MAE as the training loss function.
# 2025-04-19 21:30:49 [INFO]: Using customized MSE as the validation metric function.
# 2025-04-19 21:30:49 [INFO]: Transformer initialized with the given hyperparameters, the number of trainable parameters: 439,922
# Training Transformer model...
# 2025-04-19 21:30:50 [INFO]: Epoch 001 - training loss (MAE): 1.3038, validation MSE: 1.1504
# 2025-04-19 21:30:51 [INFO]: Epoch 002 - training loss (MAE): 0.9654, validation MSE: 1.1207
# 2025-04-19 21:30:52 [INFO]: Epoch 003 - training loss (MAE): 0.9067, validation MSE: 1.0602
# 2025-04-19 21:30:53 [INFO]: Epoch 004 - training loss (MAE): 0.8673, validation MSE: 1.0086
# 2025-04-19 21:30:54 [INFO]: Epoch 005 - training loss (MAE): 0.8229, validation MSE: 0.9465
# 2025-04-19 21:30:55 [INFO]: Epoch 006 - training loss (MAE): 0.7837, validation MSE: 0.8985
# 2025-04-19 21:30:56 [INFO]: Epoch 007 - training loss (MAE): 0.7498, validation MSE: 0.8706
# 2025-04-19 21:30:56 [INFO]: Epoch 008 - training loss (MAE): 0.7245, validation MSE: 0.8614
# 2025-04-19 21:30:57 [INFO]: Epoch 009 - training loss (MAE): 0.7024, validation MSE: 0.8490
# 2025-04-19 21:30:58 [INFO]: Epoch 010 - training loss (MAE): 0.6850, validation MSE: 0.8333
# 2025-04-19 21:30:59 [INFO]: Epoch 011 - training loss (MAE): 0.6713, validation MSE: 0.8337
# 2025-04-19 21:31:00 [INFO]: Epoch 012 - training loss (MAE): 0.6591, validation MSE: 0.8202
# 2025-04-19 21:31:01 [INFO]: Epoch 013 - training loss (MAE): 0.6457, validation MSE: 0.8127
# 2025-04-19 21:31:28 [INFO]: Epoch 042 - training loss (MAE): 0.4924, validation MSE: 0.7272
# 2025-04-19 21:31:30 [INFO]: Epoch 043 - training loss (MAE): 0.4916, validation MSE: 0.7268
# 2025-04-19 21:31:31 [INFO]: Epoch 044 - training loss (MAE): 0.4860, validation MSE: 0.7294
# 2025-04-19 21:31:31 [INFO]: Epoch 045 - training loss (MAE): 0.4846, validation MSE: 0.7325
# 2025-04-19 21:31:32 [INFO]: Epoch 046 - training loss (MAE): 0.4823, validation MSE: 0.7290
# 2025-04-19 21:31:33 [INFO]: Epoch 047 - training loss (MAE): 0.4783, validation MSE: 0.7330
# 2025-04-19 21:31:34 [INFO]: Epoch 048 - training loss (MAE): 0.4784, validation MSE: 0.7314
# 2025-04-19 21:31:34 [INFO]: Exceeded the training patience. Terminating the training procedure...
# 2025-04-19 21:31:34 [INFO]: Finished training. The best model is from epoch#43.
# 2025-04-19 21:31:34 [INFO]: Saved the model to ../results/imputation/transformer/20250419_T213049/Transformer.pypots
# Transformer training complete.
# Imputando con Transformer en el conjunto de test...
# Forma imputación Transformer: (253, 24, 114), NaNs: 0

# %% [markdown]
# ### 4.6. Modelo SAITS
#
# Si la biblioteca `pypots` está disponible, configuramos y entrenamos un modelo SAITS (Self-Attention based Imputation for Time Series) usando los datos de entrenamiento y validación preprocesados. Luego, usamos el modelo entrenado para imputar los valores faltantes en el conjunto de test.

# %%
# ## 5. Imputación con SAITS (Requiere PyPOTS)

if SAITS is not None:
    print("\nConfigurando y ejecutando imputación con SAITS...")
    # Configurar modelo SAITS
    saits_config = config.SAITS_PARAMS.copy()
    saits_config['n_features'] = processed_data['n_features'] # Establecer dinámicamente

    saits_model = SAITS(**saits_config)

    # Configurar optimizador, planificador y función de pérdida
    optimizer = Adam(saits_model.model.parameters(), **config.SAITS_OPTIMIZER_PARAMS)
    scheduler = ReduceLROnPlateau(optimizer, **config.SAITS_SCHEDULER_PARAMS)
    loss_func = SmoothL1Loss(**config.SAITS_LOSS_PARAMS)

    # Entrenar el modelo
    # Nota: Podrías querer ajustar epochs/patience para ejecuciones más rápidas
    print("Entrenando modelo SAITS...")
    saits_model.fit(
        train_set=dataset_for_training,
        val_set=dataset_for_validating, # Pasar conjunto de validación para early stopping
        )
    print("Entrenamiento de SAITS completo.")

    # Predecir (imputar) en el conjunto de test
    print("Imputando con SAITS en el conjunto de test...")
    saits_prediction = saits_model.predict(dataset_for_testing)
    imputed_results['saits'] = saits_prediction["imputation"]
    print(f"Forma imputación SAITS: {imputed_results['saits'].shape}, NaNs: {np.isnan(imputed_results['saits']).sum()}")

else:
    print("\nSaltando imputación con SAITS ya que pypots no está instalado.")
# Out:
# 2025-04-19 21:31:34 [INFO]: No given device, using default device: cpu
# 2025-04-19 21:31:34 [INFO]: Model files will be saved to ../results/imputation/saits/20250419_T213134
# 2025-04-19 21:31:34 [INFO]: Tensorboard file will be saved to ../results/imputation/saits/20250419_T213134/tensorboard
# 2025-04-19 21:31:34 [INFO]: Using customized MAE as the training loss function.
# 2025-04-19 21:31:34 [INFO]: Using customized MSE as the validation metric function.
# 2025-04-19 21:31:34 [WARNING]: ‼️ d_model must = n_heads * d_k, it should be divisible by n_heads and the result should be equal to d_k, but got d_model=192, n_heads=4, d_k=32
# 2025-04-19 21:31:34 [WARNING]: ⚠️ d_model is reset to 128 = n_heads (4) * d_k (32)
# 2025-04-19 21:31:35 [INFO]: SAITS initialized with the given hyperparameters, the number of trainable parameters:
# 2025-04-19 21:32:45 [INFO]: Epoch 026 - training loss (MAE): 0.5410, validation MSE: 0.7240
# 2025-04-19 21:32:48 [INFO]: Epoch 027 - training loss (MAE): 0.5357, validation MSE: 0.7192
# 2025-04-19 21:32:50 [INFO]: Epoch 028 - training loss (MAE): 0.5299, validation MSE: 0.7188
# 2025-04-19 21:32:52 [INFO]: Epoch 029 - training loss (MAE): 0.5246, validation MSE: 0.7126
# 2025-04-19 21:32:55 [INFO]: Epoch 030 - training loss (MAE): 0.5215, validation MSE: 0.7115
# 2025-04-19 21:32:57 [INFO]: Epoch 031 - training loss (MAE): 0.5164, validation MSE: 0.7155
# 2025-04-19 21:33:00 [INFO]: Epoch 032 - training loss (MAE): 0.5116, validation MSE: 0.7139
# 2025-04-19 21:33:02 [INFO]: Epoch 033 - training loss (MAE): 0.5061, validation MSE: 0.7091
# 2025-04-19 21:33:05 [INFO]: Epoch 034 - training loss (MAE): 0.5041, validation MSE: 0.7019
# 2025-04-19 21:33:08 [INFO]: Epoch 035 - training loss (MAE): 0.4996, validation MSE: 0.7105
# 2025-04-19 21:33:10 [INFO]: Epoch 036 - training loss (MAE): 0.4947, validation MSE: 0.7121
# 2025-04-19 21:33:13 [INFO]: Epoch 037 - training loss (MAE): 0.4916, validation MSE: 0.7095
# 2025-04-19 21:33:15 [INFO]: Epoch 038 - training loss (MAE): 0.4905, validation MSE: 0.7100
# 2025-04-19 21:33:18 [INFO]: Epoch 039 - training loss (MAE): 0.4845, validation MSE: 0.7086
# 2025-04-19 21:33:18 [INFO]: Exceeded the training patience. Terminating the training procedure...
# 2025-04-19 21:33:18 [INFO]: Finished training. The best model is from epoch#34.
# 2025-04-19 21:33:18 [INFO]: Saved the model to ../results/imputation/saits/20250419_T213134/SAITS.pypots
# Entrenamiento de SAITS completo.
# Imputando con SAITS en el conjunto de test...
# Forma imputación SAITS: (253, 24, 114), NaNs: 0

# %% [markdown]
# ## 5. Métodos de Imputación para Periodo 2
#
# Aplicamos métodos base a los datos del conjunto de test (`dataset_for_testing2['X']`). Almacenamos los resultados en un diccionario.

# %%
# Aplicar métodos base a los datos del conjunto de test (`dataset_for_testing['X']`)
X_test_missing2 = dataset_for_testing2['X']
imputed_results2 = {} # Diccionario para almacenar resultados

print("\nEjecutando métodos de imputación base...")
# Out:
# Ejecutando métodos de imputación base...

# %% [markdown]
# ### 5.1. Modelos Baseline

# %% [markdown]
# #### 5.1.1 Imputación por Mediana en Periodo 2
#
# Rellenamos los valores faltantes utilizando la mediana de cada característica (columna) calculada sobre todo el conjunto de datos de test (a través de todas las muestras y pasos de tiempo).

# %%
imputed_results2['median'] = im.impute_median_sample_wise(X_test_missing2)
print(f"Forma imputación mediana: {imputed_results2['median'].shape}, NaNs: {np.isnan(imputed_results2['median']).sum()}")
# Out:
# Forma imputación mediana: (73, 24, 114), NaNs: 0

# %% [markdown]
# #### 5.1.2 Imputación por Media en Periodo 2
#
# Similar a la mediana, pero usamos la media de cada característica para rellenar los valores faltantes.

# %%
imputed_results2['mean'] = im.impute_mean_sample_wise(X_test_missing2)
print(f"Forma imputación media: {imputed_results2['mean'].shape}, NaNs: {np.isnan(imputed_results2['mean']).sum()}")
# Out:
# Forma imputación media: (73, 24, 114), NaNs: 0

# %% [markdown]
# #### 5.1.3 Interpolación Lineal en Periodo 2
#
# Rellenamos los valores faltantes mediante interpolación lineal a lo largo del eje temporal (pasos de tiempo) para cada muestra y característica de forma independiente.

# %%
imputed_results2['linear'] = im.impute_linear(X_test_missing2)
print(f"Forma imputación lineal: {imputed_results2['linear'].shape}, NaNs: {np.isnan(imputed_results2['linear']).sum()}")
# Out:
# Forma imputación lineal: (73, 24, 114), NaNs: 0

# %% [markdown]
# #### 5.1.4 Relleno Forward/Backward (ffill/bfill) en Periodo 2

# %%
# ### 4.4 Relleno Forward/Backward (ffill/bfill)
# Nota: Estos métodos pueden requerir eliminar columnas como WS, WD si causan problemas.
# Modificamos los datos de entrada si es necesario:
X_test_missing2_no_ws_wd = X_test_missing2.copy()
cols_to_drop_indices = [config.FEATURE_COLUMNS.index(col) for col in config.COLS_TO_DROP_FOR_BASELINE if col in config.FEATURE_COLUMNS]

if cols_to_drop_indices:
    print(f"Eliminando columnas en índices {cols_to_drop_indices} para métodos Fill.")
    X_test_missing2_no_ws_wd = np.delete(X_test_missing2, cols_to_drop_indices, axis=2)
else:
    X_test_missing2_no_ws_wd = X_test_missing2 # No hay columnas que eliminar

imputed_results2['ffill'] = im.impute_forward(X_test_missing2_no_ws_wd)
imputed_results2['bfill'] = im.impute_backward(X_test_missing2_no_ws_wd)
print(f"Forma imputación Forward fill {imputed_results2['ffill'].shape}, NaNs: {np.isnan(imputed_results2['ffill']).sum()}")
print(f"Forma imputación Backward fill: {imputed_results2['bfill'].shape}, NaNs: {np.isnan(imputed_results2['bfill']).sum()}")
# Out:
# Eliminando columnas en índices [111, 112] para métodos Fill.
# Forma imputación Forward fill (73, 24, 112), NaNs: 0
# Forma imputación Backward fill: (73, 24, 112), NaNs: 0

# %%
print(dataset_for_training2['X'].shape)
print(dataset_for_validating2['X'].shape)
print(dataset_for_testing['X'].shape)
# Out:
# (289, 24, 114)
# (49, 24, 114)
# (253, 24, 114)

# %% [markdown]
# ### 5.2. Modelo Transformer

# %%
from pampaneira_imputation import config

transformer_config = config.TRANSFORMER_PARAMS.copy()
transformer_config['n_features'] = processed_data2['n_features']  # Set dynamically
    
# Initialize the Transformer model
transformer_model = Transformer(**transformer_config)
    
# Set up optimizer, scheduler, and loss function
optimizer = Adam(transformer_model.model.parameters(), **config.TRANSFORMER_OPTIMIZER_PARAMS)
scheduler = ReduceLROnPlateau(optimizer, **config.TRANSFORMER_SCHEDULER_PARAMS)
loss_func = SmoothL1Loss(**config.TRANSFORMER_LOSS_PARAMS)
    
# Train the model
print("Training Transformer model...")
transformer_model.fit(
        train_set=dataset_for_training2,
        val_set=dataset_for_validating2,  # Pass validation set for early stopping
)
print("Transformer training complete.")

# Predecir (imputar) en el conjunto de test
print("Imputando con SAITS en el conjunto de test...")
transformer_prediction2 = transformer_model.predict(dataset_for_testing2)
imputed_results2['transformer'] = transformer_prediction2["imputation"]
print(f"Forma imputación Transformer: {imputed_results2['transformer'].shape}, NaNs: {np.isnan(imputed_results2['transformer']).sum()}")
# 2025-04-19 21:33:29 [INFO]: Epoch 024 - training loss (MAE): 0.7511, validation MSE: 0.4031
# 2025-04-19 21:33:30 [INFO]: Epoch 025 - training loss (MAE): 0.7403, validation MSE: 0.4044
# 2025-04-19 21:33:30 [INFO]: Epoch 026 - training loss (MAE): 0.7334, validation MSE: 0.4087
# 2025-04-19 21:33:31 [INFO]: Epoch 027 - training loss (MAE): 0.7245, validation MSE: 0.4083
# 2025-04-19 21:33:31 [INFO]: Epoch 028 - training loss (MAE): 0.7223, validation MSE: 0.4010
# 2025-04-19 21:33:32 [INFO]: Epoch 029 - training loss (MAE): 0.7097, validation MSE: 0.3968
# 2025-04-19 21:33:32 [INFO]: Epoch 030 - training loss (MAE): 0.7058, validation MSE: 0.3978
# 2025-04-19 21:33:33 [INFO]: Epoch 031 - training loss (MAE): 0.6999, validation MSE: 0.3939
# 2025-04-19 21:33:33 [INFO]: Epoch 032 - training loss (MAE): 0.6935, validation MSE: 0.3984
# 2025-04-19 21:33:34 [INFO]: Epoch 033 - training loss (MAE): 0.6829, validation MSE: 0.3982
# 2025-04-19 21:33:34 [INFO]: Epoch 034 - training loss (MAE): 0.6776, validation MSE: 0.4008
# 2025-04-19 21:33:34 [INFO]: Epoch 035 - training loss (MAE): 0.6784, validation MSE: 0.3991
# 2025-04-19 21:33:35 [INFO]: Epoch 036 - training loss (MAE): 0.6654, validation MSE: 0.3944
# 2025-04-19 21:33:35 [INFO]: Exceeded the training patience. Terminating the training procedure...
# 2025-04-19 21:33:35 [INFO]: Finished training. The best model is from epoch#31.
# 2025-04-19 21:33:35 [INFO]: Saved the model to ../results/imputation/transformer/20250419_T213319/Transformer.pypots
# Transformer training complete.
# Imputando con SAITS en el conjunto de test...
# Forma imputación Transformer: (73, 24, 114), NaNs: 0

# %% [markdown]
# ### 5.3. Modelo SAITS
#
# Si la biblioteca `pypots` está disponible, configuramos y entrenamos un modelo SAITS (Self-Attention based Imputation for Time Series) usando los datos de entrenamiento y validación preprocesados. Luego, usamos el modelo entrenado para imputar los valores faltantes en el conjunto de test.

# %%
# ## 5. Imputación con SAITS (Requiere PyPOTS)

if SAITS is not None:
    print("\nConfigurando y ejecutando imputación con SAITS...")
    # Configurar modelo SAITS
    saits_config = config.SAITS_PARAMS.copy()
    saits_config['n_features'] = processed_data2['n_features'] # Establecer dinámicamente

    saits_model = SAITS(**saits_config)

    # Configurar optimizador, planificador y función de pérdida
    optimizer = Adam(saits_model.model.parameters(), **config.SAITS_OPTIMIZER_PARAMS)
    scheduler = ReduceLROnPlateau(optimizer, **config.SAITS_SCHEDULER_PARAMS)
    loss_func = SmoothL1Loss(**config.SAITS_LOSS_PARAMS)

    # Entrenar el modelo
    # Nota: Podrías querer ajustar epochs/patience para ejecuciones más rápidas
    print("Entrenando modelo SAITS...")
    saits_model.fit(
        train_set=dataset_for_training2,
        val_set=dataset_for_validating2, # Pasar conjunto de validación para early stopping
        )
    print("Entrenamiento de SAITS completo.")

    # Predecir (imputar) en el conjunto de test
    print("Imputando con SAITS en el conjunto de test...")
    saits_prediction = saits_model.predict(dataset_for_testing2)
    imputed_results2['saits'] = saits_prediction["imputation"]
    print(f"Forma imputación SAITS: {imputed_results2['saits'].shape}, NaNs: {np.isnan(imputed_results2['saits']).sum()}")

else:
    print("\nSaltando imputación con SAITS ya que pypots no está instalado.")
# Out:
# 2025-04-19 21:33:35 [INFO]: No given device, using default device: cpu
# 2025-04-19 21:33:35 [INFO]: Model files will be saved to ../results/imputation/saits/20250419_T213335
# 2025-04-19 21:33:35 [INFO]: Tensorboard file will be saved to ../results/imputation/saits/20250419_T213335/tensorboard
# 2025-04-19 21:33:35 [INFO]: Using customized MAE as the training loss function.
# 2025-04-19 21:33:35 [INFO]: Using customized MSE as the validation metric function.
# 2025-04-19 21:33:35 [WARNING]: ‼️ d_model must = n_heads * d_k, it should be divisible by n_heads and the result should be equal to d_k, but got d_model=192, n_heads=4, d_k=32
# 2025-04-19 21:33:35 [WARNING]: ⚠️ d_model is reset to 128 = n_heads (4) * d_k (32)
# 2025-04-19 21:33:35 [INFO]: SAITS initialized with the given hyperparameters, the number of trainable parameters: 1,172,736
# Configurando y ejecutando imputación con SAITS...
# Entrenando modelo SAITS...
# 2025-04-19 21:33:36 [INFO]: Epoch 001 - training loss (MAE): 1.4582, validation MSE: 0.6705
# 2025-04-19 21:33:38 [INFO]: Epoch 002 - training loss (MAE): 1.2142, validation MSE: 0.5606
# 2025-04-19 21:33:39 [INFO]: Epoch 003 - training loss (MAE): 1.0644, validation MSE: 0.5144
# 2025-04-19 21:33:40 [INFO]: Epoch 004 - training loss (MAE): 0.9938, validation MSE: 0.5049
# 2025-04-19 21:33:41 [INFO]: Epoch 005 - training loss (MAE): 0.9522, validation MSE: 0.4964
# 2025-04-19 21:33:42 [INFO]: Epoch 006 - training loss (MAE): 0.9328, validation MSE: 0.4922
# 2025-04-19 21:33:43 [INFO]: Epoch 007 - training loss (MAE): 0.9130, validation MSE: 0.4928
# 2025-04-19 21:33:44 [INFO]: Epoch 008 - training loss (MAE): 0.9050, validation MSE: 0.4863
# 2025-04-19 21:33:45 [INFO]: Epoch 009 - training loss (MAE): 0.8833, validation MSE: 0.4836
# 2025-04-19 21:33:46 [INFO]: Epoch 010 - training loss (MAE): 0.8700, validation MSE: 0.4771
# 2025-04-19 21:33:47 [INFO]: Epoch 011 - training loss (MAE): 0.8494, validation MSE: 0.4755
# 2025-04-19 21:33:48 [INFO]: Epoch 012 - training loss (MAE): 0.8376, validation MSE: 0.4667
# 2025-04-19 21:33:49 [INFO]: Epoch 013 - training loss (MAE): 0.8258, validation MSE: 0.4593
# 2025-04-19 21:33:49 [INFO]: Epoch 014 - training loss (MAE): 0.8121, validation MSE: 0.4521
# 2025-04-19 21:33:50 [INFO]: Epoch 015 - training loss (MAE): 0.8006, validation MSE: 0.4437
# 2025-04-19 21:33:51 [INFO]: Epoch 016 - training loss (MAE): 0.7917, validation MSE: 0.4287
# 2025-04-19 21:33:52 [INFO]: Epoch 017 - training loss (MAE): 0.7848, validation MSE: 0.4210
# 2025-04-19 21:33:53 [INFO]: Epoch 018 - training loss (MAE): 0.7704, validation MSE: 0.4113
# 2025-04-19 21:33:54 [INFO]: Epoch 019 - training loss (MAE): 0.7587, validation MSE: 0.4088
# 2025-04-19 21:33:55 [INFO]: Epoch 020 - training loss (MAE): 0.7467, validation MSE: 0.4070
# 2025-04-19 21:33:56 [INFO]: Epoch 021 - training loss (MAE): 0.7423, validation MSE: 0.4082
# 2025-04-19 21:33:57 [INFO]: Epoch 022 - training loss (MAE): 0.7335, validation MSE: 0.4055
# 2025-04-19 21:33:58 [INFO]: Epoch 023 - training loss (MAE): 0.7215, validation MSE: 0.4054
# 2025-04-19 21:33:59 [INFO]: Epoch 024 - training loss (MAE): 0.7156, validation MSE: 0.4029
# 2025-04-19 21:34:00 [INFO]: Epoch 025 - training loss (MAE): 0.7082, validation MSE: 0.4066
# 2025-04-19 21:34:01 [INFO]: Epoch 026 - training loss (MAE): 0.7007, validation MSE: 0.4039
# 2025-04-19 21:34:01 [INFO]: Epoch 027 - training loss (MAE): 0.6945, validation MSE: 0.4005
# 2025-04-19 21:34:02 [INFO]: Epoch 028 - training loss (MAE): 0.6859, validation MSE: 0.3998
# 2025-04-19 21:34:03 [INFO]: Epoch 029 - training loss (MAE): 0.6808, validation MSE: 0.4050
# 2025-04-19 21:34:04 [INFO]: Epoch 030 - training loss (MAE): 0.6692, validation MSE: 0.3967
# 2025-04-19 21:34:05 [INFO]: Epoch 031 - training loss (MAE): 0.6642, validation MSE: 0.3970
# 2025-04-19 21:34:07 [INFO]: Epoch 032 - training loss (MAE): 0.6570, validation MSE: 0.3972
# 2025-04-19 21:34:08 [INFO]: Epoch 033 - training loss (MAE): 0.6547, validation MSE: 0.3988
# 2025-04-19 21:34:09 [INFO]: Epoch 034 - training loss (MAE): 0.6436, validation MSE: 0.3971
# 2025-04-19 21:34:10 [INFO]: Epoch 035 - training loss (MAE): 0.6381, validation MSE: 0.3977
# 2025-04-19 21:34:10 [INFO]: Exceeded the training patience. Terminating the training procedure...
# 2025-04-19 21:34:10 [INFO]: Finished training. The best model is from epoch#30.
# 2025-04-19 21:34:10 [INFO]: Saved the model to ../results/imputation/saits/20250419_T213335/SAITS.pypots
# Entrenamiento de SAITS completo.
# Imputando con SAITS en el conjunto de test...
# Forma imputación SAITS: (73, 24, 114), NaNs: 0

# %% [markdown]
# ## 6. Evaluar Resultados de Imputación en Periodo 1
#
# Evaluamos el rendimiento de cada método de imputación utilizando métricas estándar (MAE, MSE, RMSE, MRE) calculadas únicamente sobre los valores que fueron originalmente faltantes (indicados por `indicating_mask`). Comparamos los valores imputados (`y_pred`) con los valores verdaderos originales (`y_true`, correspondientes a `test_X_ori`).

# %%
print("\nEvaluando rendimiento de imputación en el conjunto de test...")
import pampaneira_imputation.evaluation as ev

# Usar la función del módulo de evaluación
# Requiere el diccionario de datos preprocesados (para ground truth y máscara)
# y el diccionario de resultados imputados
evaluation_table = ev.evaluate_all_methods(
    processed_data,
    imputed_results,
    methods_to_evaluate=list(imputed_results.keys()) # Evaluar todos los métodos calculados
)

evaluation_table.T
# Out:
# Evaluando rendimiento de imputación en el conjunto de test...
#
# Calculando métricas para: median
#
# Calculando métricas para: mean
#
# Calculando métricas para: linear
#
# Calculando métricas para: ffill
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 6
#       1 print("\nEvaluando rendimiento de imputación en el conjunto de test...")
#       3 # Usar la función del módulo de evaluación
#       4 # Requiere el diccionario de datos preprocesados (para ground truth y máscara)
#       5 # y el diccionario de resultados imputados
# ----> 6 evaluation_table = ev.evaluate_all_methods(
#       7     processed_data,
#       8     imputed_results,
#       9     methods_to_evaluate=list(imputed_results.keys()) # Evaluar todos los métodos calculados
#      10 )
#      12 evaluation_table.T
#
# File ~/Library/CloudStorage/Dropbox/dgiim/TFG/pampaneira_imputation/evaluation.py:99, in evaluate_all_methods(preprocessed_data, imputed_results, methods_to_evaluate)
#      96          # y_pred para estos métodos ya debería tener las columnas eliminadas
#      98     print(f"\nCalculando métricas para: {method_name}")
# ---> 99     metrics = calculate_imputation_metrics(current_y_true, y_pred, current_mask)
#     101     results.append({
#     102         "Method": method_name.replace('_', ' ').title(),  # Nombre más bonito
#     103         "RMSE": metrics.get('rmse', np.nan),
#    (...)    106         "MRE": metrics.get('mre', np.nan)
#     107     })
#     109 error_table = pd.DataFrame.from_records(results)
#
# File ~/Library/CloudStorage/Dropbox/dgiim/TFG/pampaneira_imputation/evaluation.py:34, in calculate_imputation_metrics(y_true, y_pred, indicating_mask)
#      31 y_true_filled = np.nan_to_num(y_true, nan=0.0)
#      33 if y_true.shape != y_pred.shape or y_true.shape != indicating_mask.shape:
# ---> 34     raise ValueError(f"Desajuste de forma: y_true={y_true.shape}, "
#      35                      f"y_pred={y_pred.shape}, mask={indicating_mask.shape}")
#      37 # Verifica si la suma de la máscara es cero (no hay valores para evaluar)
#      38 if indicating_mask.sum() == 0:
#
# ValueError: Desajuste de forma: y_true=(253, 24, 114), y_pred=(253, 24, 112), mask=(253, 24, 114)

# %% [markdown]
# ## 6. Evaluar Resultados de Imputación en Periodo 2
#
# Evaluamos el rendimiento de cada método de imputación utilizando métricas estándar (MAE, MSE, RMSE, MRE) calculadas únicamente sobre los valores que fueron originalmente faltantes (indicados por `indicating_mask`). Comparamos los valores imputados (`y_pred`) con los valores verdaderos originales (`y_true`, correspondientes a `test_X_ori`).

# %%
print("\nEvaluando rendimiento de imputación en el conjunto de test...")

# Usar la función del módulo de evaluación
# Requiere el diccionario de datos preprocesados (para ground truth y máscara)
# y el diccionario de resultados imputados
evaluation_table2 = ev.evaluate_all_methods(
    processed_data2,
    imputed_results2,
    methods_to_evaluate=list(imputed_results2.keys()) # Evaluar todos los métodos calculados
)

evaluation_table2.T

# %% [markdown]
# ## 7. Visualizar Resultados (Ejemplo: NO2)
#
# Visualizamos los resultados de la imputación para una característica específica (NO2) en el periodo de test. Comparamos la serie original (escalada, con valores faltantes), la serie verdadera (`Ground Truth`, escalada, antes de introducir valores faltantes artificiales) y las series imputadas por diferentes métodos. Los puntos rojos indican los valores que fueron artificialmente marcados como faltantes y luego imputados.

# %%
# ## 7. Visualizar Resultados (Ejemplo: NO2)

# Seleccionar una característica para visualizar
feature_to_plot = "NO2"
if feature_to_plot not in config.FEATURE_COLUMNS:
    print(f"Advertencia: '{feature_to_plot}' no está en las columnas de características. Saltando gráfico.")
else:
    feature_index = config.FEATURE_COLUMNS.index(feature_to_plot)

    # Obtener datos originales de test (antes de ventanear, potencialmente sin escalar para interpretabilidad)
    test_df_original = periodo_1_raw.loc[config.TEST_START_DATE:config.TEST_END_DATE]#[feature_to_plot]
    # Ajustar por fecha final exclusiva si es necesario basado en cómo se hizo el split
    # Ejemplo: si TEST_END_DATE = "2023-03-15", loc incluirá hasta "2023-03-14 23:00:00"
    # pero si los datos preprocesados excluyen el último día, ajustar aquí:
    # test_df_original = test_df_original.iloc[:-1] # O ajustar basado en el número exacto de filas


    # Reestructurar datos imputados a DataFrame para facilitar la visualización
    # Usar el scaler para invertir la transformación si se desea escala original
    scaler = processed_data['scaler']
    test_index_full = processed_data['test_index'] # Índice antes de ventanear

    plt.figure(figsize=(15, 8))
    plt.title(f"Comparación de Imputación para {feature_to_plot} (Periodo Test)")
    plt.xlabel("Tiempo")
    plt.ylabel(f"{feature_to_plot} (Escalado)") # Etiquetar como escalado

    # Graficar datos originales con valores faltantes (escalados)
    # Asegurarse que test_df_original tenga las columnas correctas antes de transformar
    original_scaled_test_data = scaler.transform(test_df_original[config.FEATURE_COLUMNS])
    original_series_scaled = pd.Series(original_scaled_test_data[:, feature_index], index=test_df_original.index)
    plt.plot(original_series_scaled.index, original_series_scaled.values, label='Original (Escalado, con NaNs)', color='gray', alpha=0.7, linestyle=':')

    # Graficar Ground Truth (donde se introdujo la ausencia) - escalado
    # Necesitamos reconstruir la serie temporal ground truth desde test_X_ori
    # Usar la utilidad de reestructuración
    ground_truth_df = utils.reshape_imputed_to_df(
         dataset_for_testing['X_ori'], # Datos escalados ANTES de enmascarar
         test_index_full, # Usar el índice antes de ventanear
         config.FEATURE_COLUMNS,
         config.N_STEPS
         )

    # Extraer el rango de tiempo relevante para graficar
    # Asegurarse que los índices coincidan con original_series_scaled
    plot_start = original_series_scaled.index.min()
    plot_end = original_series_scaled.index.max()

    # Verificar si las fechas están en ground_truth_df
    if plot_start in ground_truth_df.index and plot_end in ground_truth_df.index:
        ground_truth_series = ground_truth_df.loc[plot_start:plot_end, feature_to_plot]

        # Marcar los puntos que eran originalmente faltantes (usando la máscara)
        mask_flat = dataset_for_testing['indicating_mask'].reshape(-1, processed_data['n_features'])
        # Crear índice para la máscara aplanada que coincida con ground_truth_df
        mask_index = ground_truth_df.index[:len(mask_flat)] # Asegurar que no exceda la longitud
        mask_series = pd.Series(mask_flat[:, feature_index], index=mask_index).loc[plot_start:plot_end]

        missing_indices = mask_series[mask_series == 1].index

        plt.plot(ground_truth_series.index, ground_truth_series.values, label='Ground Truth (Escalado)', color='black', linewidth=1.5)
        # Asegurar que los missing_indices existen en ground_truth_series antes de graficar
        valid_missing_indices = missing_indices.intersection(ground_truth_series.index)
        plt.scatter(valid_missing_indices, ground_truth_series.loc[valid_missing_indices], color='red', s=15, label='Puntos Imputados (Verdad)', zorder=5)

    else:
        print("Advertencia: Rango de fechas de test original no encontrado completamente en datos ground truth reconstruidos. Saltando gráfico de ground truth.")
        ground_truth_series = None # Para evitar errores posteriores


    # Graficar resultados imputados
    plot_methods = ['median', 'linear', 'saits'] # Elegir métodos a graficar
    colors = ['blue', 'green', 'orange', 'purple', 'brown']
    linestyles = ['--', '-.', ':']

    for i, method in enumerate(plot_methods):
        if method in imputed_results:
            # Verificar si las columnas necesitan alineación (ej., ffill/bfill)
            current_cols = config.FEATURE_COLUMNS
            current_feature_index = feature_index
            y_pred = imputed_results[method]

            # Ajustar columnas y índice de característica si se eliminaron columnas para este método
            if method in ['ffill_bfill', 'bfill_ffill'] and cols_to_drop_indices:
                 current_cols = [col for idx, col in enumerate(config.FEATURE_COLUMNS) if idx not in cols_to_drop_indices]
                 if feature_to_plot in current_cols:
                     current_feature_index = current_cols.index(feature_to_plot)
                 else:
                     print(f"Saltando gráfico para {method} - {feature_to_plot} fue eliminada.")
                     continue # Saltar gráfico de este método para esta característica
                 # y_pred ya está ajustado

            # Reestructurar la predicción
            imputed_df = utils.reshape_imputed_to_df(
                 y_pred,
                 test_index_full, # Usar índice antes de ventanear
                 current_cols, # Usar columnas potencialmente reducidas
                 config.N_STEPS
            )

            # Extraer la serie y graficar en el rango correcto
            if plot_start in imputed_df.index and plot_end in imputed_df.index:
                imputed_series = imputed_df.loc[plot_start:plot_end, feature_to_plot]
                plt.plot(imputed_series.index, imputed_series.values,
                         label=f'{method.title()} Imputado',
                         color=colors[i % len(colors)],
                         linestyle=linestyles[i % len(linestyles)],
                         alpha=0.8)
            else:
                 print(f"Advertencia: Rango de fechas de test original no encontrado completamente en datos imputados ({method}). Saltando gráfico parcial.")


    plt.legend()
    plt.grid(True, linestyle='--', alpha=0.6)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### 8. Interpretación de la Tabla de Métricas de Imputación/Predicción
#
# Esta tabla compara el rendimiento de diferentes métodos de imputación o predicción utilizando cuatro métricas de error: RMSE (Raíz del Error Cuadrático Medio), MSE (Error Cuadrático Medio), MAE (Error Absoluto Medio) y MRE (Error Relativo Medio). Valores más bajos en todas las métricas indican un mejor rendimiento.
#
# En resumen, los métodos basados en modelos complejos, Transformer y Saits, demuestran el mejor rendimiento general, con valores significativamente más bajos en todas las métricas en comparación con los métodos más simples.
#
# La Media se destaca como un método de referencia sorprendentemente efectivo, superando a la Mediana y a los métodos de interpolación lineal y de relleno simple (Ffill y Bfill). Esto sugiere que para este conjunto de datos, la media proporciona una buena estimación central.
#
# Los métodos de relleno simple, Ffill (relleno hacia adelante) y Bfill (relleno hacia atrás), muestran el peor rendimiento, indicando que son enfoques ingenuos y menos efectivos para este tipo de datos.
#
# El método Lineal se sitúa en un punto intermedio, mejor que los rellenos simples pero peor que la Media, la Mediana y los modelos Transformer y Saits.

# %% [markdown]
# ## 9. Opcional: Guardar Resultados
#
# Podemos guardar la tabla de evaluación y/o los datos imputados (por ejemplo, los resultados de SAITS) en archivos CSV si es necesario para análisis posteriores o informes.

# %%
# Guardar la tabla de evaluación
# evaluation_table.to_csv(f"{config.RESULTS_DIR}/imputation_evaluation.csv")
# print(f"Resultados de evaluación guardados en {config.RESULTS_DIR}/imputation_evaluation.csv")

# Guardar datos imputados (ej. resultado de SAITS) si es necesario
# saits_imputed_df = utils.reshape_imputed_to_df(...) # Necesitas reconstruir el DataFrame
# saits_imputed_df.to_csv(...)

print("\nFlujo de trabajo finalizado.")
