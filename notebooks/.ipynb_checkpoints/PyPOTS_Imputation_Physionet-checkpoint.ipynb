# %% [markdown]
# # 📑 Tutorials for PyPOTS Imputation Models

# %% [markdown]
# ## 📀 Preparing the **PhysioNet-2012** dataset for this tutorial

# %%
from benchpots.datasets import preprocess_physionet2012

# Load the dataset with artificially missing values
physionet2012_dataset = preprocess_physionet2012(subset="all", rate=0.1)
# Out:
# 2025-03-06 13:21:12 [INFO]: You're using dataset physionet_2012, please cite it properly in your work. You can find its reference information at the below link:
# https://github.com/WenjieDu/TSDB/tree/main/dataset_profiles/physionet_2012
# 2025-03-06 13:21:12 [INFO]: Dataset physionet_2012 has already been downloaded. Processing directly...
# 2025-03-06 13:21:12 [INFO]: Dataset physionet_2012 has already been cached. Loading from cache directly...
# 2025-03-06 13:21:13 [INFO]: Loaded successfully!
# 2025-03-06 13:21:27 [WARNING]: Note that physionet_2012 has sparse observations in the time series, hence we don't add additional missing values to the training dataset.
# 2025-03-06 13:21:27 [INFO]: 69597 values masked out in the val set as ground truth, take 9.98% of the original observed values
# 2025-03-06 13:21:27 [INFO]: 85851 values masked out in the test set as ground truth, take 9.93% of the original observed values
# 2025-03-06 13:21:27 [INFO]: Total sample number: 11988
# 2025-03-06 13:21:27 [INFO]: Training set size: 7671 (63.99%)
# 2025-03-06 13:21:27 [INFO]: Validation set size: 1918 (16.00%)
# 2025-03-06 13:21:27 [INFO]: Test set size: 2399 (20.01%)
# 2025-03-06 13:21:27 [INFO]: Number of steps: 48
# 2025-03-06 13:21:27 [INFO]: Number of features: 37
# 2025-03-06 13:21:27 [INFO]: Train set missing rate: 79.76%
# 2025-03-06 13:21:27 [INFO]: Validating set missing rate: 81.57%
# 2025-03-06 13:21:27 [INFO]: Test set missing rate: 81.72%

# %%
physionet2012_dataset.keys()
# Out:
# dict_keys(['n_classes', 'n_steps', 'n_features', 'scaler', 'train_X', 'train_y', 'train_ICUType', 'val_X', 'val_y', 'val_ICUType', 'test_X', 'test_y', 'test_ICUType', 'val_X_ori', 'test_X_ori'])

# %%
# Assemble the datasets for training, validating, and testing.

dataset_for_training = {
    "X": physionet2012_dataset['train_X'],
}

dataset_for_validating = {
    "X": physionet2012_dataset['val_X'],
    "X_ori": physionet2012_dataset['val_X_ori'],
}

dataset_for_testing = {
    "X": physionet2012_dataset['test_X'],
    "X_ori": physionet2012_dataset['test_X_ori']
}

# %% [markdown]
# ## División en entrenamiento, validación y testing
#
# - 64% Training
# - 16% Validation
# - 20% Testing

# %%
dataset_for_testing['X_ori']
# Out:
# array([[[-0.09521819, -0.29235632, -0.27728012, ..., -0.12677684,
#           0.06501677,         nan],
#         [        nan,         nan,         nan, ...,         nan,
#           0.06501677,         nan],
#         [        nan,         nan,         nan, ...,         nan,
#           0.06501677,         nan],
#         ...,
#         [        nan,         nan,         nan, ...,         nan,
#           0.06501677,         nan],
#         [        nan,         nan,         nan, ...,         nan,
#           0.06501677,         nan],
#         [        nan,         nan,         nan, ...,         nan,
#           0.06501677,         nan]],
#
#        [[        nan,         nan,         nan, ...,         nan,
#           0.15852198,         nan],
#         [        nan,         nan,         nan, ...,         nan,
#           0.15852198,         nan],
#         [        nan,         nan,         nan, ..., -0.60859964,
#           0.15852198,         nan],
#         ...,
#         [        nan,         nan,         nan, ...,         nan,
#                  nan,         nan],
#         [        nan,         nan,         nan, ...,         nan,
#                  nan,         nan],
#         [        nan,         nan,         nan, ...,         nan,
#           0.15852198,         nan]],
#
#        [[        nan,         nan,         nan, ...,         nan,
#          -0.69860912,         nan],
#         [        nan,         nan,         nan, ...,         nan,
#          -0.69860912,         nan],
#         [ 1.75251364, -0.26930448, -0.25671917, ...,  0.80959577,
#          -0.69860912,         nan],
#         ...,
#         [        nan,         nan,         nan, ...,         nan,
#                  nan,         nan],
#         [        nan,         nan,         nan, ...,         nan,
#                  nan,         nan],
#         [        nan,         nan,         nan, ...,         nan,
#                  nan,         nan]],
#
#        ...,
#
#        [[        nan,         nan,         nan, ...,         nan,
#          -0.9830208 ,         nan],
#         [        nan,         nan,         nan, ...,         nan,
#          -0.9830208 ,         nan],
#         [        nan,         nan,         nan, ...,         nan,
#          -0.9830208 ,         nan],
#         ...,
#         [        nan,         nan,         nan, ..., -0.60859964,
#          -0.9830208 ,         nan],
#         [        nan,         nan,         nan, ...,         nan,
#                  nan,         nan],
#         [        nan,         nan,         nan, ...,         nan,
#                  nan,         nan]],
#
#        [[        nan,         nan,         nan, ...,         nan,
#          -0.75315383, -0.01529093],
#         [        nan,         nan,         nan, ...,         nan,
#                  nan, -0.09836158],
#         [        nan,         nan,         nan, ...,         nan,
#                  nan, -0.169565  ],
#         ...,
#         [        nan,         nan,         nan, ...,         nan,
#          -0.23497912,         nan],
#         [        nan,         nan,         nan, ...,         nan,
#          -0.23497912,         nan],
#         [        nan,         nan,         nan, ...,         nan,
#          -0.23497912,         nan]],
#
#        [[        nan,         nan,         nan, ...,         nan,
#          -0.58172761,         nan],
#         [        nan,         nan,         nan, ...,         nan,
#          -0.58172761,         nan],
#         [        nan,         nan,         nan, ...,         nan,
#          -0.58172761,         nan],
#         ...,
#         [        nan,         nan,         nan, ...,         nan,
#          -0.58172761,         nan],
#         [        nan,         nan,         nan, ...,         nan,
#          -0.58172761,         nan],
#         [        nan,         nan,         nan, ...,         nan,
#          -0.58172761,  0.05591249]]], shape=(2399, 48, 37))

# %%
dataset_for_testing['X']
# Out:
# array([[[-0.09521819,         nan, -0.27728012, ..., -0.12677684,
#           0.06501677,         nan],
#         [        nan,         nan,         nan, ...,         nan,
#           0.06501677,         nan],
#         [        nan,         nan,         nan, ...,         nan,
#                  nan,         nan],
#         ...,
#         [        nan,         nan,         nan, ...,         nan,
#           0.06501677,         nan],
#         [        nan,         nan,         nan, ...,         nan,
#           0.06501677,         nan],
#         [        nan,         nan,         nan, ...,         nan,
#           0.06501677,         nan]],
#
#        [[        nan,         nan,         nan, ...,         nan,
#           0.15852198,         nan],
#         [        nan,         nan,         nan, ...,         nan,
#           0.15852198,         nan],
#         [        nan,         nan,         nan, ...,         nan,
#           0.15852198,         nan],
#         ...,
#         [        nan,         nan,         nan, ...,         nan,
#                  nan,         nan],
#         [        nan,         nan,         nan, ...,         nan,
#                  nan,         nan],
#         [        nan,         nan,         nan, ...,         nan,
#           0.15852198,         nan]],
#
#        [[        nan,         nan,         nan, ...,         nan,
#          -0.69860912,         nan],
#         [        nan,         nan,         nan, ...,         nan,
#          -0.69860912,         nan],
#         [ 1.75251364, -0.26930448, -0.25671917, ...,  0.80959577,
#          -0.69860912,         nan],
#         ...,
#         [        nan,         nan,         nan, ...,         nan,
#                  nan,         nan],
#         [        nan,         nan,         nan, ...,         nan,
#                  nan,         nan],
#         [        nan,         nan,         nan, ...,         nan,
#                  nan,         nan]],
#
#        ...,
#
#        [[        nan,         nan,         nan, ...,         nan,
#          -0.9830208 ,         nan],
#         [        nan,         nan,         nan, ...,         nan,
#          -0.9830208 ,         nan],
#         [        nan,         nan,         nan, ...,         nan,
#          -0.9830208 ,         nan],
#         ...,
#         [        nan,         nan,         nan, ..., -0.60859964,
#          -0.9830208 ,         nan],
#         [        nan,         nan,         nan, ...,         nan,
#                  nan,         nan],
#         [        nan,         nan,         nan, ...,         nan,
#                  nan,         nan]],
#
#        [[        nan,         nan,         nan, ...,         nan,
#          -0.75315383, -0.01529093],
#         [        nan,         nan,         nan, ...,         nan,
#                  nan, -0.09836158],
#         [        nan,         nan,         nan, ...,         nan,
#                  nan, -0.169565  ],
#         ...,
#         [        nan,         nan,         nan, ...,         nan,
#          -0.23497912,         nan],
#         [        nan,         nan,         nan, ...,         nan,
#          -0.23497912,         nan],
#         [        nan,         nan,         nan, ...,         nan,
#          -0.23497912,         nan]],
#
#        [[        nan,         nan,         nan, ...,         nan,
#          -0.58172761,         nan],
#         [        nan,         nan,         nan, ...,         nan,
#          -0.58172761,         nan],
#         [        nan,         nan,         nan, ...,         nan,
#          -0.58172761,         nan],
#         ...,
#         [        nan,         nan,         nan, ...,         nan,
#          -0.58172761,         nan],
#         [        nan,         nan,         nan, ...,         nan,
#          -0.58172761,         nan],
#         [        nan,         nan,         nan, ...,         nan,
#          -0.58172761,  0.05591249]]], shape=(2399, 48, 37))

# %%
import pandas as pd
import numpy as np

# Supongamos que 'dataset_for_testing['X']' es tu numpy array de shape (2399, 48, 37)
# Reestructuramos el array para convertirlo en un formato adecuado para series temporales multivariantes
# Transponemos y aplanamos para que tengamos (2399 * 48, 37)

X_reshaped = dataset_for_testing['X'].reshape(-1, 37)

# Ahora X_reshaped tiene la forma (2399 * 48, 37)

# Creamos un índice para las filas basado en el paso temporal
index = pd.MultiIndex.from_product([range(2399), range(48)], names=['Sample', 'Time'])

# Creamos el DataFrame
df = pd.DataFrame(X_reshaped, columns=features, index=index)

# Mostrar las primeras filas del DataFrame
df
# Out:
#               Albumin  ALP      ALT       AST  Bilirubin       BUN  \
# Sample Time
# 0      0    -0.095218  NaN -0.27728  2.316841  -0.193283 -0.474027
#        1          NaN  NaN      NaN       NaN        NaN       NaN
#        2          NaN  NaN      NaN       NaN        NaN       NaN
#        3          NaN  NaN      NaN       NaN        NaN       NaN
#        4          NaN  NaN      NaN       NaN        NaN       NaN
# ...               ...  ...      ...       ...        ...       ...
# 2398   43         NaN  NaN      NaN       NaN        NaN       NaN
#        44         NaN  NaN      NaN       NaN        NaN       NaN
#        45         NaN  NaN      NaN       NaN        NaN       NaN
#        46         NaN  NaN      NaN       NaN        NaN       NaN
#        47         NaN  NaN      NaN       NaN        NaN       NaN
#
#              Cholesterol  Creatinine   DiasABP      FiO2  ...  Platelets  \
# Sample Time                                               ...
# 0      0             NaN   -0.371081       NaN       NaN  ...  -0.291488
#        1             NaN         NaN       NaN       NaN  ...  -0.370320
#        2             NaN         NaN       NaN       NaN  ...  -0.720683
#        3             NaN         NaN       NaN       NaN  ...  -0.659370
#        4             NaN         NaN       NaN       NaN  ...  -0.843311
# ...                  ...         ...       ...       ...  ...        ...
# 2398   43            NaN         NaN       NaN       NaN  ...        NaN
#        44            NaN         NaN  1.480764 -0.758754  ...        NaN
#        45            NaN         NaN  1.441798       NaN  ...        NaN
#        46            NaN         NaN  1.246970 -0.226440  ...        NaN
#        47            NaN         NaN       NaN       NaN  ...        NaN
#
#              RespRate      SaO2    SysABP  Temp  TroponinI  TroponinT  \
# Sample Time
# 0      0          NaN       NaN -0.613794   NaN        NaN        NaN
#        1          NaN       NaN       NaN   NaN        NaN        NaN
#        2          NaN       NaN       NaN   NaN        NaN        NaN
#        3          NaN       NaN -0.534433   NaN        NaN        NaN
#        4          NaN       NaN       NaN   NaN        NaN        NaN
# ...               ...       ...       ...   ...        ...        ...
# 2398   43         NaN  2.387220       NaN   NaN        NaN        NaN
#        44         NaN  1.282731  0.417899   NaN        NaN   0.494567
#        45         NaN  1.834975       NaN   NaN        NaN  -0.240272
#        46         NaN  1.282731       NaN   NaN        NaN  -0.474084
#        47         NaN  1.452652       NaN   NaN        NaN        NaN
#
#                 Urine       WBC    Weight
# Sample Time
# 0      0    -0.126777  0.065017       NaN
#        1          NaN  0.065017       NaN
#        2          NaN       NaN       NaN
#        3          NaN  0.065017       NaN
#        4          NaN  0.065017       NaN
# ...               ...       ...       ...
# 2398   43         NaN -0.581728       NaN
#        44         NaN -0.581728       NaN
#        45         NaN -0.581728       NaN
#        46         NaN -0.581728       NaN
#        47         NaN -0.581728  0.055912
#
# [115152 rows x 37 columns]

# %%
import matplotlib.pyplot as plt

# Seleccionar una muestra específica (por ejemplo, la primera muestra, índice 0)
sample_index = 0
time_steps = range(48)  # 48 pasos de tiempo

# Obtener los datos de la primera muestra para las características específicas
sample_data = df.loc[sample_index, ['HR', 'NIMAP']]

# Crear gráfico para Ritmo Cardíaco (HR)
plt.figure(figsize=(14, 6))
if sample_data['HR'].notna().any():  # Verificar si hay datos válidos
    plt.plot(time_steps, sample_data['HR'], label='Ritmo Cardíaco (HR)', color='b')
    plt.title(f'Ritmo Cardíaco (HR) para la Muestra {sample_index + 1}', fontsize=16)
    plt.xlabel('Paso de tiempo', fontsize=14)
    plt.ylabel('Valor de HR', fontsize=14)
    plt.legend(loc='upper right', bbox_to_anchor=(1.2, 1), fontsize=10)
    plt.tight_layout()
else:
    print("No hay datos válidos para Ritmo Cardíaco (HR) en la muestra.")

# %%
# Crear gráfico para Presión Arterial No Invasiva (NIMAP)
plt.figure(figsize=(14, 6))
if sample_data['NIMAP'].notna().any():  # Verificar si hay datos válidos
    plt.plot(time_steps, sample_data['NIMAP'], label='Presión Arterial No Invasiva (NIMAP)', color='g')
    plt.title(f'Presión Arterial No Invasiva (NIMAP) para la Muestra {sample_index + 1}', fontsize=16)
    plt.xlabel('Paso de tiempo', fontsize=14)
    plt.ylabel('Valor de NIMAP', fontsize=14)
    plt.legend(loc='upper right', bbox_to_anchor=(1.2, 1), fontsize=10)
    plt.tight_layout()
else:
    print("No hay datos válidos para Presión Arterial No Invasiva (NIMAP) en la muestra.")

# Mostrar los gráficos
plt.show()

# %%
dataset_for_training['X']
# Out:
# array([[[            nan,             nan,             nan, ...,
#                      nan, -3.34186687e+00,             nan],
#         [            nan,             nan,             nan, ...,
#                      nan,             nan,             nan],
#         [            nan,             nan,             nan, ...,
#                      nan,             nan,             nan],
#         ...,
#         [            nan,             nan,             nan, ...,
#                      nan,             nan,             nan],
#         [            nan,             nan,             nan, ...,
#                      nan,             nan,             nan],
#         [            nan,             nan,             nan, ...,
#                      nan,             nan,             nan]],
#
#        [[            nan,             nan,             nan, ...,
#                      nan, -2.82949840e-01,  2.50627088e-03],
#         [            nan,             nan,             nan, ...,
#          -4.98983937e-01,             nan,  8.54514434e-04],
#         [            nan,             nan,             nan, ...,
#                      nan,             nan,             nan],
#         ...,
#         [            nan,             nan,             nan, ...,
#                      nan, -6.04831464e-02, -1.07077807e-02],
#         [            nan,             nan,             nan, ...,
#                      nan, -6.04831464e-02,             nan],
#         [            nan,             nan,             nan, ...,
#                      nan, -6.04831464e-02,             nan]],
#
#        [[-9.61992367e-02, -2.95986376e-01, -3.01610806e-01, ...,
#          -1.31637473e-01,  5.86954393e-02,             nan],
#         [            nan,             nan,             nan, ...,
#                      nan,  5.86954393e-02,             nan],
#         [            nan,             nan,             nan, ...,
#                      nan,  5.86954393e-02,             nan],
#         ...,
#         [            nan,             nan,             nan, ...,
#                      nan,  5.86954393e-02,             nan],
#         [            nan,             nan,             nan, ...,
#                      nan,  5.86954393e-02,             nan],
#         [            nan,             nan,             nan, ...,
#                      nan,  5.86954393e-02,             nan]],
#
#        ...,
#
#        [[            nan,             nan,             nan, ...,
#                      nan,  4.96090793e+00,             nan],
#         [            nan,             nan,             nan, ...,
#                      nan,             nan,             nan],
#         [            nan,             nan,             nan, ...,
#                      nan,             nan,             nan],
#         ...,
#         [            nan,             nan,             nan, ...,
#                      nan,             nan,             nan],
#         [            nan,             nan,             nan, ...,
#                      nan,             nan,             nan],
#         [            nan,             nan,             nan, ...,
#                      nan,             nan,             nan]],
#
#        [[            nan,             nan,             nan, ...,
#                      nan,  7.45859174e-02, -7.97242014e-04],
#         [            nan,             nan,             nan, ...,
#          -6.69217664e-01,             nan,             nan],
#         [            nan,             nan,             nan, ...,
#                      nan,             nan,             nan],
#         ...,
#         [            nan,             nan,             nan, ...,
#                      nan,  3.92395479e-01,             nan],
#         [            nan,             nan,             nan, ...,
#                      nan,             nan,             nan],
#         [            nan,             nan,             nan, ...,
#                      nan,  3.92395479e-01,             nan]],
#
#        [[            nan,             nan,             nan, ...,
#                      nan, -3.98155806e-01, -2.88771016e-02],
#         [-3.17370638e-01, -2.85824081e-01, -2.87708698e-01, ...,
#           5.85136114e-01,             nan,             nan],
#         [            nan,             nan,             nan, ...,
#                      nan,             nan,             nan],
#         ...,
#         [            nan,             nan,             nan, ...,
#                      nan,             nan,             nan],
#         [            nan,             nan,             nan, ...,
#                      nan,             nan,             nan],
#         [            nan,             nan,             nan, ...,
#                      nan,             nan,             nan]]],
#       shape=(7671, 48, 37))

# %%
physionet2012_dataset['n_steps']
# Out:
# 48

# %%
physionet2012_dataset['n_features']
# Out:
# 37

# %% [markdown]
# ## 🚀 An example of **SAITS** for imputation

# %%
from pypots.optim import Adam
from pypots.imputation import SAITS

# initialize the model
saits = SAITS(
    n_steps=physionet2012_dataset['n_steps'],
    n_features=physionet2012_dataset['n_features'],
    n_layers=2,
    d_model=256,
    d_ffn=128,
    n_heads=4,
    d_k=64,
    d_v=64,
    dropout=0.1,
    attn_dropout=0.1,
    ##### Esto diferencia al SAIT del modelo Transformer
    diagonal_attention_mask=True,  # otherwise the original self-attention mechanism will be applied
    ORT_weight=1,  # you can adjust the weight values of arguments ORT_weight
    # and MIT_weight to make the SAITS model focus more on one task. Usually you can just leave them to the default values, i.e. 1.
    MIT_weight=1,
    batch_size=32,
    # here we set epochs=10 for a quick demo, you can set it to 100 or more for better performance
    epochs=10,
    # here we set patience=3 to early stop the training if the evaluting loss doesn't decrease for 3 epoches.
    # You can leave it to defualt as None to disable early stopping.
    patience=3,
    # give the optimizer. Different from torch.optim.Optimizer, you don't have to specify model's parameters when
    # initializing pypots.optim.Optimizer. You can also leave it to default. It will initilize an Adam optimizer with lr=0.001.
    optimizer=Adam(lr=1e-3),
    # this num_workers argument is for torch.utils.data.Dataloader. It's the number of subprocesses to use for data loading.
    # Leaving it to default as 0 means data loading will be in the main process, i.e. there won't be subprocesses.
    # You can increase it to >1 if you think your dataloading is a bottleneck to your model training speed
    num_workers=0,
    # just leave it to default as None, PyPOTS will automatically assign the best device for you.
    # Set it as 'cpu' if you don't have CUDA devices. You can also set it to 'cuda:0' or 'cuda:1' if you have multiple CUDA devices, even parallelly on ['cuda:0', 'cuda:1']
    device=None,  
    # set the path for saving tensorboard and trained model files 
    saving_path="tutorial_results/imputation/saits",
    # only save the best model after training finished.
    # You can also set it as "better" to save models performing better ever during training.
    model_saving_strategy="best",
)
# Out:
# /Users/eigenric/.local/share/virtualenvs/TFG--n4J6ECg/lib/python3.13/site-packages/pypots/nn/modules/reformer/local_attention.py:31: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast(enabled=False)
# /Users/eigenric/.local/share/virtualenvs/TFG--n4J6ECg/lib/python3.13/site-packages/pypots/nn/modules/reformer/local_attention.py:98: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast(enabled=False)
# 2025-03-06 14:21:30 [INFO]: No given device, using default device: cpu
# 2025-03-06 14:21:30 [INFO]: Model files will be saved to tutorial_results/imputation/saits/20250306_T142130
# 2025-03-06 14:21:30 [INFO]: Tensorboard file will be saved to tutorial_results/imputation/saits/20250306_T142130/tensorboard
# 2025-03-06 14:21:30 [INFO]: SAITS initialized with the given hyperparameters, the number of trainable parameters: 1,378,358
# ████████╗██╗███╗   ███╗███████╗    ███████╗███████╗██████╗ ██╗███████╗███████╗    █████╗ ██╗
# ╚══██╔══╝██║████╗ ████║██╔════╝    ██╔════╝██╔════╝██╔══██╗██║██╔════╝██╔════╝   ██╔══██╗██║
#    ██║   ██║██╔████╔██║█████╗█████╗███████╗█████╗  ██████╔╝██║█████╗  ███████╗   ███████║██║
#    ██║   ██║██║╚██╔╝██║██╔══╝╚════╝╚════██║██╔══╝  ██╔══██╗██║██╔══╝  ╚════██║   ██╔══██║██║
#    ██║   ██║██║ ╚═╝ ██║███████╗    ███████║███████╗██║  ██║██║███████╗███████║██╗██║  ██║██║
#    ╚═╝   ╚═╝╚═╝     ╚═╝╚══════╝    ╚══════╝╚══════╝╚═╝  ╚═╝╚═╝╚══════╝╚══════╝╚═╝╚═╝  ╚═╝╚═╝
# ai4ts v0.0.3 - building AI for unified time-series analysis, https://time-series.ai

# %%
# train the model on the training set, and validate it on the validating set to select the best model for testing in the next step
saits.fit(train_set=dataset_for_training, val_set=dataset_for_validating)
# Out:
# 2025-03-06 14:22:07 [INFO]: Epoch 001 - training loss: 0.7450, validation loss: 0.4323
# 2025-03-06 14:22:50 [INFO]: Epoch 002 - training loss: 0.5498, validation loss: 0.4236
# 2025-03-06 14:23:36 [INFO]: Epoch 003 - training loss: 0.4994, validation loss: 0.3857
# 2025-03-06 14:24:18 [INFO]: Epoch 004 - training loss: 0.4628, validation loss: 0.3650
# 2025-03-06 14:24:52 [INFO]: Epoch 005 - training loss: 0.4368, validation loss: 0.3517
# 2025-03-06 14:25:26 [INFO]: Epoch 006 - training loss: 0.4184, validation loss: 0.3342
# 2025-03-06 14:25:59 [INFO]: Epoch 007 - training loss: 0.4034, validation loss: 0.3288
# 2025-03-06 14:26:33 [INFO]: Epoch 008 - training loss: 0.3896, validation loss: 0.3282
# 2025-03-06 14:27:09 [INFO]: Epoch 009 - training loss: 0.3804, validation loss: 0.3147
# 2025-03-06 14:27:54 [INFO]: Epoch 010 - training loss: 0.3730, validation loss: 0.3110
# 2025-03-06 14:27:54 [INFO]: Finished training. The best model is from epoch#10.
# 2025-03-06 14:27:54 [INFO]: Saved the model to tutorial_results/imputation/saits/20250306_T142130/SAITS.pypots

# %%
# the testing stage, impute the originally-missing values and artificially-missing values in the test set

saits_results = saits.predict(dataset_for_testing)
saits_imputation = saits_results["imputation"]

# %%
saits_imputation
# Out:
# array([[[-0.09521819, -0.24690533, -0.27728012, ..., -0.12677684,
#           0.06501677,  0.01692275],
#         [-0.42354825, -0.31886524, -0.29859236, ..., -0.35862166,
#           0.06501677, -0.02234535],
#         [-0.4388218 , -0.30568   , -0.25097674, ..., -0.30225128,
#           0.02749445, -0.01857247],
#         ...,
#         [-0.4294129 , -0.3082028 , -0.2774266 , ..., -0.33813152,
#           0.06501677, -0.02050705],
#         [-0.5348446 , -0.3394674 , -0.31065947, ..., -0.41703537,
#           0.06501677,  0.02127906],
#         [-0.4307561 , -0.3166366 , -0.27021033, ..., -0.37421572,
#           0.06501677,  0.01709956]],
#
#        [[-0.22629237, -0.1381374 , -0.24000591, ..., -0.38785952,
#           0.15852198,  0.02890418],
#         [-0.12833552, -0.18803248, -0.16802512, ..., -0.30907467,
#           0.15852198,  0.04227029],
#         [-0.01654783, -0.1398545 , -0.14912863, ..., -0.41553372,
#           0.15852198,  0.06056905],
#         ...,
#         [-0.5772635 , -0.30227453, -0.319808  , ..., -0.3339383 ,
#           0.14277683,  0.06797233],
#         [-0.5742606 , -0.30775318, -0.3288908 , ..., -0.35522038,
#           0.14888886,  0.06600088],
#         [-0.4076653 , -0.3012706 , -0.30492544, ..., -0.39173618,
#           0.15852198,  0.06312805]],
#
#        [[-0.56249183, -0.432329  , -0.33923793, ..., -0.22581375,
#          -0.6986091 , -0.0419026 ],
#         [-0.3444251 , -0.4157726 , -0.28928864, ..., -0.15769936,
#          -0.6986091 , -0.05453303],
#         [ 1.7525136 , -0.26930448, -0.25671917, ...,  0.80959576,
#          -0.6986091 , -0.03942863],
#         ...,
#         [-0.6503234 , -0.3000461 , -0.25530118, ..., -0.2784829 ,
#          -0.60268563, -0.0033283 ],
#         [-0.5280241 , -0.32626992, -0.27292335, ..., -0.27275592,
#          -0.6548902 ,  0.00765846],
#         [-0.55080724, -0.37775636, -0.2775558 , ..., -0.30837923,
#          -0.63393503, -0.01990001]],
#
#        ...,
#
#        [[-0.47845587, -0.37105972, -0.32678157, ..., -0.28341362,
#          -0.9830208 , -0.01294226],
#         [-0.45178068, -0.36866492, -0.31118214, ..., -0.30000985,
#          -0.9830208 ,  0.00682252],
#         [-0.45695987, -0.39758927, -0.33489382, ..., -0.2903555 ,
#          -0.9830208 , -0.00404076],
#         ...,
#         [-0.3189603 , -0.23457271, -0.22782353, ..., -0.60859966,
#          -0.9830208 , -0.00832307],
#         [-0.72749776, -0.36516708, -0.37832254, ..., -0.31135795,
#          -1.0631862 ,  0.01057216],
#         [-0.7141679 , -0.3749118 , -0.38382846, ..., -0.34590286,
#          -1.0786351 ,  0.01819833]],
#
#        [[-0.69726455, -0.3574838 , -0.38451445, ..., -0.16513285,
#          -0.7531538 , -0.01529093],
#         [-0.66795474, -0.34278122, -0.4013614 , ..., -0.13477057,
#          -0.36736637, -0.09836158],
#         [-0.6743711 , -0.29532766, -0.3477108 , ..., -0.11481363,
#          -0.20782578, -0.169565  ],
#         ...,
#         [-0.57527494, -0.3671672 , -0.34626764, ..., -0.15001337,
#          -0.23497912,  0.03999541],
#         [-0.62685996, -0.39719376, -0.43265927, ..., -0.14531898,
#          -0.23497912,  0.04937043],
#         [-0.5633235 , -0.3672993 , -0.42961186, ..., -0.15791088,
#          -0.23497912,  0.04622293]],
#
#        [[-0.45478332, -0.37286043, -0.34641424, ..., -0.17702974,
#          -0.5817276 ,  0.01168409],
#         [-0.59360564, -0.38878474, -0.3813606 , ..., -0.22666512,
#          -0.5817276 ,  0.04016414],
#         [-0.45145577, -0.37378216, -0.36758673, ..., -0.15625533,
#          -0.5817276 ,  0.04121118],
#         ...,
#         [-0.2870729 , -0.26961145, -0.3123216 , ..., -0.17105359,
#          -0.5817276 ,  0.08550204],
#         [-0.2823249 , -0.27180517, -0.32044882, ..., -0.20024323,
#          -0.5817276 ,  0.08121603],
#         [-0.37328386, -0.3061116 , -0.32858232, ..., -0.17844982,
#          -0.5817276 ,  0.05591249]]], shape=(2399, 48, 37), dtype=float32)

# %%
import pandas as pd
import numpy as np

# Supongamos que 'dataset_for_testing['X']' es tu numpy array de shape (2399, 48, 37)
# Reestructuramos el array para convertirlo en un formato adecuado para series temporales multivariantes
# Transponemos y aplanamos para que tengamos (2399 * 48, 37)

X_reshaped = saits_imputation.reshape(-1, 37)

# Ahora X_reshaped tiene la forma (2399 * 48, 37)

# Creamos un índice para las filas basado en el paso temporal
index = pd.MultiIndex.from_product([range(2399), range(48)], names=['Sample', 'Time'])

# Creamos el DataFrame
df_imputation = pd.DataFrame(X_reshaped, columns=features, index=index)

# Mostrar las primeras filas del DataFrame
df_imputation
# Out:
#               Albumin       ALP       ALT       AST  Bilirubin       BUN  \
# Sample Time
# 0      0    -0.095218 -0.246905 -0.277280  2.316841  -0.193283 -0.474027
#        1    -0.423548 -0.318865 -0.298592  1.326656  -0.457249 -0.475211
#        2    -0.438822 -0.305680 -0.250977  1.469036  -0.478655 -0.510978
#        3    -0.372676 -0.344201 -0.290648  1.399516  -0.425360 -0.431471
#        4    -0.409903 -0.376129 -0.269124  1.276314  -0.408454 -0.503147
# ...               ...       ...       ...       ...        ...       ...
# 2398   43   -0.400294 -0.321020 -0.374187  0.512067  -0.502170 -0.467372
#        44   -0.291858 -0.230269 -0.223448  0.642365  -0.637383 -0.460171
#        45   -0.287073 -0.269611 -0.312322  0.475925  -0.462386 -0.311811
#        46   -0.282325 -0.271805 -0.320449  0.378157  -0.439411 -0.331388
#        47   -0.373284 -0.306112 -0.328582  0.474654  -0.384414 -0.503122
#
#              Cholesterol  Creatinine   DiasABP      FiO2  ...  Platelets  \
# Sample Time                                               ...
# 0      0        0.526486   -0.371081  0.351227 -0.046049  ...  -0.291488
#        1       -0.117103   -0.323409  0.395027  0.056061  ...  -0.370320
#        2       -0.003583   -0.313056  0.318612 -0.066256  ...  -0.720683
#        3       -0.006880   -0.336377  0.308467 -0.059858  ...  -0.659370
#        4       -0.273600   -0.351337  0.272218 -0.160708  ...  -0.843311
# ...                  ...         ...       ...       ...  ...        ...
# 2398   43      -0.199886   -0.296255  1.754107 -0.519132  ...   0.100848
#        44       0.047834   -0.434435  1.480764 -0.758754  ...   0.034328
#        45      -0.015232   -0.343353  1.441798 -0.547801  ...  -0.040391
#        46      -0.084565   -0.365055  1.246970 -0.226440  ...   0.106231
#        47      -0.013620   -0.292638  1.189569 -0.484162  ...   0.010546
#
#              RespRate      SaO2    SysABP      Temp  TroponinI  TroponinT  \
# Sample Time
# 0      0    -0.055426  0.106142 -0.613793  0.058607  -0.341967   1.233391
#        1     0.183191 -0.011094 -0.365231  0.395719  -0.314783   1.741112
#        2     0.151716 -0.046641 -0.395352  0.412677  -0.327917   1.543791
#        3     0.265351  0.063953 -0.534433  0.287742  -0.339523   1.817575
#        4     0.265904 -0.103463 -0.338033  0.316177  -0.328032   1.602911
# ...               ...       ...       ...       ...        ...        ...
# 2398   43    0.280868  2.387219  0.094857  0.506719   0.019381  -0.222676
#        44    0.379033  1.282731  0.417899  0.021478  -0.127354   0.494567
#        45    0.349117  1.834975  0.050634  0.216716  -0.044132  -0.240272
#        46    0.351577  1.282731  0.119847  0.135287  -0.051492  -0.474084
#        47    0.364572  1.452652  0.019672  0.336985  -0.142315  -0.380051
#
#                 Urine       WBC    Weight
# Sample Time
# 0      0    -0.126777  0.065017  0.016923
#        1    -0.358622  0.065017 -0.022345
#        2    -0.302251  0.027494 -0.018572
#        3    -0.361941  0.065017 -0.030632
#        4    -0.362000  0.065017 -0.017393
# ...               ...       ...       ...
# 2398   43   -0.098030 -0.581728  0.073332
#        44   -0.076677 -0.581728  0.079514
#        45   -0.171054 -0.581728  0.085502
#        46   -0.200243 -0.581728  0.081216
#        47   -0.178450 -0.581728  0.055912
#
# [115152 rows x 37 columns]

# %%
import matplotlib.pyplot as plt

# Seleccionar una muestra específica (por ejemplo, la primera muestra, índice 0)
sample_index = 0
time_steps = range(48)  # 48 pasos de tiempo

# Obtener los datos de la primera muestra para las características específicas
sample_data = df.loc[sample_index, ['HR', 'NIMAP']]

# Crear gráfico para Ritmo Cardíaco (HR)
plt.figure(figsize=(14, 6))
if sample_data['HR'].notna().any():  # Verificar si hay datos válidos
    plt.plot(time_steps, sample_data['HR'], label='Ritmo Cardíaco (HR)', color='b')
    plt.title(f'Ritmo Cardíaco (HR) para la Muestra {sample_index + 1}', fontsize=16)
    plt.xlabel('Paso de tiempo', fontsize=14)
    plt.ylabel('Valor de HR', fontsize=14)
    plt.legend(loc='upper right', bbox_to_anchor=(1.2, 1), fontsize=10)
    plt.tight_layout()
else:
    print("No hay datos válidos para Ritmo Cardíaco (HR) en la muestra.")

# %%
import matplotlib.pyplot as plt

# Seleccionar una muestra específica (por ejemplo, la primera muestra, índice 0)
sample_index = 0
time_steps = range(48)  # 48 pasos de tiempo

# Obtener los datos de la primera muestra para las características específicas
sample_data = df_imputation.loc[sample_index, ['HR', 'NIMAP']]

# Crear gráfico para Ritmo Cardíaco (HR)
plt.figure(figsize=(14, 6))
if sample_data['HR'].notna().any():  # Verificar si hay datos válidos
    plt.plot(time_steps, sample_data['HR'], label='Ritmo Cardíaco (HR)', color='b')
    plt.title(f'Ritmo Cardíaco (HR) para la Muestra {sample_index + 1}', fontsize=16)
    plt.xlabel('Paso de tiempo', fontsize=14)
    plt.ylabel('Valor de HR', fontsize=14)
    plt.legend(loc='upper right', bbox_to_anchor=(1.2, 1), fontsize=10)
    plt.tight_layout()
else:
    print("No hay datos válidos para Ritmo Cardíaco (HR) en la muestra.")

# %%
# Crear gráfico para Presión Arterial No Invasiva (NIMAP)
plt.figure(figsize=(14, 6))
if sample_data['NIMAP'].notna().any():  # Verificar si hay datos válidos
    plt.plot(time_steps, sample_data['NIMAP'], label='Presión Arterial No Invasiva (NIMAP)', color='g')
    plt.title(f'Presión Arterial No Invasiva (NIMAP) para la Muestra {sample_index + 1}', fontsize=16)
    plt.xlabel('Paso de tiempo', fontsize=14)
    plt.ylabel('Valor de NIMAP', fontsize=14)
    plt.legend(loc='upper right', bbox_to_anchor=(1.2, 1), fontsize=10)
    plt.tight_layout()
else:
    print("No hay datos válidos para Presión Arterial No Invasiva (NIMAP) en la muestra.")

# Mostrar los gráficos
plt.show()

# %%
# Crear gráfico para Presión Arterial No Invasiva (NIMAP)
plt.figure(figsize=(14, 6))
if sample_data['NIMAP'].notna().any():  # Verificar si hay datos válidos
    plt.plot(time_steps, sample_data['NIMAP'], label='Presión Arterial No Invasiva (NIMAP)', color='g')
    plt.title(f'Presión Arterial No Invasiva (NIMAP) para la Muestra {sample_index + 1}', fontsize=16)
    plt.xlabel('Paso de tiempo', fontsize=14)
    plt.ylabel('Valor de NIMAP', fontsize=14)
    plt.legend(loc='upper right', bbox_to_anchor=(1.2, 1), fontsize=10)
    plt.tight_layout()
else:
    print("No hay datos válidos para Presión Arterial No Invasiva (NIMAP) en la muestra.")

# Mostrar los gráficos
plt.show()

# %%
saits_imputation.shape
# Out:
# (2399, 48, 37)

# %%
from pypots.utils.metrics import calc_mae

physionet2012_dataset['test_X_indicating_mask'] = np.isnan(physionet2012_dataset['test_X']).astype(int)

# Crear una copia de los datos originales
test_X_ori_fixed = np.copy(physionet2012_dataset['test_X_ori'])

# Reemplazar NaNs por 0 (valor constante)
test_X_ori_fixed[np.isnan(test_X_ori_fixed)] = 0

# Verificar si quedan NaNs
num_nans_fixed = np.isnan(test_X_ori_fixed).sum()
print(f"Número de NaNs en test_X_ori después de imputación (con 0): {num_nans_fixed}")

# calculate mean absolute error on the ground truth (artificially-missing values)
# predictions, targets, masks
testing_mae = calc_mae(
    saits_imputation, 
    test_X_ori_fixed, 
    physionet2012_dataset['test_X_indicating_mask'],
)
print(f"Testing mean absolute error (MAE): {testing_mae:.4f}")
# Out:
# Número de NaNs en test_X_ori después de imputación (con 0): 0
# Testing mean absolute error (MAE): 0.3040
