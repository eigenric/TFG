# %% [markdown]
# # Notebook Air-Quality Beijing

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
import os
import sys
from sklearn.preprocessing import StandardScaler # Mantener para uso directo/verificación potencial
from torch.optim import Adam
from torch.optim.lr_scheduler import ReduceLROnPlateau
from torch.nn import SmoothL1Loss

# Asegurar que la raíz del proyecto esté en el Python path
# Ajusta la profundidad del path ('../') según sea necesario
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
# Importar módulos refactorizados
from pampaneira_imputation import config
from pampaneira_imputation import data_preprocessor as dp
from pampaneira_imputation import imputation_methods as im
from pampaneira_imputation import evaluation as ev
from pampaneira_imputation import utils
# Out:
# ████████╗██╗███╗   ███╗███████╗    ███████╗███████╗██████╗ ██╗███████╗███████╗    █████╗ ██╗
# ╚══██╔══╝██║████╗ ████║██╔════╝    ██╔════╝██╔════╝██╔══██╗██║██╔════╝██╔════╝   ██╔══██╗██║
#    ██║   ██║██╔████╔██║█████╗█████╗███████╗█████╗  ██████╔╝██║█████╗  ███████╗   ███████║██║
#    ██║   ██║██║╚██╔╝██║██╔══╝╚════╝╚════██║██╔══╝  ██╔══██╗██║██╔══╝  ╚════██║   ██╔══██║██║
#    ██║   ██║██║ ╚═╝ ██║███████╗    ███████║███████╗██║  ██║██║███████╗███████║██╗██║  ██║██║
#    ╚═╝   ╚═╝╚═╝     ╚═╝╚══════╝    ╚══════╝╚══════╝╚═╝  ╚═╝╚═╝╚══════╝╚══════╝╚═╝╚═╝  ╚═╝╚═╝
# ai4ts v0.0.3 - building AI for unified time-series analysis, https://time-series.ai

# %%
from benchpots.datasets import preprocess_beijing_air_quality

# Load the dataset with artificially missing values
beijing_air_quality = preprocess_beijing_air_quality(0.95, 24, "subseq", seq_len=20)
# Out:
# 2025-06-08 13:16:45 [INFO]: You're using dataset beijing_multisite_air_quality, please cite it properly in your work. You can find its reference information at the below link:
# https://github.com/WenjieDu/TSDB/tree/main/dataset_profiles/beijing_multisite_air_quality
# 2025-06-08 13:16:45 [INFO]: Dataset beijing_multisite_air_quality has already been downloaded. Processing directly...
# 2025-06-08 13:16:45 [INFO]: Dataset beijing_multisite_air_quality has already been cached. Loading from cache directly...
# 2025-06-08 13:16:45 [INFO]: Loaded successfully!
# 2025-06-08 13:16:46 [INFO]: Current dataframe shape: (35064, 18)
# /Users/eigenric/Library/CloudStorage/Dropbox/dgiim/TFG/.venv/lib/python3.13/site-packages/benchpots/datasets/beijing_multisite_air_quality.py:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   current_df["date_time"] = pd.to_datetime(
# 2025-06-08 13:16:46 [INFO]: Current dataframe shape: (35064, 18)
# /Users/eigenric/Library/CloudStorage/Dropbox/dgiim/TFG/.venv/lib/python3.13/site-packages/benchpots/datasets/beijing_multisite_air_quality.py:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   current_df["date_time"] = pd.to_datetime(
# 2025-06-08 13:16:46 [INFO]: Current dataframe shape: (35064, 18)
# /Users/eigenric/Library/CloudStorage/Dropbox/dgiim/TFG/.venv/lib/python3.13/site-packages/benchpots/datasets/beijing_multisite_air_quality.py:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   current_df["date_time"] = pd.to_datetime(
# 2025-06-08 13:16:46 [INFO]: Current dataframe shape: (35064, 18)
# /Users/eigenric/Library/CloudStorage/Dropbox/dgiim/TFG/.venv/lib/python3.13/site-packages/benchpots/datasets/beijing_multisite_air_quality.py:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   current_df["date_time"] = pd.to_datetime(
# 2025-06-08 13:16:46 [INFO]: Current dataframe shape: (35064, 18)
# /Users/eigenric/Library/CloudStorage/Dropbox/dgiim/TFG/.venv/lib/python3.13/site-packages/benchpots/datasets/beijing_multisite_air_quality.py:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   current_df["date_time"] = pd.to_datetime(
# 2025-06-08 13:16:46 [INFO]: Current dataframe shape: (35064, 18)
# /Users/eigenric/Library/CloudStorage/Dropbox/dgiim/TFG/.venv/lib/python3.13/site-packages/benchpots/datasets/beijing_multisite_air_quality.py:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   current_df["date_time"] = pd.to_datetime(
# 2025-06-08 13:16:46 [INFO]: Current dataframe shape: (35064, 18)
# /Users/eigenric/Library/CloudStorage/Dropbox/dgiim/TFG/.venv/lib/python3.13/site-packages/benchpots/datasets/beijing_multisite_air_quality.py:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   current_df["date_time"] = pd.to_datetime(
# 2025-06-08 13:16:46 [INFO]: Current dataframe shape: (35064, 18)
# /Users/eigenric/Library/CloudStorage/Dropbox/dgiim/TFG/.venv/lib/python3.13/site-packages/benchpots/datasets/beijing_multisite_air_quality.py:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   current_df["date_time"] = pd.to_datetime(
# 2025-06-08 13:16:46 [INFO]: Current dataframe shape: (35064, 18)
# /Users/eigenric/Library/CloudStorage/Dropbox/dgiim/TFG/.venv/lib/python3.13/site-packages/benchpots/datasets/beijing_multisite_air_quality.py:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   current_df["date_time"] = pd.to_datetime(
# 2025-06-08 13:16:46 [INFO]: Current dataframe shape: (35064, 18)
# /Users/eigenric/Library/CloudStorage/Dropbox/dgiim/TFG/.venv/lib/python3.13/site-packages/benchpots/datasets/beijing_multisite_air_quality.py:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   current_df["date_time"] = pd.to_datetime(
# 2025-06-08 13:16:46 [INFO]: Current dataframe shape: (35064, 18)
# /Users/eigenric/Library/CloudStorage/Dropbox/dgiim/TFG/.venv/lib/python3.13/site-packages/benchpots/datasets/beijing_multisite_air_quality.py:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   current_df["date_time"] = pd.to_datetime(
# 2025-06-08 13:16:46 [INFO]: Current dataframe shape: (35064, 18)
# /Users/eigenric/Library/CloudStorage/Dropbox/dgiim/TFG/.venv/lib/python3.13/site-packages/benchpots/datasets/beijing_multisite_air_quality.py:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   current_df["date_time"] = pd.to_datetime(
# 2025-06-08 13:16:46 [INFO]: There are total 12 stations, they are ['Gucheng', 'Huairou', 'Tiantan', 'Changping', 'Guanyuan', 'Nongzhanguan', 'Wanliu', 'Dongsi', 'Wanshouxigong', 'Aotizhongxin', 'Dingling', 'Shunyi']
# 2025-06-08 13:16:46 [INFO]: Original df missing rate: 0.016
# 2025-06-08 13:16:46 [INFO]: months selected as train set are <PeriodArray>
# ['2013-03', '2013-04', '2013-05', '2013-06', '2013-07', '2013-08', '2013-09',
#  '2013-10', '2013-11', '2013-12', '2014-01', '2014-02', '2014-03', '2014-04',
#  '2014-05', '2014-06', '2014-07', '2014-08', '2014-09', '2014-10', '2014-11',
#  '2014-12', '2015-01', '2015-02', '2015-03', '2015-04', '2015-05', '2015-06']
# Length: 28, dtype: period[M]
# 2025-06-08 13:16:46 [INFO]: months selected as val set are <PeriodArray>
# ['2015-07', '2015-08', '2015-09', '2015-10', '2015-11', '2015-12', '2016-01',
#  '2016-02', '2016-03', '2016-04']
# Length: 10, dtype: period[M]
# 2025-06-08 13:16:46 [INFO]: months selected as test set are <PeriodArray>
# ['2016-05', '2016-06', '2016-07', '2016-08', '2016-09', '2016-10', '2016-11',
#  '2016-12', '2017-01', '2017-02']
# Length: 10, dtype: period[M]
# 2025-06-08 13:16:46 [WARNING]: hit_rate=1.14 > 1
# 2025-06-08 13:16:46 [WARNING]: hit_rate=1.14 > 1
# 2025-06-08 13:16:46 [WARNING]: hit_rate=1.14 > 1
# 2025-06-08 13:16:46 [INFO]: Total sample number: 1461
# 2025-06-08 13:16:46 [INFO]: Training set size: 852 (58.32%)
# 2025-06-08 13:16:46 [INFO]: Validation set size: 305 (20.88%)
# 2025-06-08 13:16:46 [INFO]: Test set size: 304 (20.81%)
# 2025-06-08 13:16:46 [INFO]: Number of steps: 24
# 2025-06-08 13:16:46 [INFO]: Number of features: 132
# 2025-06-08 13:16:46 [INFO]: Train set missing rate: 59.79%
# 2025-06-08 13:16:46 [INFO]: Validating set missing rate: 59.61%
# 2025-06-08 13:16:46 [INFO]: Test set missing rate: 59.77%

# %%
beijing_air_quality.keys()
# Out:
# dict_keys(['n_steps', 'n_features', 'scaler', 'train_X', 'val_X', 'test_X', 'train_X_ori', 'val_X_ori', 'test_X_ori'])

# %%
# Assemble the datasets for training, validating, and testing.

dataset_for_training = {
    "X": beijing_air_quality['train_X'],
}

dataset_for_validating = {
    "X": beijing_air_quality['val_X'],
    "X_ori": beijing_air_quality['val_X_ori'],
}

dataset_for_testing = {
    "X": beijing_air_quality['test_X'],
    "X_ori": beijing_air_quality['test_X_ori']
}

# %% [markdown]
# ## División en entrenamiento, validación y testing
#
#  The test set
# takes data from the first 10 months (2013/03 - 2013/12). The validation set contains data from the following 10 months
# (2014/01 - 2014/10). The training set takes the left 28 months (2014/11 - 2017/02). T

# %%
# Aplicar métodos base a los datos del conjunto de test (`dataset_for_testing['X']`)
X_test_missing = dataset_for_testing['X']
imputed_results = {} # Diccionario para almacenar resultados

print("\nEjecutando métodos de imputación base...")
# Out:
# Ejecutando métodos de imputación base...

# %% [markdown]
# #### 4.1 Imputación por Mediana
#
# Rellenamos los valores faltantes utilizando la mediana de cada característica (columna) calculada sobre todo el conjunto de datos de test (a través de todas las muestras y pasos de tiempo).

# %%
imputed_results['median'] = im.impute_median_sample_wise(X_test_missing)
print(f"Forma imputación mediana: {imputed_results['median'].shape}, NaNs: {np.isnan(imputed_results['median']).sum()}")
# Out:
#   Midiendo tiempo para 'impute_median_sample_wise'...
#   Finalizado 'impute_median_sample_wise' en 1.095957 segundos
# Forma imputación mediana: (304, 24, 132), NaNs: 0

# %% [markdown]
# #### 4.2 Imputación por Media
#
# Similar a la mediana, pero usamos la media de cada característica para rellenar los valores faltantes.

# %%
imputed_results['mean'] = im.impute_mean_sample_wise(X_test_missing)

print(f"Forma imputación media: {imputed_results['mean'].shape}, NaNs: {np.isnan(imputed_results['mean']).sum()}")
# Out:
#   Midiendo tiempo para 'impute_mean_sample_wise'...
#   Finalizado 'impute_mean_sample_wise' en 0.839115 segundos
# Forma imputación media: (304, 24, 132), NaNs: 0

# %% [markdown]
# #### 4.4 Relleno Forward (ffill)
#
# Nota: Estos métodos pueden requerir eliminar columnas como `WS`, `WD` si causan problemas o no son necesarias. La función de imputación en sí no elimina columnas, pero la evaluación podría necesitar alineación. Asumiremos por ahora que imputamos todas las características. La evaluación maneja la posible eliminación de columnas. Alternativamente, modificamos los datos de entrada antes de pasarlos a la imputación:

# %%
# ### 4.4 Relleno Forward/Backward (ffill/bfill)
# Nota: Estos métodos pueden requerir eliminar columnas como WS, WD si causan problemas.
# Modificamos los datos de entrada si es necesario:
X_test_missing_no_ws_wd = X_test_missing.copy()
cols_to_drop_indices = [config.FEATURE_COLUMNS.index(col) for col in config.COLS_TO_DROP_FOR_BASELINE if col in config.FEATURE_COLUMNS]

if cols_to_drop_indices:
    print(f"Eliminando columnas en índices {cols_to_drop_indices} para métodos Fill.")
    X_test_missing_no_ws_wd = np.delete(X_test_missing, cols_to_drop_indices, axis=2)
else:
    X_test_missing_no_ws_wd = X_test_missing # No hay columnas que eliminar

imputed_results['ffill'] = im.impute_forward(X_test_missing_no_ws_wd)
print(f"Forma imputación Forward fill {imputed_results['ffill'].shape}, NaNs: {np.isnan(imputed_results['ffill']).sum()}")
# Out:
# Eliminando columnas en índices [111, 112] para métodos Fill.
#   Midiendo tiempo para 'impute_forward'...
#   Finalizado 'impute_forward' en 0.073489 segundos
# Forma imputación Forward fill (304, 24, 130), NaNs: 0

# %% [markdown]
# ### 4.5. Modelo Transformer

# %%
transformer_model = im.fit_transformer(dataset_for_training, dataset_for_validating)
imputed_results['transformer'] = im.impute_transformer(transformer_model,
                                                       dataset_for_testing)
# Out:
# 2025-06-08 13:16:48 [INFO]: No given device, using default device: cpu
# 2025-06-08 13:16:48 [INFO]: Model files will be saved to ../results/imputation/transformer/20250608_T131648
# 2025-06-08 13:16:48 [INFO]: Tensorboard file will be saved to ../results/imputation/transformer/20250608_T131648/tensorboard
# 2025-06-08 13:16:48 [INFO]: Using customized MAE as the training loss function.
# 2025-06-08 13:16:48 [INFO]: Using customized MSE as the validation metric function.
# 2025-06-08 13:16:48 [INFO]: Transformer initialized with the given hyperparameters, the number of trainable parameters: 446,852
#   Midiendo tiempo para 'fit_transformer'...
#
# ---> Ejecutando lógica de imputación con Transformer...
#     Inicializando Transformer model...
#     Configurando optimizer, scheduler, loss...
#     Training Transformer model...
# /Users/eigenric/Library/CloudStorage/Dropbox/dgiim/TFG/.venv/lib/python3.13/site-packages/torch/optim/lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
#
# 2025-06-08 13:17:30 [INFO]: Epoch 028 - training loss (MAE): 0.4920, validation MSE: 0.3207
# 2025-06-08 13:17:32 [INFO]: Epoch 029 - training loss (MAE): 0.4964, validation MSE: 0.3139
# 2025-06-08 13:17:34 [INFO]: Epoch 030 - training loss (MAE): 0.4935, validation MSE: 0.3199
# 2025-06-08 13:17:35 [INFO]: Epoch 031 - training loss (MAE): 0.4900, validation MSE: 0.3148
# 2025-06-08 13:17:37 [INFO]: Epoch 032 - training loss (MAE): 0.4832, validation MSE: 0.3136
# 2025-06-08 13:17:38 [INFO]: Epoch 033 - training loss (MAE): 0.4794, validation MSE: 0.3104
# 2025-06-08 13:17:39 [INFO]: Epoch 034 - training loss (MAE): 0.4754, validation MSE: 0.3112
# 2025-06-08 13:17:41 [INFO]: Epoch 035 - training loss (MAE): 0.4732, validation MSE: 0.3125
# 2025-06-08 13:17:42 [INFO]: Epoch 036 - training loss (MAE): 0.4738, validation MSE: 0.3108
# 2025-06-08 13:17:44 [INFO]: Epoch 037 - training loss (MAE): 0.4711, validation MSE: 0.3107
# 2025-06-08 13:17:45 [INFO]: Epoch 038 - training loss (MAE): 0.4679, validation MSE: 0.3079
# 2025-06-08 13:17:47 [INFO]: Epoch 039 - training loss (MAE): 0.4689, validation MSE: 0.3060
# 2025-06-08 13:17:48 [INFO]: Epoch 040 - training loss (MAE): 0.4631, validation MSE: 0.3111
# 2025-06-08 13:17:49 [INFO]: Epoch 041 - training loss (MAE): 0.4601, validation MSE: 0.3079
# 2025-06-08 13:17:50 [INFO]: Epoch 042 - training loss (MAE): 0.4530, validation MSE: 0.3068
# 2025-06-08 13:17:52 [INFO]: Epoch 043 - training loss (MAE): 0.4532, validation MSE: 0.3071
# 2025-06-08 13:17:53 [INFO]: Epoch 044 - training loss (MAE): 0.4528, validation MSE: 0.3082
# 2025-06-08 13:17:53 [INFO]: Exceeded the training patience. Terminating the training procedure...
# 2025-06-08 13:17:53 [INFO]: Finished training. The best model is from epoch#39.
# 2025-06-08 13:17:53 [INFO]: Saved the model to ../results/imputation/transformer/20250608_T131648/Transformer.pypots
#     Transformer training complete.
#   Finalizado 'fit_transformer' en 64.633507 segundos
#   Midiendo tiempo para 'impute_transformer'...
#     Imputando con Transformer en el conjunto de test...
#     Imputación Transformer completa.
#   Finalizado 'impute_transformer' en 0.229661 segundos

# %% [markdown]
# ### 4.6. Modelo SAITS
#
# Si la biblioteca `pypots` está disponible, configuramos y entrenamos un modelo SAITS (Self-Attention based Imputation for Time Series) usando los datos de entrenamiento y validación preprocesados. Luego, usamos el modelo entrenado para imputar los valores faltantes en el conjunto de test.

# %%
saits_model = im.fit_saits(dataset_for_training, dataset_for_validating)
imputed_results['saits'] = im.impute_saits(saits_model,
                                           dataset_for_testing)
# Out:
# 2025-06-08 13:17:53 [INFO]: No given device, using default device: cpu
# 2025-06-08 13:17:53 [INFO]: Model files will be saved to ../results/imputation/saits/20250608_T131753
# 2025-06-08 13:17:53 [INFO]: Tensorboard file will be saved to ../results/imputation/saits/20250608_T131753/tensorboard
# 2025-06-08 13:17:53 [INFO]: Using customized MAE as the training loss function.
# 2025-06-08 13:17:53 [INFO]: Using customized MSE as the validation metric function.
# 2025-06-08 13:17:53 [INFO]: SAITS initialized with the given hyperparameters, the number of trainable parameters:
# 2025-06-08 13:19:00 [INFO]: Epoch 024 - training loss (MAE): 0.4919, validation MSE: 0.3106
# 2025-06-08 13:19:02 [INFO]: Epoch 025 - training loss (MAE): 0.4890, validation MSE: 0.3087
# 2025-06-08 13:19:04 [INFO]: Epoch 026 - training loss (MAE): 0.4867, validation MSE: 0.3048
# 2025-06-08 13:19:07 [INFO]: Epoch 027 - training loss (MAE): 0.4808, validation MSE: 0.3076
# 2025-06-08 13:19:10 [INFO]: Epoch 028 - training loss (MAE): 0.4804, validation MSE: 0.3044
# 2025-06-08 13:19:12 [INFO]: Epoch 029 - training loss (MAE): 0.4718, validation MSE: 0.3020
# 2025-06-08 13:19:16 [INFO]: Epoch 030 - training loss (MAE): 0.4659, validation MSE: 0.3023
# 2025-06-08 13:19:19 [INFO]: Epoch 031 - training loss (MAE): 0.4649, validation MSE: 0.3003
# 2025-06-08 13:19:22 [INFO]: Epoch 032 - training loss (MAE): 0.4727, validation MSE: 0.2980
# 2025-06-08 13:19:24 [INFO]: Epoch 033 - training loss (MAE): 0.4597, validation MSE: 0.2996
# 2025-06-08 13:19:27 [INFO]: Epoch 034 - training loss (MAE): 0.4603, validation MSE: 0.2967
# 2025-06-08 13:19:29 [INFO]: Epoch 035 - training loss (MAE): 0.4556, validation MSE: 0.2973
# 2025-06-08 13:19:32 [INFO]: Epoch 036 - training loss (MAE): 0.4566, validation MSE: 0.2955
# 2025-06-08 13:19:34 [INFO]: Epoch 037 - training loss (MAE): 0.4526, validation MSE: 0.2979
# 2025-06-08 13:19:36 [INFO]: Epoch 038 - training loss (MAE): 0.4509, validation MSE: 0.2959
# 2025-06-08 13:19:39 [INFO]: Epoch 039 - training loss (MAE): 0.4490, validation MSE: 0.2921
# 2025-06-08 13:19:41 [INFO]: Epoch 040 - training loss (MAE): 0.4444, validation MSE: 0.3000
# 2025-06-08 13:19:43 [INFO]: Epoch 041 - training loss (MAE): 0.4522, validation MSE: 0.2992
# 2025-06-08 13:19:47 [INFO]: Epoch 042 - training loss (MAE): 0.4446, validation MSE: 0.2996
# 2025-06-08 13:19:49 [INFO]: Epoch 043 - training loss (MAE): 0.4438, validation MSE: 0.2968
# 2025-06-08 13:19:52 [INFO]: Epoch 044 - training loss (MAE): 0.4418, validation MSE: 0.3010
# 2025-06-08 13:19:52 [INFO]: Exceeded the training patience. Terminating the training procedure...
# 2025-06-08 13:19:52 [INFO]: Finished training. The best model is from epoch#39.
# 2025-06-08 13:19:52 [INFO]: Saved the model to ../results/imputation/saits/20250608_T131753/SAITS.pypots
# Entrenamiento de SAITS completo.
#   Finalizado 'fit_saits' en 118.729798 segundos
#   Midiendo tiempo para 'impute_saits'...
# Imputando con SAITS en el conjunto de test...
#   Finalizado 'impute_saits' en 0.181148 segundos

# %%
processed_data = beijing_air_quality

# %%
beijing_air_quality.keys()
# Out:
# dict_keys(['n_steps', 'n_features', 'scaler', 'train_X', 'val_X', 'test_X', 'train_X_ori', 'val_X_ori', 'test_X_ori', 'train_preexisting_nan_mask', 'val_preexisting_nan_mask', 'test_preexisting_nan_mask', 'train_indicating_mask', 'val_indicating_mask', 'test_indicating_mask', 'train_artificial_mask', 'val_artificial_mask', 'test_artificial_mask'])

# %%
  # Guardar los índices originales ANTES del escalado y ventaneo
processed_data["test_index"] = dataset_for_testing['X'].index

# %%
 # a) Máscara de NaNs PREEXISTENTES (antes de la introducción artificial)
train_preexisting_nan_mask = np.isnan(processed_data["train_X_ori"])
val_preexisting_nan_mask = np.isnan(processed_data["val_X_ori"])
test_preexisting_nan_mask = np.isnan(processed_data["test_X_ori"])
processed_data["train_preexisting_nan_mask"] = train_preexisting_nan_mask.astype(int)
processed_data["val_preexisting_nan_mask"] = val_preexisting_nan_mask.astype(int)
processed_data["test_preexisting_nan_mask"] = test_preexisting_nan_mask.astype(int)

# Actualiza los datos en el diccionario
train_X_missing = processed_data["train_X"] 
val_X_missing = processed_data["val_X"] 
test_X_missing = processed_data["test_X"] 

# c) Máscara indicadora TOTAL (NaNs originales + artificiales)
train_indicating_mask = np.isnan(train_X_missing)
val_indicating_mask = np.isnan(val_X_missing)
test_indicating_mask = np.isnan(test_X_missing)
processed_data["train_indicating_mask"] = train_indicating_mask.astype(int)
processed_data["val_indicating_mask"] = val_indicating_mask.astype(int)
processed_data["test_indicating_mask"] = test_indicating_mask.astype(int)

# d) Máscara de NaNs ARTIFICIALES (SOLO los introducidos ahora)
# Es True donde NO era NaN antes (~preexisting) Y SÍ es NaN ahora (indicating)
train_artificial_nan_mask = ~train_preexisting_nan_mask & train_indicating_mask
val_artificial_nan_mask = ~val_preexisting_nan_mask & val_indicating_mask
test_artificial_nan_mask = ~test_preexisting_nan_mask & test_indicating_mask
processed_data["train_artificial_mask"] = train_artificial_nan_mask.astype(int)
processed_data["val_artificial_mask"] = val_artificial_nan_mask.astype(int)
processed_data["test_artificial_mask"] = test_artificial_nan_mask.astype(int)

# %%
print("\nEvaluando rendimiento de imputación en el conjunto de test...")
import pampaneira_imputation.evaluation as ev

# Usar la función del módulo de evaluación
# Requiere el diccionario de datos preprocesados (para ground truth y máscara)
# y el diccionario de resultados imputados
evaluation_table = ev.evaluate_all_methods(
    beijing_air_quality,
    imputed_results
)

evaluation_table.T
# Out:
# Evaluando rendimiento de imputación en el conjunto de test...
#
# Calculando métricas para: median
#
# Calculando métricas para: mean
# Advertencia: No se encontraron resultados imputados para el método 'linear'. Saltando.
# Ajustando datos verdaderos y máscara para ffill debido a columnas eliminadas para ffill.
#
# Calculando métricas para: ffill
# Advertencia: No se encontraron resultados imputados para el método 'bfill'. Saltando.
#
# Calculando métricas para: transformer
#
# Calculando métricas para: saits
# Method  Median    Mean   Ffill  Transformer   Saits
# RMSE    0.8561  0.8453  0.9498       0.5769  0.5655
# MSE     0.7329  0.7145  0.9022       0.3328  0.3198
# MAE     0.4473  0.4446  0.5369       0.2439  0.2351
# MRE     0.5928  0.5892  0.7099       0.3232  0.3115
