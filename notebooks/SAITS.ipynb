# %%
# SAITS: Ejemplo de Uso

# %% [markdown]
# SAITS (Self-Attention-based Imputations for Time Series) es un modelo de 2023 que pretende servir para imputar datos en POTS (Partially Observed Time Series).

# %%
# Data preprocessing. Tedious, but PyPOTS can help.
import numpy as np
import benchpots
from sklearn.preprocessing import StandardScaler
from pygrinder import mcar
from pypots.data import load_specific_dataset

data = benchpots.datasets.preprocess_physionet2012('all', 0.1)
# Out:
# 2025-02-13 15:20:54 [INFO]: You're using dataset physionet_2012, please cite it properly in your work. You can find its reference information at the below link:
# https://github.com/WenjieDu/TSDB/tree/main/dataset_profiles/physionet_2012
# 2025-02-13 15:20:54 [INFO]: Dataset physionet_2012 has already been downloaded. Processing directly...
# 2025-02-13 15:20:54 [INFO]: Dataset physionet_2012 has already been cached. Loading from cache directly...
# 2025-02-13 15:20:54 [INFO]: Loaded successfully!
# 2025-02-13 15:21:07 [WARNING]: Note that physionet_2012 has sparse observations in the time series, hence we don't add additional missing values to the training dataset.
# 2025-02-13 15:21:07 [INFO]: 69553 values masked out in the val set as ground truth, take 10.01% of the original observed values
# 2025-02-13 15:21:07 [INFO]: 86007 values masked out in the test set as ground truth, take 9.97% of the original observed values
# 2025-02-13 15:21:07 [INFO]: Total sample number: 11988
# 2025-02-13 15:21:07 [INFO]: Training set size: 7671 (63.99%)
# 2025-02-13 15:21:07 [INFO]: Validation set size: 1918 (16.00%)
# 2025-02-13 15:21:07 [INFO]: Test set size: 2399 (20.01%)
# 2025-02-13 15:21:07 [INFO]: Number of steps: 48
# 2025-02-13 15:21:07 [INFO]: Number of features: 37
# 2025-02-13 15:21:07 [INFO]: Train set missing rate: 79.73%
# 2025-02-13 15:21:07 [INFO]: Validating set missing rate: 81.64%
# 2025-02-13 15:21:07 [INFO]: Test set missing rate: 81.77%

# %%
data
# Out:
# {'n_classes': 2,
#  'n_steps': 48,
#  'n_features': 37,
#  'scaler': StandardScaler(),
#  'train_X': array([[[            nan,             nan,             nan, ...,
#                       nan, -3.29921035e+00,             nan],
#          [            nan,             nan,             nan, ...,
#                       nan,             nan,             nan],
#          [            nan,             nan,             nan, ...,
#                       nan,             nan,             nan],
#          ...,
#          [            nan,             nan,             nan, ...,
#                       nan,             nan,             nan],
#          [            nan,             nan,             nan, ...,
#                       nan,             nan,             nan],
#          [            nan,             nan,             nan, ...,
#                       nan,             nan,             nan]],
#
#         [[            nan,             nan,             nan, ...,
#                       nan, -2.79253393e-01,  2.29159306e-03],
#          [            nan,             nan,             nan, ...,
#           -1.40141191e-01,             nan,  6.49841509e-04],
#          [            nan,             nan,             nan, ...,
#                       nan,             nan,             nan],
#          ...,
#          [            nan,             nan,             nan, ...,
#                       nan, -5.96201596e-02, -1.08424193e-02],
#          [            nan,             nan,             nan, ...,
#                       nan, -5.96201596e-02,             nan],
#          [            nan,             nan,             nan, ...,
#                       nan, -5.96201596e-02,             nan]],
#
#         [[            nan,             nan,             nan, ...,
#                       nan, -1.03620364e+00,             nan],
#          [ 2.93066104e-02, -2.47934574e-01, -1.68891993e-01, ...,
#           -2.18341728e-01, -1.03620364e+00,             nan],
#          [            nan,             nan,             nan, ...,
#                       nan, -1.03620364e+00,             nan],
#          ...,
#          [            nan,             nan,             nan, ...,
#                       nan, -1.03620364e+00,             nan],
#          [            nan,             nan,             nan, ...,
#                       nan, -1.03620364e+00,             nan],
#          [            nan,             nan,             nan, ...,
#                       nan, -1.03620364e+00,             nan]],
#
#         ...,
#
#         [[            nan,             nan,             nan, ...,
#                       nan, -5.93015155e-01,             nan],
#          [            nan,             nan,             nan, ...,
#                       nan, -5.93015155e-01,             nan],
#          [            nan,             nan,             nan, ...,
#                       nan, -5.93015155e-01,             nan],
#          ...,
#          [            nan,             nan,             nan, ...,
#                       nan, -5.93015155e-01,             nan],
#          [            nan,             nan,             nan, ...,
#                       nan, -5.93015155e-01,             nan],
#          [            nan,             nan,             nan, ...,
#                       nan, -5.93015155e-01, -9.91910038e-04]],
#
#         [[            nan,             nan,             nan, ...,
#                       nan,  4.89781568e+00,             nan],
#          [            nan,             nan,             nan, ...,
#                       nan,             nan,             nan],
#          [            nan,             nan,             nan, ...,
#                       nan,             nan,             nan],
#          ...,
#          [            nan,             nan,             nan, ...,
#                       nan,             nan,             nan],
#          [            nan,             nan,             nan, ...,
#                       nan,             nan,             nan],
#          [            nan,             nan,             nan, ...,
#                       nan,             nan,             nan]],
#
#         [[            nan,             nan,             nan, ...,
#                       nan, -3.92992032e-01, -2.89016863e-02],
#          [-3.17998663e-01, -3.16592006e-01, -3.02265956e-01, ...,
#            1.55554588e-01,             nan,             nan],
#          [            nan,             nan,             nan, ...,
#                       nan,             nan,             nan],
#          ...,
#          [            nan,             nan,             nan, ...,
#                       nan,             nan,             nan],
#          [            nan,             nan,             nan, ...,
#                       nan,             nan,             nan],
#          [            nan,             nan,             nan, ...,
#                       nan,             nan,             nan]]],
#        shape=(7671, 48, 37)),
#  'train_y': array([0, 0, 0, ..., 0, 0, 0], shape=(7671,)),
#  'train_ICUType': array([4., 2., 3., ..., 4., 3., 1.], shape=(7671,)),
#  'val_X': array([[[        nan,         nan,         nan, ..., -0.01550909,
#           -0.78911626, -0.01576767],
#          [        nan,         nan,         nan, ...,  0.06513522,
#                   nan, -0.02233468],
#          [        nan,         nan,         nan, ...,         nan,
#                   nan, -0.01576767],
#          ...,
#          [        nan,         nan,         nan, ...,         nan,
#           -0.42044619,  0.0088586 ],
#          [        nan,         nan,         nan, ...,         nan,
#           -0.42044619,  0.0088586 ],
#          [        nan,         nan,         nan, ...,         nan,
#           -0.42044619,         nan]],
#
#         [[        nan,         nan,         nan, ...,         nan,
#           -0.94599714,         nan],
#          [        nan,         nan,         nan, ...,         nan,
#                   nan,         nan],
#          [        nan,         nan,         nan, ...,         nan,
#                   nan,         nan],
#          ...,
#          [        nan,         nan,         nan, ...,         nan,
#                   nan,         nan],
#          [        nan,         nan,         nan, ...,         nan,
#                   nan,         nan],
#          [        nan,         nan,         nan, ...,         nan,
#                   nan,         nan]],
#
#         [[        nan,         nan,         nan, ...,         nan,
#            0.21492138,         nan],
#          [        nan,         nan,         nan, ...,  0.21909252,
#            0.21492138, -0.01576767],
#          [        nan,         nan,         nan, ...,         nan,
#            0.21492138,         nan],
#          ...,
#          [        nan,         nan,         nan, ...,         nan,
#            0.14432499,         nan],
#          [        nan,         nan,         nan, ...,         nan,
#                   nan,         nan],
#          [        nan,         nan,         nan, ...,         nan,
#            0.14432499, -0.00263366]],
#
#         ...,
#
#         [[        nan,         nan,         nan, ..., -0.18901653,
#           -0.12237251, -0.06666197],
#          [-0.48338213, -0.32265001, -0.30960152, ..., -0.2427794 ,
#           -0.12237251, -0.05516971],
#          [        nan,         nan,         nan, ...,         nan,
#           -0.12237251,         nan],
#          ...,
#          [        nan,         nan,         nan, ...,         nan,
#           -0.12237251,         nan],
#          [        nan,         nan,         nan, ...,         nan,
#           -0.12237251,         nan],
#          [        nan,         nan,         nan, ...,         nan,
#                   nan,         nan]],
#
#         [[        nan,         nan,         nan, ...,         nan,
#           -0.71459784,         nan],
#          [ 0.53096978, -0.31558234, -0.28292673, ..., -0.14991626,
#           -0.71459784,         nan],
#          [        nan,         nan,         nan, ...,         nan,
#           -0.71459784,         nan],
#          ...,
#          [        nan,         nan,         nan, ...,         nan,
#           -0.71459784,         nan],
#          [        nan,         nan,         nan, ...,         nan,
#           -0.71459784,         nan],
#          [        nan,         nan,         nan, ...,         nan,
#           -0.71459784,         nan]],
#
#         [[-0.34004979, -0.31861134, -0.312269  , ...,  0.09690419,
#            0.52476112, -0.02069293],
#          [        nan,         nan,         nan, ...,         nan,
#                   nan,         nan],
#          [        nan,         nan,         nan, ...,         nan,
#                   nan,         nan],
#          ...,
#          [        nan,         nan,         nan, ...,         nan,
#            0.81891277,         nan],
#          [        nan,         nan,         nan, ...,         nan,
#            0.81891277,         nan],
#          [        nan,         nan,         nan, ...,  0.31439943,
#            0.81891277,         nan]]], shape=(1918, 48, 37)),
#  'val_y': array([0, 0, 0, ..., 1, 1, 0], shape=(1918,)),
#  'val_ICUType': array([2., 1., 3., ..., 4., 3., 4.], shape=(1918,)),
#  'test_X': array([[[            nan,             nan,             nan, ...,
#                       nan, -8.79322763e-01,             nan],
#          [            nan,             nan,             nan, ...,
#                       nan,             nan,             nan],
#          [            nan,             nan,             nan, ...,
#                       nan,             nan,             nan],
#          ...,
#          [            nan,             nan,             nan, ...,
#                       nan,             nan,             nan],
#          [            nan,             nan,             nan, ...,
#                       nan, -8.79322763e-01,             nan],
#          [            nan,             nan,             nan, ...,
#                       nan, -8.79322763e-01,             nan]],
#
#         [[            nan,             nan,             nan, ...,
#                       nan, -6.67533573e-01,             nan],
#          [            nan,             nan,             nan, ...,
#                       nan, -6.67533573e-01, -4.27541313e-03],
#          [            nan,             nan,             nan, ...,
#                       nan, -6.67533573e-01,             nan],
#          ...,
#          [            nan,             nan,             nan, ...,
#                       nan,             nan,             nan],
#          [            nan,             nan,             nan, ...,
#                       nan, -5.26340780e-01,             nan],
#          [            nan,             nan,             nan, ...,
#                       nan, -5.26340780e-01,             nan]],
#
#         [[            nan,             nan,             nan, ...,
#                       nan,             nan,             nan],
#          [            nan,             nan,             nan, ...,
#                       nan, -7.10675816e-01,             nan],
#          [ 1.54532169e+00, -3.03466320e-01, -2.94263518e-01, ...,
#            2.11761223e-01, -7.10675816e-01,             nan],
#          ...,
#          [            nan,             nan,             nan, ...,
#                       nan,             nan,             nan],
#          [            nan,             nan,             nan, ...,
#                       nan,             nan,             nan],
#          [            nan,             nan,             nan, ...,
#                       nan,             nan,             nan]],
#
#         ...,
#
#         [[            nan,             nan,             nan, ...,
#                       nan,  7.37285893e-02,             nan],
#          [            nan,             nan,             nan, ...,
#                       nan,             nan, -9.91910038e-04],
#          [            nan,             nan,             nan, ...,
#                       nan,             nan,             nan],
#          ...,
#          [            nan,             nan,             nan, ...,
#                       nan,             nan,             nan],
#          [            nan,             nan,             nan, ...,
#                       nan,             nan,             nan],
#          [            nan,             nan,             nan, ...,
#                       nan,             nan,             nan]],
#
#         [[            nan,             nan,             nan, ...,
#                       nan,  7.37285893e-02,             nan],
#          [            nan,             nan,             nan, ...,
#           -1.86572760e-01,             nan,             nan],
#          [            nan,             nan,             nan, ...,
#                       nan,             nan,             nan],
#          ...,
#          [            nan,             nan,             nan, ...,
#                       nan,  3.87490351e-01,             nan],
#          [            nan,             nan,             nan, ...,
#                       nan,             nan,             nan],
#          [            nan,             nan,             nan, ...,
#                       nan,  3.87490351e-01,             nan]],
#
#         [[            nan,             nan,             nan, ...,
#            3.48612163e-01,  1.76019806e+00,             nan],
#          [            nan,             nan,             nan, ...,
#                       nan,  1.76019806e+00,             nan],
#          [            nan,             nan,             nan, ...,
#                       nan,  1.76019806e+00,             nan],
#          ...,
#          [            nan,             nan,             nan, ...,
#                       nan,  1.78373019e+00,             nan],
#          [            nan,             nan,             nan, ...,
#                       nan,  1.78373019e+00,             nan],
#          [            nan,             nan,             nan, ...,
#                       nan,  1.78373019e+00,             nan]]],
#        shape=(2399, 48, 37)),
#  'test_y': array([0, 0, 0, ..., 0, 0, 0], shape=(2399,)),
#  'test_ICUType': array([3., 2., 3., ..., 4., 4., 1.], shape=(2399,)),
#  'val_X_ori': array([[[        nan,         nan,         nan, ..., -0.01550909,
#           -0.78911626, -0.01576767],
#          [        nan,         nan,         nan, ...,  0.06513522,
#                   nan, -0.02233468],
#          [        nan,         nan,         nan, ...,         nan,
#                   nan, -0.01576767],
#          ...,
#          [        nan,         nan,         nan, ...,         nan,
#           -0.42044619,  0.0088586 ],
#          [        nan,         nan,         nan, ...,         nan,
#           -0.42044619,  0.0088586 ],
#          [        nan,         nan,         nan, ...,         nan,
#           -0.42044619,         nan]],
#
#         [[        nan,         nan,         nan, ...,         nan,
#           -0.94599714,         nan],
#          [        nan,         nan,         nan, ...,         nan,
#                   nan,         nan],
#          [        nan,         nan,         nan, ...,         nan,
#                   nan,         nan],
#          ...,
#          [        nan,         nan,         nan, ...,         nan,
#                   nan,         nan],
#          [        nan,         nan,         nan, ...,         nan,
#                   nan,         nan],
#          [        nan,         nan,         nan, ...,         nan,
#                   nan,         nan]],
#
#         [[        nan,         nan,         nan, ...,         nan,
#            0.21492138,         nan],
#          [        nan,         nan,         nan, ...,  0.21909252,
#            0.21492138, -0.01576767],
#          [        nan,         nan,         nan, ...,         nan,
#            0.21492138,         nan],
#          ...,
#          [        nan,         nan,         nan, ...,         nan,
#            0.14432499,         nan],
#          [        nan,         nan,         nan, ...,         nan,
#            0.14432499,         nan],
#          [        nan,         nan,         nan, ...,         nan,
#            0.14432499, -0.00263366]],
#
#         ...,
#
#         [[        nan,         nan,         nan, ..., -0.18901653,
#           -0.12237251, -0.06666197],
#          [-0.48338213, -0.32265001, -0.30960152, ..., -0.2427794 ,
#           -0.12237251, -0.05516971],
#          [        nan,         nan,         nan, ...,         nan,
#           -0.12237251,         nan],
#          ...,
#          [        nan,         nan,         nan, ...,         nan,
#           -0.12237251,         nan],
#          [        nan,         nan,         nan, ...,         nan,
#           -0.12237251,         nan],
#          [        nan,         nan,         nan, ...,         nan,
#                   nan,         nan]],
#
#         [[        nan,         nan,         nan, ...,         nan,
#           -0.71459784,         nan],
#          [ 0.53096978, -0.31558234, -0.28292673, ..., -0.14991626,
#           -0.71459784,         nan],
#          [        nan,         nan,         nan, ...,         nan,
#           -0.71459784,         nan],
#          ...,
#          [        nan,         nan,         nan, ...,         nan,
#           -0.71459784,         nan],
#          [        nan,         nan,         nan, ...,         nan,
#           -0.71459784,         nan],
#          [        nan,         nan,         nan, ...,         nan,
#           -0.71459784,         nan]],
#
#         [[-0.34004979, -0.31861134, -0.312269  , ...,  0.09690419,
#            0.52476112, -0.02069293],
#          [        nan,         nan,         nan, ...,         nan,
#                   nan,         nan],
#          [        nan,         nan,         nan, ...,         nan,
#                   nan,         nan],
#          ...,
#          [        nan,         nan,         nan, ...,         nan,
#            0.81891277,         nan],
#          [        nan,         nan,         nan, ...,         nan,
#            0.81891277,         nan],
#          [        nan,         nan,         nan, ...,  0.31439943,
#            0.81891277,         nan]]], shape=(1918, 48, 37)),
#  'test_X_ori': array([[[            nan,             nan,             nan, ...,
#                       nan, -8.79322763e-01,             nan],
#          [            nan,             nan,             nan, ...,
#                       nan,             nan,             nan],
#          [            nan,             nan,             nan, ...,
#                       nan,             nan,             nan],
#          ...,
#          [            nan,             nan,             nan, ...,
#                       nan, -8.79322763e-01,             nan],
#          [            nan,             nan,             nan, ...,
#                       nan, -8.79322763e-01,             nan],
#          [            nan,             nan,             nan, ...,
#                       nan, -8.79322763e-01,             nan]],
#
#         [[            nan,             nan,             nan, ...,
#                       nan, -6.67533573e-01, -7.55891623e-03],
#          [            nan,             nan,             nan, ...,
#           -1.01040923e-01, -6.67533573e-01, -4.27541313e-03],
#          [            nan,             nan,             nan, ...,
#                       nan, -6.67533573e-01,             nan],
#          ...,
#          [            nan,             nan,             nan, ...,
#                       nan, -5.26340780e-01,             nan],
#          [            nan,             nan,             nan, ...,
#                       nan, -5.26340780e-01,             nan],
#          [            nan,             nan,             nan, ...,
#                       nan, -5.26340780e-01,             nan]],
#
#         [[            nan,             nan,             nan, ...,
#                       nan, -7.10675816e-01,             nan],
#          [            nan,             nan,             nan, ...,
#                       nan, -7.10675816e-01,             nan],
#          [ 1.54532169e+00, -3.03466320e-01, -2.94263518e-01, ...,
#            2.11761223e-01, -7.10675816e-01,             nan],
#          ...,
#          [            nan,             nan,             nan, ...,
#                       nan,             nan,             nan],
#          [            nan,             nan,             nan, ...,
#                       nan,             nan,             nan],
#          [            nan,             nan,             nan, ...,
#                       nan,             nan,             nan]],
#
#         ...,
#
#         [[            nan,             nan,             nan, ...,
#                       nan,  7.37285893e-02,             nan],
#          [            nan,             nan,             nan, ...,
#                       nan,             nan, -9.91910038e-04],
#          [            nan,             nan,             nan, ...,
#                       nan,             nan,             nan],
#          ...,
#          [            nan,             nan,             nan, ...,
#                       nan,             nan,             nan],
#          [            nan,             nan,             nan, ...,
#                       nan,             nan,             nan],
#          [            nan,             nan,             nan, ...,
#                       nan,             nan,             nan]],
#
#         [[            nan,             nan,             nan, ...,
#                       nan,  7.37285893e-02, -9.91910038e-04],
#          [            nan,             nan,             nan, ...,
#           -1.86572760e-01,             nan,             nan],
#          [            nan,             nan,             nan, ...,
#                       nan,             nan,             nan],
#          ...,
#          [            nan,             nan,             nan, ...,
#                       nan,  3.87490351e-01,             nan],
#          [            nan,             nan,             nan, ...,
#                       nan,             nan,             nan],
#          [            nan,             nan,             nan, ...,
#                       nan,  3.87490351e-01,             nan]],
#
#         [[            nan,             nan,             nan, ...,
#            3.48612163e-01,  1.76019806e+00,             nan],
#          [            nan,             nan,             nan, ...,
#                       nan,  1.76019806e+00,             nan],
#          [            nan,             nan,             nan, ...,
#                       nan,  1.76019806e+00,             nan],
#          ...,
#          [            nan,             nan,             nan, ...,
#                       nan,  1.78373019e+00,             nan],
#          [            nan,             nan,             nan, ...,
#                       nan,  1.78373019e+00,             nan],
#          [            nan,             nan,             nan, ...,
#                       nan,  1.78373019e+00,             nan]]],
#        shape=(2399, 48, 37))}

# %%
print(data.keys())  
print(type(data["X"]))
# Out:
# dict_keys(['n_classes', 'n_steps', 'n_features', 'scaler', 'train_X', 'train_y', 'train_ICUType', 'val_X', 'val_y', 'val_ICUType', 'test_X', 'test_y', 'test_ICUType', 'val_X_ori', 'test_X_ori'])
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[21], line 2
#       1 print(data.keys())
# ----> 2 print(type(data["X"]))
#
# KeyError: 'X'

# %%
num_samples = len(X['RecordID'].unique())
X = X.drop(['RecordID', 'Time'], axis = 1)
X = StandardScaler().fit_transform(X.to_numpy())
X = X.reshape(num_samples, 48, -1)
X_ori = X  # keep X_ori for validation
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 num_samples = len(X['RecordID'].unique())
#       2 X = X.drop(['RecordID', 'Time'], axis = 1)
#       3 X = StandardScaler().fit_transform(X.to_numpy())
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
X = mcar(X, 0.1)  # randomly hold out 10% observed values as ground truth
dataset = {"X": X}  # X for model input
print(X.shape)  # (11988, 48, 37), 11988 samples and each sample has 48 time steps, 37 features

# Model training. This is PyPOTS showtime.
from pypots.imputation import SAITS
from pypots.utils.metrics import calc_mae
saits = SAITS(n_steps=48, n_features=37, n_layers=2, d_model=256, n_heads=4, d_k=64, d_v=64, d_ffn=128, dropout=0.1, epochs=10)
# Here I use the whole dataset as the training set because ground truth is not visible to the model, you can also split it into train/val/test sets
saits.fit(dataset)  # train the model on the dataset
imputation = saits.impute(dataset)  # impute the originally-missing values and artificially-missing values
indicating_mask = np.isnan(X) ^ np.isnan(X_ori)  # indicating mask for imputation error calculation
mae = calc_mae(imputation, np.nan_to_num(X_ori), indicating_mask)  # calculate mean absolute error on the ground truth (artificially-missing values)
saits.save("save_it_here/saits_physionet2012.pypots")  # save the model for future use
saits.load("save_it_here/saits_physionet2012.pypots")  # reload the serialized model file for following imputation or training
