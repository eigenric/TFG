# %%
import pandas as pd

# %%
df = pd.read_csv("BD_POQUEIRA_CLAS_TFG_RICARDO.csv")

# %%
df[0:5]
# Out:
#    num_plate_ID     total_time_POQ  total_distance  total_holiday  \
# 0             0  381 days 10:52:37            91.5          131.0
# 1             1   92 days 21:54:09           359.5           35.0
# 2             2  237 days 18:28:27          2806.0           87.0
# 3             3   17 days 21:51:48             5.0            6.0
# 4             7  274 days 06:13:19           475.5           96.0
#
#    total_workday  total_high_season  total_low_season  entry_in_high_season  \
# 0          263.0               32.0             362.0                   1.0
# 1           78.0                9.0             104.0                   1.0
# 2          375.0               75.0             387.0                  33.0
# 3           13.0                0.0              19.0                   0.0
# 4          212.0               45.0             263.0                   3.0
#
#    entry_in_holiday  nights  ...  actual_entry_east  \
# 0               4.0   380.0  ...               True
# ...
